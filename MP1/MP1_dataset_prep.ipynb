# %% [markdown]
# # HCDE 530 — A5: Pandas Analysis
#
# ### Instructions
# In class you used pandas to answer five questions about a dataset. For A5 you are doing that on your own data — the dataset you chose for Mini Project 1 — and documenting what you found.
#
# This assignment is closely connected to MP1. The analysis you do here is the foundation for the notebook you will build in Week 6.
#
# ### Introduction
# League of Legends is an online multiplayer game where two teams of 5 battle against each other in what I can only describe as a glorified capture the flag game. Each team must destroy the other team's Nexus in their base to win the game. There are 5 unique roles on each team, corresponding to the lane or area they're typically supposed to play in: Top, Middle, Bottom, Support, and Jungle. In competitive play, players are ranked from Iron to Challenger based on their performance.
#
# As a Support main that hovers around the Bronze level, I was curious in using the Riot Developer API to answer the following questions:
# 1. Who is the most played Support champion in Bronze IV Solo 5x5 Ranked lobbies? What about across all ranks?
# 2. What does the distribution of the most popular Support player across every rank look like?
# 3. What is the most common Bottom Lane/Support pairing in Bronze-level lobbies? What about across all ranks?
#
# A previous version of these questions included one about the pick rate of cosmetic skins, but because that information isn't available through the Riot Developer API, I've changed that question to one that can actually be answered by the API.

# %% [markdown]
# ---
# ### 0. Setting up Pandas

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

print("pandas version:", pd.__version__)
# Out:
# pandas version: 3.0.2

# %% [markdown]
# ---
# ### 1. Importing up the API
#
# To begin answering my data analysis questions, I need to set up endpoints for 3 different APIs, each dealing with a different type of player information. This includes one to fetch summoner ID data (where I'll query for Player Universally Unique IDs (PUUID)), one to extract game match information based on those PUUIDs, and finally an API to extract champion picks per match.

# %% [markdown]
# ##### Player Universally Unique IDs

# %%
import json
import os
import time
import urllib.error
import urllib.request
from pathlib import Path

#function to load .env file so that this code can read the API key on it 
def _load_env(path: Path) -> None:
    """Load KEY=VALUE pairs from a .env file into os.environ (does not override existing vars).""" 
    if not path.is_file(): #if the .env file doesn't exist, return None
        return
    for line in path.read_text().splitlines():# for each line in the .env file
        line = line.strip()
        if not line or line.startswith("#") or "=" not in line:
            continue
        key, _, val = line.partition("=")
        key, val = key.strip(), val.strip().strip('"').strip("'")
        if key:
            os.environ.setdefault(key, val)


# Resolve Week 5/.env whether the kernel cwd is the repo root or the Week 5 folder
for _env in (Path(".env"), Path("Week 5") / ".env"):
    _load_env(_env)

api_key = os.environ.get("RIOT_API_KEY", "").strip() #the api key I stored in .env, will be regenerated every 24 hours
if not api_key:
    raise ValueError("RIOT_API_KEY missing: add it to Week 5/.env or set it in the environment.")

base = "https://na1.api.riotgames.com/lol/league/v4/entries/RANKED_SOLO_5x5/BRONZE/IV" #endpoint for summoner ID data, need to query for PUUIDs later
# Riot sits behind Cloudflare; default User-Agent "Python-urllib/..." often gets HTTP 403 + "error code: 1010".
headers = {
    "X-Riot-Token": api_key,
    "User-Agent": "HCDE530-A5/1.0 (pandas coursework; contact instructor)",
}

all_entries: list = [] #list to store all the data fetched from the API
for page in range(1, 326):  # pages 1 … 325 #calculated based on API request limit from Riot, but actually only fetched 258 because page 259 had no data (see break function below)
    url = f"{base}?page={page}"
    req = urllib.request.Request(url, headers=headers)
    try:
        with urllib.request.urlopen(req, timeout=30) as resp:
            data = json.load(resp)
    except urllib.error.HTTPError as e:
        body = e.read().decode(errors="replace")
        raise RuntimeError(f"HTTP {e.code} {e.reason}: {body[:500]}") from e

    if not data:
        break
    all_entries.extend(data)
    print(f"page {page}", flush=True) #print the page number to track progress as the loop runs
    time.sleep(2.0) #wait 2 seconds between requests to avoid overwhelming the server

summoner_league_json = all_entries #assign the fetched data to a variable to convert JSON into dataframe later 
print(len(summoner_league_json), "total entries across fetched pages") #total data fetched across each request aka page 
if summoner_league_json:
    print("example keys:", list(summoner_league_json[0].keys())) #fields in the JSON data fetched from the API
# Out:
# page 1
# page 2
# page 3
# page 4
# page 5
# page 6
# page 7
# page 8
# page 9
# page 10
# page 11
# page 12
# page 13
# page 14
# page 15
# page 16
# page 17
# page 18
# page 19
# page 20
# page 21
# page 22
# page 23
# page 24
# page 25
# page 26
# page 27
# page 28
# page 29
# page 30
# page 31
# page 32
# page 33
# page 34
# page 35
# page 36
# page 37
# page 38
# page 39
# page 40
# page 41
# page 42
# page 43
# page 44
# page 45
# page 46
# page 47
# page 48
# page 49
# page 50
# page 51
# page 52
# page 53
# page 54
# page 55
# page 56
# page 57
# page 58
# page 59
# page 60
# page 61
# page 62
# page 63
# page 64
# page 65
# page 66
# page 67
# page 68
# page 69
# page 70
# page 71
# page 72
# page 73
# page 74
# page 75
# page 76
# page 77
# page 78
# page 79
# page 80
# page 81
# page 82
# page 83
# page 84
# page 85
# page 86
# page 87
# page 88
# page 89
# page 90
# page 91
# page 92
# page 93
# page 94
# page 95
# page 96
# page 97
# page 98
# page 99
# page 100
# page 101
# page 102
# page 103
# page 104
# page 105
# page 106
# page 107
# page 108
# page 109
# page 110
# page 111
# page 112
# page 113
# page 114
# page 115
# page 116
# page 117
# page 118
# page 119
# page 120
# page 121
# page 122
# page 123
# page 124
# page 125
# page 126
# page 127
# page 128
# page 129
# page 130
# page 131
# page 132
# page 133
# page 134
# page 135
# page 136
# page 137
# page 138
# page 139
# page 140
# page 141
# page 142
# page 143
# page 144
# page 145
# page 146
# page 147
# page 148
# page 149
# page 150
# page 151
# page 152
# page 153
# page 154
# page 155
# page 156
# page 157
# page 158
# page 159
# page 160
# page 161
# page 162
# page 163
# page 164
# page 165
# page 166
# page 167
# page 168
# page 169
# page 170
# page 171
# page 172
# page 173
# page 174
# page 175
# page 176
# page 177
# page 178
# page 179
# page 180
# page 181
# page 182
# page 183
# page 184
# page 185
# page 186
# page 187
# page 188
# page 189
# page 190
# page 191
# page 192
# page 193
# page 194
# page 195
# page 196
# page 197
# page 198
# page 199
# page 200
# page 201
# page 202
# page 203
# page 204
# page 205
# page 206
# page 207
# page 208
# page 209
# page 210
# page 211
# page 212
# page 213
# page 214
# page 215
# page 216
# page 217
# page 218
# page 219
# page 220
# page 221
# page 222
# page 223
# page 224
# page 225
# page 226
# page 227
# page 228
# page 229
# page 230
# page 231
# page 232
# page 233
# page 234
# page 235
# page 236
# page 237
# page 238
# page 239
# page 240
# page 241
# page 242
# page 243
# page 244
# page 245
# page 246
# page 247
# page 248
# page 249
# page 250
# page 251
# page 252
# page 253
# page 254
# page 255
# page 256
# page 257
# page 258
# 52729 total entries across fetched pages
# example keys: ['leagueId', 'queueType', 'tier', 'rank', 'puuid', 'leaguePoints', 'wins', 'losses', 'veteran', 'inactive', 'freshBlood', 'hotStreak']

# %% [markdown]
# ---
# ### 2. Turning JSON data into a DataFrame

# %%
# List of dicts from section 1a — after the fetch cell runs, `summoner_league_json` and `all_entries` point to the same list.
if "summoner_league_json" in globals():
    rows = summoner_league_json
elif "all_entries" in globals():
    rows = all_entries
else:
    raise RuntimeError("Run the API cell in section 1a first so summoner_league_json / all_entries exist.")

df = pd.DataFrame(rows) #convert the JSON data into a dataframe 
n_src = len(rows) #number of records in the JSON data
n_df = len(df) #number of records in the dataframe
cols = len(df.columns) #number of columns in the dataframe
if n_src == 0:
    print("Conversion finished: empty DataFrame (0 rows) — no API data in rows yet.")
elif n_df == n_src:
    print(
        f"JSON → DataFrame conversion successful: {n_df} rows × {cols} columns "
        f"(matches all {n_src} records from summoner_league_json / all_entries)."
    )
else:
    print(
        f"Unexpected row count after conversion: DataFrame has {n_df} rows but source list has {n_src}."
    )
# Out:
# JSON → DataFrame conversion successful: 52729 rows × 12 columns (matches all 52729 records from summoner_league_json / all_entries).

# %% [markdown]
# ---
# ### 3. Analyzing the DataFrame with Pandas Operations
# #### 3a. What kinds of data did we actually fetch with all these API requests? Finding out with `df.head()`
# This operation will allow me to see all the different kinds of data associated with each row that was fetched from the API. Here, we can see that in addition to the PUUID (which we'll need to fetch match history data), we can also see their associated LP (which determines rank), wins, losses, veteran status, activity, and win streaks.

# %%
# `df` is built in section 2 — run that cell first.
print("shape (rows, columns):", df.shape) #display the number of rows and columns in the dataframe
df.head() #display the first 5 rows of the dataframe
# Out:
# shape (rows, columns): (52729, 12)
#                                leagueId        queueType    tier rank  \
# 0  04116fb7-6868-4521-9910-61fb90b76e5d  RANKED_SOLO_5x5  BRONZE   IV
# 1  1ec3dd38-bf92-4c0e-aa5d-ca540bd70919  RANKED_SOLO_5x5  BRONZE   IV
# 2  3610058c-0fc6-4ee5-a161-dad705389f88  RANKED_SOLO_5x5  BRONZE   IV
# 3  346389f6-9c92-414f-b2a1-19f5524e4895  RANKED_SOLO_5x5  BRONZE   IV
# 4  04ec97a8-c7cc-4d22-aa8d-24ac7b697054  RANKED_SOLO_5x5  BRONZE   IV
#
#                                                puuid  leaguePoints  wins  \
# 0  dmr_PvsJDqRYwdOsAvRCGlp5676GgstHkcKjev1N03OTVQ...            18    33
# 1  Q5tPr4VoHQO40KOqRSjQMkb10Uw1uFX62YNk0ZJNYLR4F3...            23     5
# 2  hseHG45GLA7RwEdsMcqt1t6VjpEMPlV_Jelsv26jLRWCQy...            31    36
# 3  LBIg2k5fCNbUGMESy8Gh5hJH9ZupZGwKdwodsu7rNwdKha...            15   169
# 4  W8zW_QFs2RAV1PcYUYWP31upsQoaVDpOmVAuUDeZyWLsV1...            18    31
#
#    losses  veteran  inactive  freshBlood  hotStreak
# 0      52    False     False       False      False
# 1       8    False     False       False      False
# 2      63    False     False       False      False
# 3     202    False     False       False      False
# 4      40    False     False       False      False

# %% [markdown]
# #### 3b. How many times does each PUUID appear? Using the operations: `df['puuid'].value_counts()` & `df.duplicated(subset=["puuid"]).sum()`
# This operation will allow me to see how many times a PUUID appears in the dataframe. Because I had to fetch data from the API in two different sesions (once before receiving an HTTP 429 error, and once after fixing it), there's a possibility that I accidentally fetched the same pages twice. Since PUUIDs are supposed to be unique to each account, each PUUID should really only appear once in my dataframe. This operation will allow me to catch if I accidentally fetched the same pages twice.

# %%
df['puuid'].value_counts() #display the number of times each PUUID appears in the dataframe in descending order
# Out:
# puuid
# ii89RSci7pZ3Jv6TdPagBbbQVEZzFd2llBH9BLhIipO18RCpJTnt0aFxrXwBOKIN7NouuTy07GtqiQ    2
# B1TB7XUm8qYdS5zFTmtOAXlQTAhahPlb0Uhb-1ZPS741W-foGbeiZpp242p0YpZvOcGniZZhBhz--A    2
# 7IOzK6xmUEZ1-zegE26isH9O5FsFKKigiP9rzhd0eoG6N-y5wMob-vOhFBUG0HuDmnn-8vtOzop8AQ    2
# ableOWCSRBhCLXyxj-ntkSCrsRxCx4XDd8xhEUoCtsV48_4PI2iAAfbWe6bdlHNsjf1D6nXSNUQ2xg    2
# o-b2eX8DQHUqnt1JtChX99atA5kVT6fdA7STnjwqugvtxTl30cRnEEHQlazAAD8FcqXXiKh9MQFfuQ    2
#                                                                                  ..
# vd37E5n0iok6pQmUbdmtDAH9CLr02BGqjZTQQSZOXOd-N8mZflR76ccZZs_tLlOQ2Kk_XpUF4h86RA    1
# DN7Y4yEoj0S3UglHmN1sBe8Is_Ru6aPsjd1KO0Oyej8FLl4tpOCulK8e5F_cF60nr8pyY5lx1w8KkA    1
# 7iOcpIxTZaQu8ZezW3ciIr59C8dpM_pTudfh9Kalx2yyZSgzPZmHzlrtAj1liYcqpFI2ngWXiyf5Mw    1
# WFl6wxhqyNJCGx_6m3QWV9OeaJSqBqVhESi4QJhYb3p-P5ByMlBrz-Y20mtsPjEvpSqs91u-Berfbg    1
# 0DzEUblGPo-tTMNDC17gD3Qn_YcbOgtVJ_mWDSpzmjSzYqdS5h1RJqoBmfcOf1PwLxhfw8_EcFCsWw    1
# Name: count, Length: 51447, dtype: int64

# %% [markdown]
# This next code block will tell us how many times a duplicated PUUID appears in the dataframe.

# %%
df.duplicated(subset=["puuid"]).sum() #display the number of duplicate PUUIDs in the dataframe
# Out:
# np.int64(1282)

# %% [markdown]
# Here, we can see that there are 1282 duplicate entries in the dataframe.
#
# #### 3c. How can we merge or deduplicate the repeated PUUIDs? Cleaning with `df.drop_duplicates` and checking with `df_deduped.duplicated`
# Now, our next step is to merge or deduplicate this repeated data.

# %%
df_deduped = df.drop_duplicates(subset=["puuid"], keep="last") #keeps the last occurence of each PUUID, which should've come from the second API call where all pages were fetched successfully

#check if the deduplication worked
print("rows before:", len(df))
df_deduped = df.drop_duplicates(subset=["puuid"], keep="first")
print("rows after:", len(df_deduped))

df_deduped.duplicated(subset=["puuid"]).sum() #double check that the deduplication worked by checking the number of duplicate PUUIDs in the dataframe
#make sure you're using the deduped dataframe instead of the original one! original one still has the duplicates
# Out:
# rows before: 52729
# rows after: 51447
# np.int64(0)

# %% [markdown]
# Now that our dataset has been cleaned of any duplicates, we can use other Pandas Analysis operations to learn more about the dataframe.
#
# #### 3d. Does this dataframe have any NaN values that could affect our future data analysis? Finding out with `df_deduped.isnull().sum()`

# %% [markdown]
# Because we know that PUUIDs are unique to each account, each column should be filled out with information that comes from Riot's API. By using this operation, we can double check that there won't be any NaN values that could affect our data analysis.

# %%
### 4. Extracting PUUIDs to use in another API for Match IDs
df_deduped.isnull().sum()
# Out:
# leagueId        0
# queueType       0
# tier            0
# rank            0
# puuid           0
# leaguePoints    0
# wins            0
# losses          0
# veteran         0
# inactive        0
# freshBlood      0
# hotStreak       0
# dtype: int64

# %% [markdown]
# Because we really only need the PUUIDs from the dataframe to proceed, we can stop our Pandas Analysis here.
#
# Now that we've cleaned up the duplicate data and gained a good understanding of the dataframe, we can move one to extract PUUIDs from each row and use them to fetch data about Match Id, which will give us the suitable information to fetch data about Champion Picks.

# %% [markdown]
# ---
# ### 5. Extracting PUUIDs to use in another API for Match IDs

# %%
# Extract unique PUUIDs from the deduplicated DataFrame for downstream API scripts.
if "df_deduped" not in globals():
    raise RuntimeError("Run the deduplication cell first so df_deduped exists.")

puuid_list = df_deduped["puuid"].dropna().astype(str).tolist()
print(f"Prepared {len(puuid_list)} PUUIDs for API scripting.")
print("Sample:", puuid_list[:5])

# Optional: save to disk as JSON so another script can load it directly.
with open("puuid_list.json", "w", encoding="utf-8") as f:
    json.dump(puuid_list, f, ensure_ascii=False, indent=2)
print("Saved puuid_list.json")
# Out:
# Prepared 51447 PUUIDs for API scripting.
# Sample: ['dmr_PvsJDqRYwdOsAvRCGlp5676GgstHkcKjev1N03OTVQyvTqLUTZmpYmQnR1QetaEeFBBAFDiI0A', 'Q5tPr4VoHQO40KOqRSjQMkb10Uw1uFX62YNk0ZJNYLR4F3k5hRus6RZxNDNbblocQhEc4or40vRRtA', 'hseHG45GLA7RwEdsMcqt1t6VjpEMPlV_Jelsv26jLRWCQyA8wqK22JG-C9hUTz_A5ilXbKCjvt-dMw', 'LBIg2k5fCNbUGMESy8Gh5hJH9ZupZGwKdwodsu7rNwdKhaOy5_ZjEDJ9MWwKmWcf35kMgsWxGpRqrg', 'W8zW_QFs2RAV1PcYUYWP31upsQoaVDpOmVAuUDeZyWLsV1_sRvTcjUaq-xjZKKhhUrwfkLWgcbmSIQ']
# Saved puuid_list.json

# %% [markdown]
# ---
# ### 6. Using stored PUUIDs to fetch data for Match IDs
# It's important to be precise with this API, because it could return matches that weren't played in Ranked 5x5 Solo (which is how we filtered the PUUIDs above). For analysis purposes, we'll be fetching the 10 most recent matches associated with the PUUIDs that were extracted from the dataframe above. As a reminder, the PUUIDs are supposed to represent players that were Bronze IV in Ranked 5x5 Solo queue as of May 6th, 2026.
#
# Additionally, even though the JSON contains around 51,400 PUUIDs (as fetched from the previous API endpoint), the code below will only fetch Match IDs for the first 500 PUUIDs in the JSON file due to time constraints and request limits from Riot. A sample size of 500 should be statistically significant enough to demonstrate major patterns in player behavior. This will take around 40 minutes.

# %%
import json
import os
import time
import urllib.error
import urllib.parse
import urllib.request
from pathlib import Path

QUEUE_ID = 420  # Ranked Solo/Duo 5v5 — see https://static.developer.riotgames.com/docs/lol/queues.json
MATCH_IDS_START = 0
MATCH_IDS_COUNT = 10
REQUEST_SLEEP_SEC = 2.0  # increase if you get HTTP 429
MAX_PUUIDS = 500  # loop through the first 500 PUUIDs from puuid_list.json

#function to load .env file so that this code can read the API key on it 
def _load_env(path: Path) -> None:
    if not path.is_file():
        return
    for line in path.read_text().splitlines():
        line = line.strip()
        if not line or line.startswith("#") or "=" not in line:
            continue
        key, _, val = line.partition("=")
        key, val = key.strip(), val.strip().strip('"').strip("'")
        if key:
            os.environ.setdefault(key, val)

# Resolve Week 5/.env whether the kernel cwd is the repo root or the Week 5 folder
for _env in (Path(".env"), Path("Week 5") / ".env"):
    _load_env(_env)

api_key = os.environ.get("RIOT_API_KEY", "").strip() #the api key I stored in .env, will be regenerated every 24 hours
if not api_key:
    raise ValueError("RIOT_API_KEY missing: add it to Week 5/.env or set it in the environment.") #debugging flag in case API key is missing

# Load PUUID list using relative fallback paths so this works from different kernel cwd values  bc having trouble that this code is not reading the puuid_list.json file
puuid_candidates = [
    Path("puuid_list.json"),
    Path("Week 5") / "puuid_list.json",
    Path("..") / "Week 5" / "puuid_list.json",
]
puuid_path = next((p for p in puuid_candidates if p.is_file()), None)
if puuid_path is None: #debugging flag in case puuid_list.json is not found
    raise FileNotFoundError(
        "puuid_list.json not found. Tried: " + ", ".join(str(p) for p in puuid_candidates)
    )
#load the puuid_list.json file
with open(puuid_path, encoding="utf-8") as f:
    puuids = json.load(f)

if not isinstance(puuids, list): #debugging flag in case puuid_list.json is not a list
    raise TypeError("puuid_list.json should contain a JSON array of PUUID strings.")

if MAX_PUUIDS is not None: 
    puuids = puuids[: int(MAX_PUUIDS)]

# Save checkpoint/output in a relative path that is valid for current cwd bc having trouble that this code is not reading the puuid_list.json file
out_candidates = [
    Path("match_ids_by_puuid.json"),
    Path("Week 5") / "match_ids_by_puuid.json",
    Path("..") / "Week 5" / "match_ids_by_puuid.json",
]
out_path = next((p for p in out_candidates if p.parent.exists()), out_candidates[0])

# Resume support: load existing checkpoint and skip those PUUIDs on rerun in case session is interrupted.
if out_path.is_file():
    with open(out_path, encoding="utf-8") as f:
        existing = json.load(f)
    if not isinstance(existing, dict):
        raise TypeError("match_ids_by_puuid.json should contain a JSON object keyed by puuid.")
    match_ids_by_puuid: dict[str, list] = existing
else:
    match_ids_by_puuid: dict[str, list] = {}

#create a set of PUUIDs to compare with the existing PUUIDs in the JSON file
puuid_set = set(puuids)
completed = {k for k in match_ids_by_puuid.keys() if k in puuid_set}
remaining_puuids = [p for p in puuids if p not in completed]

#print the number of PUUIDs that have already been completed and the number of PUUIDs that are remaining to be completed
total_puuids = len(puuids)
remaining_total = len(remaining_puuids)
print(f"Already completed: {len(completed)} / {total_puuids}")
print(f"Remaining this run: {remaining_total}")

#set the headers for the API request
headers = {
    "X-Riot-Token": api_key,
    "User-Agent": "HCDE530-A5/1.0 (match-v5 by-puuid; coursework)",
}
base_url = "https://americas.api.riotgames.com/lol/match/v5/matches/by-puuid" #endpoint for fetching match IDs by PUUID

#loop through the remaining PUUIDs and fetch the match IDs
for step_idx, puuid in enumerate(remaining_puuids, start=1):
    safe_puuid = urllib.parse.quote(puuid, safe="")
    query = urllib.parse.urlencode(
        {"start": MATCH_IDS_START, "count": MATCH_IDS_COUNT, "queue": QUEUE_ID} #parameters for the API request
    )
    url = f"{base_url}/{safe_puuid}/ids?{query}" #construct the URL for the API request
    req = urllib.request.Request(url, headers=headers) #send the request to the API

    try:
        with urllib.request.urlopen(req, timeout=30) as resp: 
            match_ids = json.load(resp)
    except urllib.error.HTTPError as e:
        body = e.read().decode(errors="replace")
        if e.code == 429:
            time.sleep(60)
            with urllib.request.urlopen(req, timeout=30) as resp:
                match_ids = json.load(resp)
        else:
            raise RuntimeError(f"HTTP {e.code} {e.reason}: {body[:500]}") from e

    match_ids_by_puuid[puuid] = match_ids #add the match IDs to the dictionary

    # Checkpoint after each success so reruns can resume where this run left off.
    with open(out_path, "w", encoding="utf-8") as f:
        json.dump(match_ids_by_puuid, f, ensure_ascii=False, indent=2)

    processed_now = step_idx
    processed_total = len(completed) + processed_now
    print(
        f"PUUIDs processed this run: {processed_now} / {remaining_total} | "
        f"overall: {processed_total} / {total_puuids}",
        flush=True,
    )
    time.sleep(REQUEST_SLEEP_SEC) #wait 2 seconds between requests to avoid overwhelming the server

print(f"Done. Saved {len(match_ids_by_puuid)} PUUID entries to {out_path.resolve()}") #print the number of PUUIDs that have been processed and the total number of PUUIDs that have been processed
# Out:
# Already completed: 480 / 500
# Remaining this run: 20
# PUUIDs processed this run: 1 / 20 | overall: 481 / 500
# PUUIDs processed this run: 2 / 20 | overall: 482 / 500
# PUUIDs processed this run: 3 / 20 | overall: 483 / 500
# PUUIDs processed this run: 4 / 20 | overall: 484 / 500
# PUUIDs processed this run: 5 / 20 | overall: 485 / 500
# PUUIDs processed this run: 6 / 20 | overall: 486 / 500
# PUUIDs processed this run: 7 / 20 | overall: 487 / 500
# PUUIDs processed this run: 8 / 20 | overall: 488 / 500
# PUUIDs processed this run: 9 / 20 | overall: 489 / 500
# PUUIDs processed this run: 10 / 20 | overall: 490 / 500
# PUUIDs processed this run: 11 / 20 | overall: 491 / 500
# PUUIDs processed this run: 12 / 20 | overall: 492 / 500
# PUUIDs processed this run: 13 / 20 | overall: 493 / 500
# PUUIDs processed this run: 14 / 20 | overall: 494 / 500
# PUUIDs processed this run: 15 / 20 | overall: 495 / 500
# PUUIDs processed this run: 16 / 20 | overall: 496 / 500
# PUUIDs processed this run: 17 / 20 | overall: 497 / 500
# PUUIDs processed this run: 18 / 20 | overall: 498 / 500
# PUUIDs processed this run: 19 / 20 | overall: 499 / 500
# PUUIDs processed this run: 20 / 20 | overall: 500 / 500
# Done. Saved 500 PUUID entries to /Users/ruofuli/hcde530/Week 5/match_ids_by_puuid.json

# %% [markdown]
# #### 6a. Converting Match ID JSON to usable dataframe
# Similar to the initial dataframe that allowed us to extract the PUUIDs, now we need to convert the Match IDs JSON into a usable dataframe for Pandas Analysis.

# %%
from pathlib import Path
import json

# Find the match-id checkpoint file using relative fallbacks.
match_candidates = [
    Path("match_ids_by_puuid.json"),
    Path("Week 5") / "match_ids_by_puuid.json",
    Path("..") / "Week 5" / "match_ids_by_puuid.json",
]
match_path = next((p for p in match_candidates if p.is_file()), None)
if match_path is None:
    raise FileNotFoundError( #debugging flag in case match_ids_by_puuid.json is not found
        "match_ids_by_puuid.json not found. Tried: " + ", ".join(str(p) for p in match_candidates)
    )

#load the match_ids_by_puuid.json file
with open(match_path, encoding="utf-8") as f:
    match_ids_by_puuid = json.load(f)

if not isinstance(match_ids_by_puuid, dict):
    raise TypeError("match_ids_by_puuid.json should contain an object mapping puuid -> list[match_id].")

# Flatten dict-of-lists into row records for pandas.
rows = []
for puuid, match_ids in match_ids_by_puuid.items():
    if not isinstance(match_ids, list):
        continue
    for match_id in match_ids:
        rows.append({"puuid": puuid, "match_id": match_id})

matches_df = pd.DataFrame(rows) #convert the match_ids_by_puuid.json file into a dataframe

print("Loaded:", match_path.resolve())
print("shape (rows, columns):", matches_df.shape)
print("unique PUUIDs:", matches_df["puuid"].nunique() if not matches_df.empty else 0)
print("unique match IDs:", matches_df["match_id"].nunique() if not matches_df.empty else 0)
matches_df.head()
# Out:
# Loaded: /Users/ruofuli/hcde530/Week 5/match_ids_by_puuid.json
# shape (rows, columns): (4831, 2)
# unique PUUIDs: 500
# unique match IDs: 4825
#                                                puuid        match_id
# 0  dmr_PvsJDqRYwdOsAvRCGlp5676GgstHkcKjev1N03OTVQ...  NA1_5550304472
# 1  dmr_PvsJDqRYwdOsAvRCGlp5676GgstHkcKjev1N03OTVQ...  NA1_5545162641
# 2  dmr_PvsJDqRYwdOsAvRCGlp5676GgstHkcKjev1N03OTVQ...  NA1_5530609519
# 3  dmr_PvsJDqRYwdOsAvRCGlp5676GgstHkcKjev1N03OTVQ...  NA1_5530552256
# 4  dmr_PvsJDqRYwdOsAvRCGlp5676GgstHkcKjev1N03OTVQ...  NA1_5530519318

# %% [markdown]
# ---
# ### 7. Analyzing the Match ID dataframe (named `matches_df) using Pandas Analysis
# #### 7a. How many repeated Match IDs are there? With `matches_df.duplicated` and `matches_df["match_id"].value_counts()`
# It makes sense if there are repeated Match IDs, because it's entirely possible that some of these players played against each other in multiple matches. However, because we want to eventually find out which Support role champion has the highest pick rate, it's best to (once again) deduplicate our repeated Match IDs to avoid skewing our data.

# %%
if "matches_df" not in globals():
    raise RuntimeError("Run section 6a first so matches_df exists.")

# Count duplicate rows by match_id (all repeats beyond the first occurrence).
duplicate_match_rows = matches_df.duplicated(subset=["match_id"]).sum()

# Count how many distinct match IDs appear more than once.
match_id_counts = matches_df["match_id"].value_counts()
repeated_match_id_count = (match_id_counts > 1).sum()

print("Total rows:", len(matches_df))
print("Unique match IDs:", matches_df["match_id"].nunique())
print("Duplicate match-ID rows:", duplicate_match_rows)
print("Distinct match IDs that are repeated:", repeated_match_id_count)

# Optional: preview top repeated match IDs.
match_id_counts[match_id_counts > 1].head(10)
# Out:
# Total rows: 4831
# Unique match IDs: 4825
# Duplicate match-ID rows: 6
# Distinct match IDs that are repeated: 6
# match_id
# NA1_5553492411    2
# NA1_5553880975    2
# NA1_5477932306    2
# NA1_5515936514    2
# NA1_5554756967    2
# NA1_5554481168    2
# Name: count, dtype: int64

# %% [markdown]
# Honestly, super surprised that only 6 Match IDs were repeated. This means that across the 10 most recent games (as of the snapshot taken on May 6, 2026) from the 500 player sample size I used, only 12 of these entries appeared in the same match with 1 other entry in this sample.
#
# Now I'm curious...
#
# #### 7b. Which of these PUUIDs shared the same Match ID? With `matches_df.groupby("match_id")["puuid"]`

# %%
if "matches_df" not in globals():
    raise RuntimeError("Run section 6a first so matches_df exists.")

# Show match IDs that were linked to more than one PUUID, plus the PUUIDs in each shared match.
shared_match_puuids = (
    matches_df.groupby("match_id")["puuid"]
    .agg(lambda s: sorted(set(s)))
    .reset_index(name="puuids")
)
shared_match_puuids["puuid_count"] = shared_match_puuids["puuids"].str.len() #count the number of PUUIDs in each match
shared_match_puuids = shared_match_puuids[shared_match_puuids["puuid_count"] > 1] #only keep the matches that have more than 1 PUUID
shared_match_puuids = shared_match_puuids.sort_values("puuid_count", ascending=False) #sort the matches by the number of PUUIDs in descending order

print("match IDs shared by multiple PUUIDs:", len(shared_match_puuids))
shared_match_puuids.head(20)

# One row per (match_id, puuid) pair for easier filtering/export.
shared_match_pairs = shared_match_puuids[["match_id", "puuids"]].explode("puuids")#explode the PUUIDs into separate rows
shared_match_pairs = shared_match_pairs.rename(columns={"puuids": "puuid"}) #rename the PUUID column to "puuid"
shared_match_pairs.head(20) #first 20 entries but there's only 12 rows in total
# Out:
# match IDs shared by multiple PUUIDs: 6
#             match_id                                              puuid
# 1169  NA1_5477932306  kM2Q35kVATyg_-g2p4hucag6ZSM57O8VIIs6rJKO4rH3sw...
# 1169  NA1_5477932306  romsuHz5QKq_XUkx7N4qKPjoc2vD4VHsbgFlGeBlmYyufv...
# 2463  NA1_5515936514  N5ad-8s5iKPYbF14er-6c8TcorXz5JpAkWZ4jZjbcSeR-Y...
# 2463  NA1_5515936514  gbLR3Z4L37vx7U3zu5hYHsFHCjFg9seX5KGXOTTchCkdYJ...
# 4329  NA1_5553492411  FFuw8Efm1P2O9fvvt_xSrn9kOfHI5EaaGnFTBJ3sTN0PnD...
# 4329  NA1_5553492411  eoraV-WPRU9WFjZV_MR7t-6ArYKxPMi3wwRHn7tByfnNiT...
# 4418  NA1_5553880975  HBEhi9sBqE7VqfS1OmK6UcJ-0K6ob-_1LYQ6Q-jVzrH2e9...
# 4418  NA1_5553880975  lAMJFfS183Y5omawvwncjvaJiOBSOMeDaJZD2dv-8IdtQ2...
# 4585  NA1_5554481168  44QNoWysHHA5AjcZ3gmo05AdxqNQGYeV0Bz5vqrUcxqewd...
# 4585  NA1_5554481168  EmW71KcXaKFFJih3Y2F2Hbuq1ls3-4PFU3-F5jixCeIdlO...
# 4685  NA1_5554756967  FPNJo2T8taVm5fnE9VndYM5kFv-zM3fTPkx7CwmT1sdEM2...
# 4685  NA1_5554756967  RM85rpEjVbNejT5Cw7ZUxMZ4FBPLxR0sbmHbmv9kaXInb1...

# %% [markdown]
# #### 7c. Deduplicating repeated Match IDs
# Back to business. As mentioned in 7a, every Match ID has to be unique to avoid skewing the data when we have to analyze it later.

# %%
if "matches_df" not in globals():
    raise RuntimeError("Run section 6a first so matches_df exists.")

rows_before = len(matches_df)

# Deduplicate by match_id so each match contributes only once to later analysis.
matches_df_deduped = matches_df.drop_duplicates(subset=["match_id"], keep="first").copy()

rows_after = len(matches_df_deduped)#number of rows in the deduplicated dataframe
removed = rows_before - rows_after #number of rows removed from the deduplicated dataframe

print("rows before dedupe:", rows_before)
print("rows after dedupe:", rows_after)
print("duplicate rows removed:", removed)
print("remaining duplicate match IDs:", matches_df_deduped.duplicated(subset=["match_id"]).sum())

# Save deduped match IDs for downstream scripts/notebooks.
match_deduped_candidates = [
    Path("matches_df_deduped.json"), #possible file paths to find the deduplicated dataframe for match IDs
    Path("Week 5") / "matches_df_deduped.json",
    Path("..") / "Week 5" / "matches_df_deduped.json",
]
match_deduped_out = next((p for p in match_deduped_candidates if p.parent.exists()), match_deduped_candidates[0]) #find the first file path that exists
matches_df_deduped.to_json(match_deduped_out, orient="records", indent=2) #save the deduplicated dataframe to the file path
print("Saved deduped match DataFrame to:", match_deduped_out.resolve()) #print the file path of the deduplicated dataframe

matches_df_deduped.head()
# Out:
# rows before dedupe: 4831
# rows after dedupe: 4825
# duplicate rows removed: 6
# remaining duplicate match IDs: 0
# Saved deduped match DataFrame to: /Users/ruofuli/hcde530/Week 5/matches_df_deduped.json
#                                                puuid        match_id
# 0  dmr_PvsJDqRYwdOsAvRCGlp5676GgstHkcKjev1N03OTVQ...  NA1_5550304472
# 1  dmr_PvsJDqRYwdOsAvRCGlp5676GgstHkcKjev1N03OTVQ...  NA1_5545162641
# 2  dmr_PvsJDqRYwdOsAvRCGlp5676GgstHkcKjev1N03OTVQ...  NA1_5530609519
# 3  dmr_PvsJDqRYwdOsAvRCGlp5676GgstHkcKjev1N03OTVQ...  NA1_5530552256
# 4  dmr_PvsJDqRYwdOsAvRCGlp5676GgstHkcKjev1N03OTVQ...  NA1_5530519318

# %% [markdown]
# While I was expecting 5000 initial rows, there ended up being less because some players didn't play enough Ranked games to fill up all 10 spots.

# %% [markdown]
# ---
# ### 8. Using stored Match IDs to fetch data for Champion Picks
# In our third and final API that we'll be calling to answer our analytical questions, we'll be using the Match IDs stored in the deduped JSON file in another endpoint that fetches data for which champions were selected per Match ID.
#
# Similar to the transition from PUUIDs to Match IDs, I will be unable to cycle through all of the Match IDs that were fetched previously due to API request limits. As a result, the code below will only cycle through the first 500 Match IDs that appear in the JSON file, which equals to about 50 players.
#
# Each Match ID is going to return a lot of fields, so we'll have to do some further data cleaning after to extract the fields that we actually care about; namely, the 10 champion picks for the game, 5 from each team. The game doesn't allow for repeated champion picks (at least in Ranked), so each champion should be unique.

# %%
import json
import os
import time
import urllib.error
import urllib.parse
import urllib.request
from pathlib import Path

MIN_PICKS_PER_MATCH = 10  # ranked 5v5; re-fetch if checkpoint has fewer
REQUEST_SLEEP_SEC = 2.0  # increase if you get HTTP 429


def _load_env(path: Path) -> None:
    if not path.is_file():
        return
    for line in path.read_text().splitlines():
        line = line.strip()
        if not line or line.startswith("#") or "=" not in line:
            continue
        key, _, val = line.partition("=")
        key, val = key.strip(), val.strip().strip('"').strip("'")
        if key:
            os.environ.setdefault(key, val)


def _extract_champion_picks(match_data: dict) -> list[dict]:
    """Pull champion/role fields from info.participants for one match."""
    participants = match_data.get("info", {}).get("participants", [])
    picks = []
    for p in participants:
        if not isinstance(p, dict):
            continue
        picks.append(
            {
                "puuid": p.get("puuid"),
                "championId": p.get("championId"),
                "championName": p.get("championName"),
                "teamId": p.get("teamId"),
                "teamPosition": p.get("teamPosition"),
                "individualPosition": p.get("individualPosition"),
                "win": p.get("win"),
            }
        )
    return picks


def _is_complete(picks: object) -> bool:
    return isinstance(picks, list) and len(picks) >= MIN_PICKS_PER_MATCH


for _env in (
    Path(".env"),
    Path("Week 5") / ".env",
    Path("..") / "Week 5" / ".env",
):
    _load_env(_env)

api_key = os.environ.get("RIOT_API_KEY", "").strip()
if not api_key:
    raise ValueError("RIOT_API_KEY missing: add it to Week 5/.env or set it in the environment.")

deduped_candidates = [
    Path("matches_df_deduped.json"),
    Path("Week 5") / "matches_df_deduped.json",
    Path("..") / "Week 5" / "matches_df_deduped.json",
]
deduped_path = next((p for p in deduped_candidates if p.is_file()), None)
if deduped_path is None:
    raise FileNotFoundError(
        "matches_df_deduped.json not found. Tried: " + ", ".join(str(p) for p in deduped_candidates)
    )

with open(deduped_path, encoding="utf-8") as f:
    deduped_records = json.load(f)

if not isinstance(deduped_records, list):
    raise TypeError("matches_df_deduped.json should contain a JSON array of records.")

seen: set[str] = set()
all_unique_match_ids: list[str] = []
for row in deduped_records:
    mid = row.get("match_id") if isinstance(row, dict) else None
    if not mid or mid in seen:
        continue
    seen.add(mid)
    all_unique_match_ids.append(str(mid))

out_candidates = [
    Path("champion_picks_by_match_id.json"),
    Path("Week 5") / "champion_picks_by_match_id.json",
    Path("..") / "Week 5" / "champion_picks_by_match_id.json",
]
out_path = next((p for p in out_candidates if p.parent.exists()), out_candidates[0])

if out_path.is_file():
    with open(out_path, encoding="utf-8") as f:
        existing = json.load(f)
    if not isinstance(existing, dict):
        raise TypeError("champion_picks_by_match_id.json should be a JSON object keyed by match_id.")
    champion_picks_by_match_id: dict[str, list] = existing
else:
    champion_picks_by_match_id = {}

match_ids = all_unique_match_ids
completed = {mid for mid in match_ids if _is_complete(champion_picks_by_match_id.get(mid))}
remaining_match_ids = [mid for mid in match_ids if mid not in completed]

total_match_ids = len(match_ids)
remaining_total = len(remaining_match_ids)
print("Loaded match list from:", deduped_path.resolve())
print("Total unique match IDs:", total_match_ids)
print("Already complete in checkpoint:", len(completed), "/", total_match_ids)
print("Remaining this run:", remaining_total)
print("Checkpoint file:", out_path.resolve())

headers = {
    "X-Riot-Token": api_key,
    "User-Agent": "HCDE530-A5/1.0 (match-v5 champion picks; coursework)",
}
base_url = "https://americas.api.riotgames.com/lol/match/v5/matches"

for step_idx, match_id in enumerate(remaining_match_ids, start=1):
    safe_match_id = urllib.parse.quote(match_id, safe="")
    url = f"{base_url}/{safe_match_id}"
    req = urllib.request.Request(url, headers=headers)

    try:
        with urllib.request.urlopen(req, timeout=30) as resp:
            match_data = json.load(resp)
    except urllib.error.HTTPError as e:
        body = e.read().decode(errors="replace")
        if e.code == 429:
            time.sleep(60)
            with urllib.request.urlopen(req, timeout=30) as resp:
                match_data = json.load(resp)
        else:
            raise RuntimeError(f"HTTP {e.code} {e.reason}: {body[:500]}") from e

    champion_picks_by_match_id[match_id] = _extract_champion_picks(match_data)

    with open(out_path, "w", encoding="utf-8") as f:
        json.dump(champion_picks_by_match_id, f, ensure_ascii=False, indent=2)

    processed_now = step_idx
    processed_total = len(completed) + processed_now
    print(
        f"Match IDs processed this run: {processed_now} / {remaining_total} | "
        f"overall: {processed_total} / {total_match_ids}",
        flush=True,
    )
    time.sleep(REQUEST_SLEEP_SEC)

print(f"Done. Saved champion picks for {len(champion_picks_by_match_id)} matches to {out_path.resolve()}")
# Out:
# Loaded match list from: /Users/ruofuli/hcde530/Week 5/matches_df_deduped.json
# Total unique match IDs: 4825
# Already complete in checkpoint: 0 / 4825
# Remaining this run: 4825
# Checkpoint file: /Users/ruofuli/hcde530/MP1/champion_picks_by_match_id.json
# Match IDs processed this run: 1 / 4825 | overall: 1 / 4825
# Match IDs processed this run: 2 / 4825 | overall: 2 / 4825
# Match IDs processed this run: 3 / 4825 | overall: 3 / 4825
# Match IDs processed this run: 4 / 4825 | overall: 4 / 4825
# Match IDs processed this run: 5 / 4825 | overall: 5 / 4825
# Match IDs processed this run: 6 / 4825 | overall: 6 / 4825
# Match IDs processed this run: 7 / 4825 | overall: 7 / 4825
# Match IDs processed this run: 8 / 4825 | overall: 8 / 4825
# Match IDs processed this run: 9 / 4825 | overall: 9 / 4825
# Match IDs processed this run: 10 / 4825 | overall: 10 / 4825
# Match IDs processed this run: 11 / 4825 | overall: 11 / 4825
# Match IDs processed this run: 12 / 4825 | overall: 12 / 4825
# Match IDs processed this run: 13 / 4825 | overall: 13 / 4825
# Match IDs processed this run: 14 / 4825 | overall: 14 / 4825
# Match IDs processed this run: 15 / 4825 | overall: 15 / 4825
# Match IDs processed this run: 16 / 4825 | overall: 16 / 4825
# Match IDs processed this run: 17 / 4825 | overall: 17 / 4825
# Match IDs processed this run: 18 / 4825 | overall: 18 / 4825
# Match IDs processed this run: 19 / 4825 | overall: 19 / 4825
# Match IDs processed this run: 20 / 4825 | overall: 20 / 4825
# Match IDs processed this run: 21 / 4825 | overall: 21 / 4825
# Match IDs processed this run: 22 / 4825 | overall: 22 / 4825
# Match IDs processed this run: 23 / 4825 | overall: 23 / 4825
# Match IDs processed this run: 24 / 4825 | overall: 24 / 4825
# Match IDs processed this run: 25 / 4825 | overall: 25 / 4825
# Match IDs processed this run: 26 / 4825 | overall: 26 / 4825
# Match IDs processed this run: 27 / 4825 | overall: 27 / 4825
# Match IDs processed this run: 28 / 4825 | overall: 28 / 4825
# Match IDs processed this run: 29 / 4825 | overall: 29 / 4825
# Match IDs processed this run: 30 / 4825 | overall: 30 / 4825
# Match IDs processed this run: 31 / 4825 | overall: 31 / 4825
# Match IDs processed this run: 32 / 4825 | overall: 32 / 4825
# Match IDs processed this run: 33 / 4825 | overall: 33 / 4825
# Match IDs processed this run: 34 / 4825 | overall: 34 / 4825
# Match IDs processed this run: 35 / 4825 | overall: 35 / 4825
# Match IDs processed this run: 36 / 4825 | overall: 36 / 4825
# Match IDs processed this run: 37 / 4825 | overall: 37 / 4825
# Match IDs processed this run: 38 / 4825 | overall: 38 / 4825
# Match IDs processed this run: 39 / 4825 | overall: 39 / 4825
# Match IDs processed this run: 40 / 4825 | overall: 40 / 4825
# Match IDs processed this run: 41 / 4825 | overall: 41 / 4825
# Match IDs processed this run: 42 / 4825 | overall: 42 / 4825
# Match IDs processed this run: 43 / 4825 | overall: 43 / 4825
# Match IDs processed this run: 44 / 4825 | overall: 44 / 4825
# Match IDs processed this run: 45 / 4825 | overall: 45 / 4825
# Match IDs processed this run: 46 / 4825 | overall: 46 / 4825
# Match IDs processed this run: 47 / 4825 | overall: 47 / 4825
# Match IDs processed this run: 48 / 4825 | overall: 48 / 4825
# Match IDs processed this run: 49 / 4825 | overall: 49 / 4825
# Match IDs processed this run: 50 / 4825 | overall: 50 / 4825
# Match IDs processed this run: 51 / 4825 | overall: 51 / 4825
# Match IDs processed this run: 52 / 4825 | overall: 52 / 4825
# Match IDs processed this run: 53 / 4825 | overall: 53 / 4825
# Match IDs processed this run: 54 / 4825 | overall: 54 / 4825
# Match IDs processed this run: 55 / 4825 | overall: 55 / 4825
# Match IDs processed this run: 56 / 4825 | overall: 56 / 4825
# Match IDs processed this run: 57 / 4825 | overall: 57 / 4825
# Match IDs processed this run: 58 / 4825 | overall: 58 / 4825
# Match IDs processed this run: 59 / 4825 | overall: 59 / 4825
# Match IDs processed this run: 60 / 4825 | overall: 60 / 4825
# Match IDs processed this run: 61 / 4825 | overall: 61 / 4825
# Match IDs processed this run: 62 / 4825 | overall: 62 / 4825
# Match IDs processed this run: 63 / 4825 | overall: 63 / 4825
# Match IDs processed this run: 64 / 4825 | overall: 64 / 4825
# Match IDs processed this run: 65 / 4825 | overall: 65 / 4825
# Match IDs processed this run: 66 / 4825 | overall: 66 / 4825
# Match IDs processed this run: 67 / 4825 | overall: 67 / 4825
# Match IDs processed this run: 68 / 4825 | overall: 68 / 4825
# Match IDs processed this run: 69 / 4825 | overall: 69 / 4825
# Match IDs processed this run: 70 / 4825 | overall: 70 / 4825
# Match IDs processed this run: 71 / 4825 | overall: 71 / 4825
# Match IDs processed this run: 72 / 4825 | overall: 72 / 4825
# Match IDs processed this run: 73 / 4825 | overall: 73 / 4825
# Match IDs processed this run: 74 / 4825 | overall: 74 / 4825
# Match IDs processed this run: 75 / 4825 | overall: 75 / 4825
# Match IDs processed this run: 76 / 4825 | overall: 76 / 4825
# Match IDs processed this run: 77 / 4825 | overall: 77 / 4825
# Match IDs processed this run: 78 / 4825 | overall: 78 / 4825
# Match IDs processed this run: 79 / 4825 | overall: 79 / 4825
# Match IDs processed this run: 80 / 4825 | overall: 80 / 4825
# Match IDs processed this run: 81 / 4825 | overall: 81 / 4825
# Match IDs processed this run: 82 / 4825 | overall: 82 / 4825
# Match IDs processed this run: 83 / 4825 | overall: 83 / 4825
# Match IDs processed this run: 84 / 4825 | overall: 84 / 4825
# Match IDs processed this run: 85 / 4825 | overall: 85 / 4825
# Match IDs processed this run: 86 / 4825 | overall: 86 / 4825
# Match IDs processed this run: 87 / 4825 | overall: 87 / 4825
# Match IDs processed this run: 88 / 4825 | overall: 88 / 4825
# Match IDs processed this run: 89 / 4825 | overall: 89 / 4825
# Match IDs processed this run: 90 / 4825 | overall: 90 / 4825
# Match IDs processed this run: 91 / 4825 | overall: 91 / 4825
# Match IDs processed this run: 92 / 4825 | overall: 92 / 4825
# Match IDs processed this run: 93 / 4825 | overall: 93 / 4825
# Match IDs processed this run: 94 / 4825 | overall: 94 / 4825
# Match IDs processed this run: 95 / 4825 | overall: 95 / 4825
# Match IDs processed this run: 96 / 4825 | overall: 96 / 4825
# Match IDs processed this run: 97 / 4825 | overall: 97 / 4825
# Match IDs processed this run: 98 / 4825 | overall: 98 / 4825
# Match IDs processed this run: 99 / 4825 | overall: 99 / 4825
# Match IDs processed this run: 100 / 4825 | overall: 100 / 4825
# Match IDs processed this run: 101 / 4825 | overall: 101 / 4825
# Match IDs processed this run: 102 / 4825 | overall: 102 / 4825
# Match IDs processed this run: 103 / 4825 | overall: 103 / 4825
# Match IDs processed this run: 104 / 4825 | overall: 104 / 4825
# Match IDs processed this run: 105 / 4825 | overall: 105 / 4825
# Match IDs processed this run: 106 / 4825 | overall: 106 / 4825
# Match IDs processed this run: 107 / 4825 | overall: 107 / 4825
# Match IDs processed this run: 108 / 4825 | overall: 108 / 4825
# Match IDs processed this run: 109 / 4825 | overall: 109 / 4825
# Match IDs processed this run: 110 / 4825 | overall: 110 / 4825
# Match IDs processed this run: 111 / 4825 | overall: 111 / 4825
# Match IDs processed this run: 112 / 4825 | overall: 112 / 4825
# Match IDs processed this run: 113 / 4825 | overall: 113 / 4825
# Match IDs processed this run: 114 / 4825 | overall: 114 / 4825
# Match IDs processed this run: 115 / 4825 | overall: 115 / 4825
# Match IDs processed this run: 116 / 4825 | overall: 116 / 4825
# Match IDs processed this run: 117 / 4825 | overall: 117 / 4825
# Match IDs processed this run: 118 / 4825 | overall: 118 / 4825
# Match IDs processed this run: 119 / 4825 | overall: 119 / 4825
# Match IDs processed this run: 120 / 4825 | overall: 120 / 4825
# Match IDs processed this run: 121 / 4825 | overall: 121 / 4825
# Match IDs processed this run: 122 / 4825 | overall: 122 / 4825
# Match IDs processed this run: 123 / 4825 | overall: 123 / 4825
# Match IDs processed this run: 124 / 4825 | overall: 124 / 4825
# Match IDs processed this run: 125 / 4825 | overall: 125 / 4825
# Match IDs processed this run: 126 / 4825 | overall: 126 / 4825
# Match IDs processed this run: 127 / 4825 | overall: 127 / 4825
# Match IDs processed this run: 128 / 4825 | overall: 128 / 4825
# Match IDs processed this run: 129 / 4825 | overall: 129 / 4825
# Match IDs processed this run: 130 / 4825 | overall: 130 / 4825
# Match IDs processed this run: 131 / 4825 | overall: 131 / 4825
# Match IDs processed this run: 132 / 4825 | overall: 132 / 4825
# Match IDs processed this run: 133 / 4825 | overall: 133 / 4825
# Match IDs processed this run: 134 / 4825 | overall: 134 / 4825
# Match IDs processed this run: 135 / 4825 | overall: 135 / 4825
# Match IDs processed this run: 136 / 4825 | overall: 136 / 4825
# Match IDs processed this run: 137 / 4825 | overall: 137 / 4825
# Match IDs processed this run: 138 / 4825 | overall: 138 / 4825
# Match IDs processed this run: 139 / 4825 | overall: 139 / 4825
# Match IDs processed this run: 140 / 4825 | overall: 140 / 4825
# Match IDs processed this run: 141 / 4825 | overall: 141 / 4825
# Match IDs processed this run: 142 / 4825 | overall: 142 / 4825
# Match IDs processed this run: 143 / 4825 | overall: 143 / 4825
# Match IDs processed this run: 144 / 4825 | overall: 144 / 4825
# Match IDs processed this run: 145 / 4825 | overall: 145 / 4825
# Match IDs processed this run: 146 / 4825 | overall: 146 / 4825
# Match IDs processed this run: 147 / 4825 | overall: 147 / 4825
# Match IDs processed this run: 148 / 4825 | overall: 148 / 4825
# Match IDs processed this run: 149 / 4825 | overall: 149 / 4825
# Match IDs processed this run: 150 / 4825 | overall: 150 / 4825
# Match IDs processed this run: 151 / 4825 | overall: 151 / 4825
# Match IDs processed this run: 152 / 4825 | overall: 152 / 4825
# Match IDs processed this run: 153 / 4825 | overall: 153 / 4825
# Match IDs processed this run: 154 / 4825 | overall: 154 / 4825
# Match IDs processed this run: 155 / 4825 | overall: 155 / 4825
# Match IDs processed this run: 156 / 4825 | overall: 156 / 4825
# Match IDs processed this run: 157 / 4825 | overall: 157 / 4825
# Match IDs processed this run: 158 / 4825 | overall: 158 / 4825
# Match IDs processed this run: 159 / 4825 | overall: 159 / 4825
# Match IDs processed this run: 160 / 4825 | overall: 160 / 4825
# Match IDs processed this run: 161 / 4825 | overall: 161 / 4825
# Match IDs processed this run: 162 / 4825 | overall: 162 / 4825
# Match IDs processed this run: 163 / 4825 | overall: 163 / 4825
# Match IDs processed this run: 164 / 4825 | overall: 164 / 4825
# Match IDs processed this run: 165 / 4825 | overall: 165 / 4825
# Match IDs processed this run: 166 / 4825 | overall: 166 / 4825
# Match IDs processed this run: 167 / 4825 | overall: 167 / 4825
# Match IDs processed this run: 168 / 4825 | overall: 168 / 4825
# Match IDs processed this run: 169 / 4825 | overall: 169 / 4825
# Match IDs processed this run: 170 / 4825 | overall: 170 / 4825
# Match IDs processed this run: 171 / 4825 | overall: 171 / 4825
# Match IDs processed this run: 172 / 4825 | overall: 172 / 4825
# Match IDs processed this run: 173 / 4825 | overall: 173 / 4825
# Match IDs processed this run: 174 / 4825 | overall: 174 / 4825
# Match IDs processed this run: 175 / 4825 | overall: 175 / 4825
# Match IDs processed this run: 176 / 4825 | overall: 176 / 4825
# Match IDs processed this run: 177 / 4825 | overall: 177 / 4825
# Match IDs processed this run: 178 / 4825 | overall: 178 / 4825
# Match IDs processed this run: 179 / 4825 | overall: 179 / 4825
# Match IDs processed this run: 180 / 4825 | overall: 180 / 4825
# Match IDs processed this run: 181 / 4825 | overall: 181 / 4825
# Match IDs processed this run: 182 / 4825 | overall: 182 / 4825
# Match IDs processed this run: 183 / 4825 | overall: 183 / 4825
# Match IDs processed this run: 184 / 4825 | overall: 184 / 4825
# Match IDs processed this run: 185 / 4825 | overall: 185 / 4825
# Match IDs processed this run: 186 / 4825 | overall: 186 / 4825
# Match IDs processed this run: 187 / 4825 | overall: 187 / 4825
# Match IDs processed this run: 188 / 4825 | overall: 188 / 4825
# Match IDs processed this run: 189 / 4825 | overall: 189 / 4825
# Match IDs processed this run: 190 / 4825 | overall: 190 / 4825
# Match IDs processed this run: 191 / 4825 | overall: 191 / 4825
# Match IDs processed this run: 192 / 4825 | overall: 192 / 4825
# Match IDs processed this run: 193 / 4825 | overall: 193 / 4825
# Match IDs processed this run: 194 / 4825 | overall: 194 / 4825
# Match IDs processed this run: 195 / 4825 | overall: 195 / 4825
# Match IDs processed this run: 196 / 4825 | overall: 196 / 4825
# Match IDs processed this run: 197 / 4825 | overall: 197 / 4825
# Match IDs processed this run: 198 / 4825 | overall: 198 / 4825
# Match IDs processed this run: 199 / 4825 | overall: 199 / 4825
# Match IDs processed this run: 200 / 4825 | overall: 200 / 4825
# Match IDs processed this run: 201 / 4825 | overall: 201 / 4825
# Match IDs processed this run: 202 / 4825 | overall: 202 / 4825
# Match IDs processed this run: 203 / 4825 | overall: 203 / 4825
# Match IDs processed this run: 204 / 4825 | overall: 204 / 4825
# Match IDs processed this run: 205 / 4825 | overall: 205 / 4825
# Match IDs processed this run: 206 / 4825 | overall: 206 / 4825
# Match IDs processed this run: 207 / 4825 | overall: 207 / 4825
# Match IDs processed this run: 208 / 4825 | overall: 208 / 4825
# Match IDs processed this run: 209 / 4825 | overall: 209 / 4825
# Match IDs processed this run: 210 / 4825 | overall: 210 / 4825
# Match IDs processed this run: 211 / 4825 | overall: 211 / 4825
# Match IDs processed this run: 212 / 4825 | overall: 212 / 4825
# Match IDs processed this run: 213 / 4825 | overall: 213 / 4825
# Match IDs processed this run: 214 / 4825 | overall: 214 / 4825
# Match IDs processed this run: 215 / 4825 | overall: 215 / 4825
# Match IDs processed this run: 216 / 4825 | overall: 216 / 4825
# Match IDs processed this run: 217 / 4825 | overall: 217 / 4825
# Match IDs processed this run: 218 / 4825 | overall: 218 / 4825
# Match IDs processed this run: 219 / 4825 | overall: 219 / 4825
# Match IDs processed this run: 220 / 4825 | overall: 220 / 4825
# Match IDs processed this run: 221 / 4825 | overall: 221 / 4825
# Match IDs processed this run: 222 / 4825 | overall: 222 / 4825
# Match IDs processed this run: 223 / 4825 | overall: 223 / 4825
# Match IDs processed this run: 224 / 4825 | overall: 224 / 4825
# Match IDs processed this run: 225 / 4825 | overall: 225 / 4825
# Match IDs processed this run: 226 / 4825 | overall: 226 / 4825
# Match IDs processed this run: 227 / 4825 | overall: 227 / 4825
# Match IDs processed this run: 228 / 4825 | overall: 228 / 4825
# Match IDs processed this run: 229 / 4825 | overall: 229 / 4825
# Match IDs processed this run: 230 / 4825 | overall: 230 / 4825
# Match IDs processed this run: 231 / 4825 | overall: 231 / 4825
# Match IDs processed this run: 232 / 4825 | overall: 232 / 4825
# Match IDs processed this run: 233 / 4825 | overall: 233 / 4825
# Match IDs processed this run: 234 / 4825 | overall: 234 / 4825
# Match IDs processed this run: 235 / 4825 | overall: 235 / 4825
# Match IDs processed this run: 236 / 4825 | overall: 236 / 4825
# Match IDs processed this run: 237 / 4825 | overall: 237 / 4825
# Match IDs processed this run: 238 / 4825 | overall: 238 / 4825
# Match IDs processed this run: 239 / 4825 | overall: 239 / 4825
# Match IDs processed this run: 240 / 4825 | overall: 240 / 4825
# Match IDs processed this run: 241 / 4825 | overall: 241 / 4825
# Match IDs processed this run: 242 / 4825 | overall: 242 / 4825
# Match IDs processed this run: 243 / 4825 | overall: 243 / 4825
# Match IDs processed this run: 244 / 4825 | overall: 244 / 4825
# Match IDs processed this run: 245 / 4825 | overall: 245 / 4825
# Match IDs processed this run: 246 / 4825 | overall: 246 / 4825
# Match IDs processed this run: 247 / 4825 | overall: 247 / 4825
# Match IDs processed this run: 248 / 4825 | overall: 248 / 4825
# Match IDs processed this run: 249 / 4825 | overall: 249 / 4825
# Match IDs processed this run: 250 / 4825 | overall: 250 / 4825
# Match IDs processed this run: 251 / 4825 | overall: 251 / 4825
# Match IDs processed this run: 252 / 4825 | overall: 252 / 4825
# Match IDs processed this run: 253 / 4825 | overall: 253 / 4825
# Match IDs processed this run: 254 / 4825 | overall: 254 / 4825
# Match IDs processed this run: 255 / 4825 | overall: 255 / 4825
# Match IDs processed this run: 256 / 4825 | overall: 256 / 4825
# Match IDs processed this run: 257 / 4825 | overall: 257 / 4825
# Match IDs processed this run: 258 / 4825 | overall: 258 / 4825
# Match IDs processed this run: 259 / 4825 | overall: 259 / 4825
# Match IDs processed this run: 260 / 4825 | overall: 260 / 4825
# Match IDs processed this run: 261 / 4825 | overall: 261 / 4825
# Match IDs processed this run: 262 / 4825 | overall: 262 / 4825
# Match IDs processed this run: 263 / 4825 | overall: 263 / 4825
# Match IDs processed this run: 264 / 4825 | overall: 264 / 4825
# Match IDs processed this run: 265 / 4825 | overall: 265 / 4825
# Match IDs processed this run: 266 / 4825 | overall: 266 / 4825
# Match IDs processed this run: 267 / 4825 | overall: 267 / 4825
# Match IDs processed this run: 268 / 4825 | overall: 268 / 4825
# Match IDs processed this run: 269 / 4825 | overall: 269 / 4825
# Match IDs processed this run: 270 / 4825 | overall: 270 / 4825
# Match IDs processed this run: 271 / 4825 | overall: 271 / 4825
# Match IDs processed this run: 272 / 4825 | overall: 272 / 4825
# Match IDs processed this run: 273 / 4825 | overall: 273 / 4825
# Match IDs processed this run: 274 / 4825 | overall: 274 / 4825
# Match IDs processed this run: 275 / 4825 | overall: 275 / 4825
# Match IDs processed this run: 276 / 4825 | overall: 276 / 4825
# Match IDs processed this run: 277 / 4825 | overall: 277 / 4825
# Match IDs processed this run: 278 / 4825 | overall: 278 / 4825
# Match IDs processed this run: 279 / 4825 | overall: 279 / 4825
# Match IDs processed this run: 280 / 4825 | overall: 280 / 4825
# Match IDs processed this run: 281 / 4825 | overall: 281 / 4825
# Match IDs processed this run: 282 / 4825 | overall: 282 / 4825
# Match IDs processed this run: 283 / 4825 | overall: 283 / 4825
# Match IDs processed this run: 284 / 4825 | overall: 284 / 4825
# Match IDs processed this run: 285 / 4825 | overall: 285 / 4825
# Match IDs processed this run: 286 / 4825 | overall: 286 / 4825
# Match IDs processed this run: 287 / 4825 | overall: 287 / 4825
# Match IDs processed this run: 288 / 4825 | overall: 288 / 4825
# Match IDs processed this run: 289 / 4825 | overall: 289 / 4825
# Match IDs processed this run: 290 / 4825 | overall: 290 / 4825
# Match IDs processed this run: 291 / 4825 | overall: 291 / 4825
# Match IDs processed this run: 292 / 4825 | overall: 292 / 4825
# Match IDs processed this run: 293 / 4825 | overall: 293 / 4825
# Match IDs processed this run: 294 / 4825 | overall: 294 / 4825
# Match IDs processed this run: 295 / 4825 | overall: 295 / 4825
# Match IDs processed this run: 296 / 4825 | overall: 296 / 4825
# Match IDs processed this run: 297 / 4825 | overall: 297 / 4825
# Match IDs processed this run: 298 / 4825 | overall: 298 / 4825
# Match IDs processed this run: 299 / 4825 | overall: 299 / 4825
# Match IDs processed this run: 300 / 4825 | overall: 300 / 4825
# Match IDs processed this run: 301 / 4825 | overall: 301 / 4825
# Match IDs processed this run: 302 / 4825 | overall: 302 / 4825
# Match IDs processed this run: 303 / 4825 | overall: 303 / 4825
# Match IDs processed this run: 304 / 4825 | overall: 304 / 4825
# Match IDs processed this run: 305 / 4825 | overall: 305 / 4825
# Match IDs processed this run: 306 / 4825 | overall: 306 / 4825
# Match IDs processed this run: 307 / 4825 | overall: 307 / 4825
# Match IDs processed this run: 308 / 4825 | overall: 308 / 4825
# Match IDs processed this run: 309 / 4825 | overall: 309 / 4825
# Match IDs processed this run: 310 / 4825 | overall: 310 / 4825
# Match IDs processed this run: 311 / 4825 | overall: 311 / 4825
# Match IDs processed this run: 312 / 4825 | overall: 312 / 4825
# Match IDs processed this run: 313 / 4825 | overall: 313 / 4825
# Match IDs processed this run: 314 / 4825 | overall: 314 / 4825
# Match IDs processed this run: 315 / 4825 | overall: 315 / 4825
# Match IDs processed this run: 316 / 4825 | overall: 316 / 4825
# Match IDs processed this run: 317 / 4825 | overall: 317 / 4825
# Match IDs processed this run: 318 / 4825 | overall: 318 / 4825
# Match IDs processed this run: 319 / 4825 | overall: 319 / 4825
# Match IDs processed this run: 320 / 4825 | overall: 320 / 4825
# Match IDs processed this run: 321 / 4825 | overall: 321 / 4825
# Match IDs processed this run: 322 / 4825 | overall: 322 / 4825
# Match IDs processed this run: 323 / 4825 | overall: 323 / 4825
# Match IDs processed this run: 324 / 4825 | overall: 324 / 4825
# Match IDs processed this run: 325 / 4825 | overall: 325 / 4825
# Match IDs processed this run: 326 / 4825 | overall: 326 / 4825
# Match IDs processed this run: 327 / 4825 | overall: 327 / 4825
# Match IDs processed this run: 328 / 4825 | overall: 328 / 4825
# Match IDs processed this run: 329 / 4825 | overall: 329 / 4825
# Match IDs processed this run: 330 / 4825 | overall: 330 / 4825
# Match IDs processed this run: 331 / 4825 | overall: 331 / 4825
# Match IDs processed this run: 332 / 4825 | overall: 332 / 4825
# Match IDs processed this run: 333 / 4825 | overall: 333 / 4825
# Match IDs processed this run: 334 / 4825 | overall: 334 / 4825
# Match IDs processed this run: 335 / 4825 | overall: 335 / 4825
# Match IDs processed this run: 336 / 4825 | overall: 336 / 4825
# Match IDs processed this run: 337 / 4825 | overall: 337 / 4825
# Match IDs processed this run: 338 / 4825 | overall: 338 / 4825
# Match IDs processed this run: 339 / 4825 | overall: 339 / 4825
# Match IDs processed this run: 340 / 4825 | overall: 340 / 4825
# Match IDs processed this run: 341 / 4825 | overall: 341 / 4825
# Match IDs processed this run: 342 / 4825 | overall: 342 / 4825
# Match IDs processed this run: 343 / 4825 | overall: 343 / 4825
# Match IDs processed this run: 344 / 4825 | overall: 344 / 4825
# Match IDs processed this run: 345 / 4825 | overall: 345 / 4825
# Match IDs processed this run: 346 / 4825 | overall: 346 / 4825
# Match IDs processed this run: 347 / 4825 | overall: 347 / 4825
# Match IDs processed this run: 348 / 4825 | overall: 348 / 4825
# Match IDs processed this run: 349 / 4825 | overall: 349 / 4825
# Match IDs processed this run: 350 / 4825 | overall: 350 / 4825
# Match IDs processed this run: 351 / 4825 | overall: 351 / 4825
# Match IDs processed this run: 352 / 4825 | overall: 352 / 4825
# Match IDs processed this run: 353 / 4825 | overall: 353 / 4825
# Match IDs processed this run: 354 / 4825 | overall: 354 / 4825
# Match IDs processed this run: 355 / 4825 | overall: 355 / 4825
# Match IDs processed this run: 356 / 4825 | overall: 356 / 4825
# Match IDs processed this run: 357 / 4825 | overall: 357 / 4825
# Match IDs processed this run: 358 / 4825 | overall: 358 / 4825
# Match IDs processed this run: 359 / 4825 | overall: 359 / 4825
# Match IDs processed this run: 360 / 4825 | overall: 360 / 4825
# Match IDs processed this run: 361 / 4825 | overall: 361 / 4825
# Match IDs processed this run: 362 / 4825 | overall: 362 / 4825
# Match IDs processed this run: 363 / 4825 | overall: 363 / 4825
# Match IDs processed this run: 364 / 4825 | overall: 364 / 4825
# Match IDs processed this run: 365 / 4825 | overall: 365 / 4825
# Match IDs processed this run: 366 / 4825 | overall: 366 / 4825
# Match IDs processed this run: 367 / 4825 | overall: 367 / 4825
# Match IDs processed this run: 368 / 4825 | overall: 368 / 4825
# Match IDs processed this run: 369 / 4825 | overall: 369 / 4825
# Match IDs processed this run: 370 / 4825 | overall: 370 / 4825
# Match IDs processed this run: 371 / 4825 | overall: 371 / 4825
# Match IDs processed this run: 372 / 4825 | overall: 372 / 4825
# Match IDs processed this run: 373 / 4825 | overall: 373 / 4825
# Match IDs processed this run: 374 / 4825 | overall: 374 / 4825
# Match IDs processed this run: 375 / 4825 | overall: 375 / 4825
# Match IDs processed this run: 376 / 4825 | overall: 376 / 4825
# Match IDs processed this run: 377 / 4825 | overall: 377 / 4825
# Match IDs processed this run: 378 / 4825 | overall: 378 / 4825
# Match IDs processed this run: 379 / 4825 | overall: 379 / 4825
# Match IDs processed this run: 380 / 4825 | overall: 380 / 4825
# Match IDs processed this run: 381 / 4825 | overall: 381 / 4825
# Match IDs processed this run: 382 / 4825 | overall: 382 / 4825
# Match IDs processed this run: 383 / 4825 | overall: 383 / 4825
# Match IDs processed this run: 384 / 4825 | overall: 384 / 4825
# Match IDs processed this run: 385 / 4825 | overall: 385 / 4825
# Match IDs processed this run: 386 / 4825 | overall: 386 / 4825
# Match IDs processed this run: 387 / 4825 | overall: 387 / 4825
# Match IDs processed this run: 388 / 4825 | overall: 388 / 4825
# Match IDs processed this run: 389 / 4825 | overall: 389 / 4825
# Match IDs processed this run: 390 / 4825 | overall: 390 / 4825
# Match IDs processed this run: 391 / 4825 | overall: 391 / 4825
# Match IDs processed this run: 392 / 4825 | overall: 392 / 4825
# Match IDs processed this run: 393 / 4825 | overall: 393 / 4825
# Match IDs processed this run: 394 / 4825 | overall: 394 / 4825
# Match IDs processed this run: 395 / 4825 | overall: 395 / 4825
# Match IDs processed this run: 396 / 4825 | overall: 396 / 4825
# Match IDs processed this run: 397 / 4825 | overall: 397 / 4825
# Match IDs processed this run: 398 / 4825 | overall: 398 / 4825
# Match IDs processed this run: 399 / 4825 | overall: 399 / 4825
# Match IDs processed this run: 400 / 4825 | overall: 400 / 4825
# Match IDs processed this run: 401 / 4825 | overall: 401 / 4825
# Match IDs processed this run: 402 / 4825 | overall: 402 / 4825
# Match IDs processed this run: 403 / 4825 | overall: 403 / 4825
# Match IDs processed this run: 404 / 4825 | overall: 404 / 4825
# Match IDs processed this run: 405 / 4825 | overall: 405 / 4825
# Match IDs processed this run: 406 / 4825 | overall: 406 / 4825
# Match IDs processed this run: 407 / 4825 | overall: 407 / 4825
# Match IDs processed this run: 408 / 4825 | overall: 408 / 4825
# Match IDs processed this run: 409 / 4825 | overall: 409 / 4825
# Match IDs processed this run: 410 / 4825 | overall: 410 / 4825
# Match IDs processed this run: 411 / 4825 | overall: 411 / 4825
# Match IDs processed this run: 412 / 4825 | overall: 412 / 4825
# Match IDs processed this run: 413 / 4825 | overall: 413 / 4825
# Match IDs processed this run: 414 / 4825 | overall: 414 / 4825
# Match IDs processed this run: 415 / 4825 | overall: 415 / 4825
# Match IDs processed this run: 416 / 4825 | overall: 416 / 4825
# Match IDs processed this run: 417 / 4825 | overall: 417 / 4825
# Match IDs processed this run: 418 / 4825 | overall: 418 / 4825
# Match IDs processed this run: 419 / 4825 | overall: 419 / 4825
# Match IDs processed this run: 420 / 4825 | overall: 420 / 4825
# Match IDs processed this run: 421 / 4825 | overall: 421 / 4825
# Match IDs processed this run: 422 / 4825 | overall: 422 / 4825
# Match IDs processed this run: 423 / 4825 | overall: 423 / 4825
# Match IDs processed this run: 424 / 4825 | overall: 424 / 4825
# Match IDs processed this run: 425 / 4825 | overall: 425 / 4825
# Match IDs processed this run: 426 / 4825 | overall: 426 / 4825
# Match IDs processed this run: 427 / 4825 | overall: 427 / 4825
# Match IDs processed this run: 428 / 4825 | overall: 428 / 4825
# Match IDs processed this run: 429 / 4825 | overall: 429 / 4825
# Match IDs processed this run: 430 / 4825 | overall: 430 / 4825
# Match IDs processed this run: 431 / 4825 | overall: 431 / 4825
# Match IDs processed this run: 432 / 4825 | overall: 432 / 4825
# Match IDs processed this run: 433 / 4825 | overall: 433 / 4825
# Match IDs processed this run: 434 / 4825 | overall: 434 / 4825
# Match IDs processed this run: 435 / 4825 | overall: 435 / 4825
# Match IDs processed this run: 436 / 4825 | overall: 436 / 4825
# Match IDs processed this run: 437 / 4825 | overall: 437 / 4825
# Match IDs processed this run: 438 / 4825 | overall: 438 / 4825
# Match IDs processed this run: 439 / 4825 | overall: 439 / 4825
# Match IDs processed this run: 440 / 4825 | overall: 440 / 4825
# Match IDs processed this run: 441 / 4825 | overall: 441 / 4825
# Match IDs processed this run: 442 / 4825 | overall: 442 / 4825
# Match IDs processed this run: 443 / 4825 | overall: 443 / 4825
# Match IDs processed this run: 444 / 4825 | overall: 444 / 4825
# Match IDs processed this run: 445 / 4825 | overall: 445 / 4825
# Match IDs processed this run: 446 / 4825 | overall: 446 / 4825
# Match IDs processed this run: 447 / 4825 | overall: 447 / 4825
# Match IDs processed this run: 448 / 4825 | overall: 448 / 4825
# Match IDs processed this run: 449 / 4825 | overall: 449 / 4825
# Match IDs processed this run: 450 / 4825 | overall: 450 / 4825
# Match IDs processed this run: 451 / 4825 | overall: 451 / 4825
# Match IDs processed this run: 452 / 4825 | overall: 452 / 4825
# Match IDs processed this run: 453 / 4825 | overall: 453 / 4825
# Match IDs processed this run: 454 / 4825 | overall: 454 / 4825
# Match IDs processed this run: 455 / 4825 | overall: 455 / 4825
# Match IDs processed this run: 456 / 4825 | overall: 456 / 4825
# Match IDs processed this run: 457 / 4825 | overall: 457 / 4825
# Match IDs processed this run: 458 / 4825 | overall: 458 / 4825
# Match IDs processed this run: 459 / 4825 | overall: 459 / 4825
# Match IDs processed this run: 460 / 4825 | overall: 460 / 4825
# Match IDs processed this run: 461 / 4825 | overall: 461 / 4825
# Match IDs processed this run: 462 / 4825 | overall: 462 / 4825
# Match IDs processed this run: 463 / 4825 | overall: 463 / 4825
# Match IDs processed this run: 464 / 4825 | overall: 464 / 4825
# Match IDs processed this run: 465 / 4825 | overall: 465 / 4825
# Match IDs processed this run: 466 / 4825 | overall: 466 / 4825
# Match IDs processed this run: 467 / 4825 | overall: 467 / 4825
# Match IDs processed this run: 468 / 4825 | overall: 468 / 4825
# Match IDs processed this run: 469 / 4825 | overall: 469 / 4825
# Match IDs processed this run: 470 / 4825 | overall: 470 / 4825
# Match IDs processed this run: 471 / 4825 | overall: 471 / 4825
# Match IDs processed this run: 472 / 4825 | overall: 472 / 4825
# Match IDs processed this run: 473 / 4825 | overall: 473 / 4825
# Match IDs processed this run: 474 / 4825 | overall: 474 / 4825
# Match IDs processed this run: 475 / 4825 | overall: 475 / 4825
# Match IDs processed this run: 476 / 4825 | overall: 476 / 4825
# Match IDs processed this run: 477 / 4825 | overall: 477 / 4825
# Match IDs processed this run: 478 / 4825 | overall: 478 / 4825
# Match IDs processed this run: 479 / 4825 | overall: 479 / 4825
# Match IDs processed this run: 480 / 4825 | overall: 480 / 4825
# Match IDs processed this run: 481 / 4825 | overall: 481 / 4825
# Match IDs processed this run: 482 / 4825 | overall: 482 / 4825
# Match IDs processed this run: 483 / 4825 | overall: 483 / 4825
# Match IDs processed this run: 484 / 4825 | overall: 484 / 4825
# Match IDs processed this run: 485 / 4825 | overall: 485 / 4825
# Match IDs processed this run: 486 / 4825 | overall: 486 / 4825
# Match IDs processed this run: 487 / 4825 | overall: 487 / 4825
# Match IDs processed this run: 488 / 4825 | overall: 488 / 4825
# Match IDs processed this run: 489 / 4825 | overall: 489 / 4825
# Match IDs processed this run: 490 / 4825 | overall: 490 / 4825
# Match IDs processed this run: 491 / 4825 | overall: 491 / 4825
# Match IDs processed this run: 492 / 4825 | overall: 492 / 4825
# Match IDs processed this run: 493 / 4825 | overall: 493 / 4825
# Match IDs processed this run: 494 / 4825 | overall: 494 / 4825
# Match IDs processed this run: 495 / 4825 | overall: 495 / 4825
# Match IDs processed this run: 496 / 4825 | overall: 496 / 4825
# Match IDs processed this run: 497 / 4825 | overall: 497 / 4825
# Match IDs processed this run: 498 / 4825 | overall: 498 / 4825
# Match IDs processed this run: 499 / 4825 | overall: 499 / 4825
# Match IDs processed this run: 500 / 4825 | overall: 500 / 4825
# Match IDs processed this run: 501 / 4825 | overall: 501 / 4825
# Match IDs processed this run: 502 / 4825 | overall: 502 / 4825
# Match IDs processed this run: 503 / 4825 | overall: 503 / 4825
# Match IDs processed this run: 504 / 4825 | overall: 504 / 4825
# Match IDs processed this run: 505 / 4825 | overall: 505 / 4825
# Match IDs processed this run: 506 / 4825 | overall: 506 / 4825
# Match IDs processed this run: 507 / 4825 | overall: 507 / 4825
# Match IDs processed this run: 508 / 4825 | overall: 508 / 4825
# Match IDs processed this run: 509 / 4825 | overall: 509 / 4825
# Match IDs processed this run: 510 / 4825 | overall: 510 / 4825
# Match IDs processed this run: 511 / 4825 | overall: 511 / 4825
# Match IDs processed this run: 512 / 4825 | overall: 512 / 4825
# Match IDs processed this run: 513 / 4825 | overall: 513 / 4825
# Match IDs processed this run: 514 / 4825 | overall: 514 / 4825
# Match IDs processed this run: 515 / 4825 | overall: 515 / 4825
# Match IDs processed this run: 516 / 4825 | overall: 516 / 4825
# Match IDs processed this run: 517 / 4825 | overall: 517 / 4825
# Match IDs processed this run: 518 / 4825 | overall: 518 / 4825
# Match IDs processed this run: 519 / 4825 | overall: 519 / 4825
# Match IDs processed this run: 520 / 4825 | overall: 520 / 4825
# Match IDs processed this run: 521 / 4825 | overall: 521 / 4825
# Match IDs processed this run: 522 / 4825 | overall: 522 / 4825
# Match IDs processed this run: 523 / 4825 | overall: 523 / 4825
# Match IDs processed this run: 524 / 4825 | overall: 524 / 4825
# Match IDs processed this run: 525 / 4825 | overall: 525 / 4825
# Match IDs processed this run: 526 / 4825 | overall: 526 / 4825
# Match IDs processed this run: 527 / 4825 | overall: 527 / 4825
# Match IDs processed this run: 528 / 4825 | overall: 528 / 4825
# Match IDs processed this run: 529 / 4825 | overall: 529 / 4825
# Match IDs processed this run: 530 / 4825 | overall: 530 / 4825
# Match IDs processed this run: 531 / 4825 | overall: 531 / 4825
# Match IDs processed this run: 532 / 4825 | overall: 532 / 4825
# Match IDs processed this run: 533 / 4825 | overall: 533 / 4825
# Match IDs processed this run: 534 / 4825 | overall: 534 / 4825
# Match IDs processed this run: 535 / 4825 | overall: 535 / 4825
# Match IDs processed this run: 536 / 4825 | overall: 536 / 4825
# Match IDs processed this run: 537 / 4825 | overall: 537 / 4825
# Match IDs processed this run: 538 / 4825 | overall: 538 / 4825
# Match IDs processed this run: 539 / 4825 | overall: 539 / 4825
# Match IDs processed this run: 540 / 4825 | overall: 540 / 4825
# Match IDs processed this run: 541 / 4825 | overall: 541 / 4825
# Match IDs processed this run: 542 / 4825 | overall: 542 / 4825
# Match IDs processed this run: 543 / 4825 | overall: 543 / 4825
# Match IDs processed this run: 544 / 4825 | overall: 544 / 4825
# Match IDs processed this run: 545 / 4825 | overall: 545 / 4825
# Match IDs processed this run: 546 / 4825 | overall: 546 / 4825
# Match IDs processed this run: 547 / 4825 | overall: 547 / 4825
# Match IDs processed this run: 548 / 4825 | overall: 548 / 4825
# Match IDs processed this run: 549 / 4825 | overall: 549 / 4825
# Match IDs processed this run: 550 / 4825 | overall: 550 / 4825
# Match IDs processed this run: 551 / 4825 | overall: 551 / 4825
# Match IDs processed this run: 552 / 4825 | overall: 552 / 4825
# Match IDs processed this run: 553 / 4825 | overall: 553 / 4825
# Match IDs processed this run: 554 / 4825 | overall: 554 / 4825
# Match IDs processed this run: 555 / 4825 | overall: 555 / 4825
# Match IDs processed this run: 556 / 4825 | overall: 556 / 4825
# Match IDs processed this run: 557 / 4825 | overall: 557 / 4825
# Match IDs processed this run: 558 / 4825 | overall: 558 / 4825
# Match IDs processed this run: 559 / 4825 | overall: 559 / 4825
# Match IDs processed this run: 560 / 4825 | overall: 560 / 4825
# Match IDs processed this run: 561 / 4825 | overall: 561 / 4825
# Match IDs processed this run: 562 / 4825 | overall: 562 / 4825
# Match IDs processed this run: 563 / 4825 | overall: 563 / 4825
# Match IDs processed this run: 564 / 4825 | overall: 564 / 4825
# Match IDs processed this run: 565 / 4825 | overall: 565 / 4825
# Match IDs processed this run: 566 / 4825 | overall: 566 / 4825
# Match IDs processed this run: 567 / 4825 | overall: 567 / 4825
# Match IDs processed this run: 568 / 4825 | overall: 568 / 4825
# Match IDs processed this run: 569 / 4825 | overall: 569 / 4825
# Match IDs processed this run: 570 / 4825 | overall: 570 / 4825
# Match IDs processed this run: 571 / 4825 | overall: 571 / 4825
# Match IDs processed this run: 572 / 4825 | overall: 572 / 4825
# Match IDs processed this run: 573 / 4825 | overall: 573 / 4825
# Match IDs processed this run: 574 / 4825 | overall: 574 / 4825
# Match IDs processed this run: 575 / 4825 | overall: 575 / 4825
# Match IDs processed this run: 576 / 4825 | overall: 576 / 4825
# Match IDs processed this run: 577 / 4825 | overall: 577 / 4825
# Match IDs processed this run: 578 / 4825 | overall: 578 / 4825
# Match IDs processed this run: 579 / 4825 | overall: 579 / 4825
# Match IDs processed this run: 580 / 4825 | overall: 580 / 4825
# Match IDs processed this run: 581 / 4825 | overall: 581 / 4825
# Match IDs processed this run: 582 / 4825 | overall: 582 / 4825
# Match IDs processed this run: 583 / 4825 | overall: 583 / 4825
# Match IDs processed this run: 584 / 4825 | overall: 584 / 4825
# Match IDs processed this run: 585 / 4825 | overall: 585 / 4825
# Match IDs processed this run: 586 / 4825 | overall: 586 / 4825
# Match IDs processed this run: 587 / 4825 | overall: 587 / 4825
# Match IDs processed this run: 588 / 4825 | overall: 588 / 4825
# Match IDs processed this run: 589 / 4825 | overall: 589 / 4825
# Match IDs processed this run: 590 / 4825 | overall: 590 / 4825
# Match IDs processed this run: 591 / 4825 | overall: 591 / 4825
# Match IDs processed this run: 592 / 4825 | overall: 592 / 4825
# Match IDs processed this run: 593 / 4825 | overall: 593 / 4825
# Match IDs processed this run: 594 / 4825 | overall: 594 / 4825
# Match IDs processed this run: 595 / 4825 | overall: 595 / 4825
# Match IDs processed this run: 596 / 4825 | overall: 596 / 4825
# Match IDs processed this run: 597 / 4825 | overall: 597 / 4825
# Match IDs processed this run: 598 / 4825 | overall: 598 / 4825
# Match IDs processed this run: 599 / 4825 | overall: 599 / 4825
# Match IDs processed this run: 600 / 4825 | overall: 600 / 4825
# Match IDs processed this run: 601 / 4825 | overall: 601 / 4825
# Match IDs processed this run: 602 / 4825 | overall: 602 / 4825
# Match IDs processed this run: 603 / 4825 | overall: 603 / 4825
# Match IDs processed this run: 604 / 4825 | overall: 604 / 4825
# Match IDs processed this run: 605 / 4825 | overall: 605 / 4825
# Match IDs processed this run: 606 / 4825 | overall: 606 / 4825
# Match IDs processed this run: 607 / 4825 | overall: 607 / 4825
# Match IDs processed this run: 608 / 4825 | overall: 608 / 4825
# Match IDs processed this run: 609 / 4825 | overall: 609 / 4825
# Match IDs processed this run: 610 / 4825 | overall: 610 / 4825
# Match IDs processed this run: 611 / 4825 | overall: 611 / 4825
# Match IDs processed this run: 612 / 4825 | overall: 612 / 4825
# Match IDs processed this run: 613 / 4825 | overall: 613 / 4825
# Match IDs processed this run: 614 / 4825 | overall: 614 / 4825
# Match IDs processed this run: 615 / 4825 | overall: 615 / 4825
# Match IDs processed this run: 616 / 4825 | overall: 616 / 4825
# Match IDs processed this run: 617 / 4825 | overall: 617 / 4825
# Match IDs processed this run: 618 / 4825 | overall: 618 / 4825
# Match IDs processed this run: 619 / 4825 | overall: 619 / 4825
# Match IDs processed this run: 620 / 4825 | overall: 620 / 4825
# Match IDs processed this run: 621 / 4825 | overall: 621 / 4825
# Match IDs processed this run: 622 / 4825 | overall: 622 / 4825
# Match IDs processed this run: 623 / 4825 | overall: 623 / 4825
# Match IDs processed this run: 624 / 4825 | overall: 624 / 4825
# Match IDs processed this run: 625 / 4825 | overall: 625 / 4825
# Match IDs processed this run: 626 / 4825 | overall: 626 / 4825
# Match IDs processed this run: 627 / 4825 | overall: 627 / 4825
# Match IDs processed this run: 628 / 4825 | overall: 628 / 4825
# Match IDs processed this run: 629 / 4825 | overall: 629 / 4825
# Match IDs processed this run: 630 / 4825 | overall: 630 / 4825
# Match IDs processed this run: 631 / 4825 | overall: 631 / 4825
# Match IDs processed this run: 632 / 4825 | overall: 632 / 4825
# Match IDs processed this run: 633 / 4825 | overall: 633 / 4825
# Match IDs processed this run: 634 / 4825 | overall: 634 / 4825
# Match IDs processed this run: 635 / 4825 | overall: 635 / 4825
# Match IDs processed this run: 636 / 4825 | overall: 636 / 4825
# Match IDs processed this run: 637 / 4825 | overall: 637 / 4825
# Match IDs processed this run: 638 / 4825 | overall: 638 / 4825
# Match IDs processed this run: 639 / 4825 | overall: 639 / 4825
# Match IDs processed this run: 640 / 4825 | overall: 640 / 4825
# Match IDs processed this run: 641 / 4825 | overall: 641 / 4825
# Match IDs processed this run: 642 / 4825 | overall: 642 / 4825
# Match IDs processed this run: 643 / 4825 | overall: 643 / 4825
# Match IDs processed this run: 644 / 4825 | overall: 644 / 4825
# Match IDs processed this run: 645 / 4825 | overall: 645 / 4825
# Match IDs processed this run: 646 / 4825 | overall: 646 / 4825
# Match IDs processed this run: 647 / 4825 | overall: 647 / 4825
# Match IDs processed this run: 648 / 4825 | overall: 648 / 4825
# Match IDs processed this run: 649 / 4825 | overall: 649 / 4825
# Match IDs processed this run: 650 / 4825 | overall: 650 / 4825
# Match IDs processed this run: 651 / 4825 | overall: 651 / 4825
# Match IDs processed this run: 652 / 4825 | overall: 652 / 4825
# Match IDs processed this run: 653 / 4825 | overall: 653 / 4825
# Match IDs processed this run: 654 / 4825 | overall: 654 / 4825
# Match IDs processed this run: 655 / 4825 | overall: 655 / 4825
# Match IDs processed this run: 656 / 4825 | overall: 656 / 4825
# Match IDs processed this run: 657 / 4825 | overall: 657 / 4825
# Match IDs processed this run: 658 / 4825 | overall: 658 / 4825
# Match IDs processed this run: 659 / 4825 | overall: 659 / 4825
# Match IDs processed this run: 660 / 4825 | overall: 660 / 4825
# Match IDs processed this run: 661 / 4825 | overall: 661 / 4825
# Match IDs processed this run: 662 / 4825 | overall: 662 / 4825
# Match IDs processed this run: 663 / 4825 | overall: 663 / 4825
# Match IDs processed this run: 664 / 4825 | overall: 664 / 4825
# Match IDs processed this run: 665 / 4825 | overall: 665 / 4825
# Match IDs processed this run: 666 / 4825 | overall: 666 / 4825
# Match IDs processed this run: 667 / 4825 | overall: 667 / 4825
# Match IDs processed this run: 668 / 4825 | overall: 668 / 4825
# Match IDs processed this run: 669 / 4825 | overall: 669 / 4825
# Match IDs processed this run: 670 / 4825 | overall: 670 / 4825
# Match IDs processed this run: 671 / 4825 | overall: 671 / 4825
# Match IDs processed this run: 672 / 4825 | overall: 672 / 4825
# Match IDs processed this run: 673 / 4825 | overall: 673 / 4825
# Match IDs processed this run: 674 / 4825 | overall: 674 / 4825
# Match IDs processed this run: 675 / 4825 | overall: 675 / 4825
# Match IDs processed this run: 676 / 4825 | overall: 676 / 4825
# Match IDs processed this run: 677 / 4825 | overall: 677 / 4825
# Match IDs processed this run: 678 / 4825 | overall: 678 / 4825
# Match IDs processed this run: 679 / 4825 | overall: 679 / 4825
# Match IDs processed this run: 680 / 4825 | overall: 680 / 4825
# Match IDs processed this run: 681 / 4825 | overall: 681 / 4825
# Match IDs processed this run: 682 / 4825 | overall: 682 / 4825
# Match IDs processed this run: 683 / 4825 | overall: 683 / 4825
# Match IDs processed this run: 684 / 4825 | overall: 684 / 4825
# Match IDs processed this run: 685 / 4825 | overall: 685 / 4825
# Match IDs processed this run: 686 / 4825 | overall: 686 / 4825
# Match IDs processed this run: 687 / 4825 | overall: 687 / 4825
# Match IDs processed this run: 688 / 4825 | overall: 688 / 4825
# Match IDs processed this run: 689 / 4825 | overall: 689 / 4825
# Match IDs processed this run: 690 / 4825 | overall: 690 / 4825
# Match IDs processed this run: 691 / 4825 | overall: 691 / 4825
# Match IDs processed this run: 692 / 4825 | overall: 692 / 4825
# Match IDs processed this run: 693 / 4825 | overall: 693 / 4825
# Match IDs processed this run: 694 / 4825 | overall: 694 / 4825
# Match IDs processed this run: 695 / 4825 | overall: 695 / 4825
# Match IDs processed this run: 696 / 4825 | overall: 696 / 4825
# Match IDs processed this run: 697 / 4825 | overall: 697 / 4825
# Match IDs processed this run: 698 / 4825 | overall: 698 / 4825
# Match IDs processed this run: 699 / 4825 | overall: 699 / 4825
# Match IDs processed this run: 700 / 4825 | overall: 700 / 4825
# Match IDs processed this run: 701 / 4825 | overall: 701 / 4825
# Match IDs processed this run: 702 / 4825 | overall: 702 / 4825
# Match IDs processed this run: 703 / 4825 | overall: 703 / 4825
# Match IDs processed this run: 704 / 4825 | overall: 704 / 4825
# Match IDs processed this run: 705 / 4825 | overall: 705 / 4825
# Match IDs processed this run: 706 / 4825 | overall: 706 / 4825
# Match IDs processed this run: 707 / 4825 | overall: 707 / 4825
# Match IDs processed this run: 708 / 4825 | overall: 708 / 4825
# Match IDs processed this run: 709 / 4825 | overall: 709 / 4825
# Match IDs processed this run: 710 / 4825 | overall: 710 / 4825
# Match IDs processed this run: 711 / 4825 | overall: 711 / 4825
# Match IDs processed this run: 712 / 4825 | overall: 712 / 4825
# Match IDs processed this run: 713 / 4825 | overall: 713 / 4825
# Match IDs processed this run: 714 / 4825 | overall: 714 / 4825
# Match IDs processed this run: 715 / 4825 | overall: 715 / 4825
# Match IDs processed this run: 716 / 4825 | overall: 716 / 4825
# Match IDs processed this run: 717 / 4825 | overall: 717 / 4825
# Match IDs processed this run: 718 / 4825 | overall: 718 / 4825
# Match IDs processed this run: 719 / 4825 | overall: 719 / 4825
# Match IDs processed this run: 720 / 4825 | overall: 720 / 4825
# Match IDs processed this run: 721 / 4825 | overall: 721 / 4825
# Match IDs processed this run: 722 / 4825 | overall: 722 / 4825
# Match IDs processed this run: 723 / 4825 | overall: 723 / 4825
# Match IDs processed this run: 724 / 4825 | overall: 724 / 4825
# Match IDs processed this run: 725 / 4825 | overall: 725 / 4825
# Match IDs processed this run: 726 / 4825 | overall: 726 / 4825
# Match IDs processed this run: 727 / 4825 | overall: 727 / 4825
# Match IDs processed this run: 728 / 4825 | overall: 728 / 4825
# Match IDs processed this run: 729 / 4825 | overall: 729 / 4825
# Match IDs processed this run: 730 / 4825 | overall: 730 / 4825
# Match IDs processed this run: 731 / 4825 | overall: 731 / 4825
# Match IDs processed this run: 732 / 4825 | overall: 732 / 4825
# Match IDs processed this run: 733 / 4825 | overall: 733 / 4825
# Match IDs processed this run: 734 / 4825 | overall: 734 / 4825
# Match IDs processed this run: 735 / 4825 | overall: 735 / 4825
# Match IDs processed this run: 736 / 4825 | overall: 736 / 4825
# Match IDs processed this run: 737 / 4825 | overall: 737 / 4825
# Match IDs processed this run: 738 / 4825 | overall: 738 / 4825
# Match IDs processed this run: 739 / 4825 | overall: 739 / 4825
# Match IDs processed this run: 740 / 4825 | overall: 740 / 4825
# Match IDs processed this run: 741 / 4825 | overall: 741 / 4825
# Match IDs processed this run: 742 / 4825 | overall: 742 / 4825
# Match IDs processed this run: 743 / 4825 | overall: 743 / 4825
# Match IDs processed this run: 744 / 4825 | overall: 744 / 4825
# Match IDs processed this run: 745 / 4825 | overall: 745 / 4825
# Match IDs processed this run: 746 / 4825 | overall: 746 / 4825
# Match IDs processed this run: 747 / 4825 | overall: 747 / 4825
# Match IDs processed this run: 748 / 4825 | overall: 748 / 4825
# Match IDs processed this run: 749 / 4825 | overall: 749 / 4825
# Match IDs processed this run: 750 / 4825 | overall: 750 / 4825
# Match IDs processed this run: 751 / 4825 | overall: 751 / 4825
# Match IDs processed this run: 752 / 4825 | overall: 752 / 4825
# Match IDs processed this run: 753 / 4825 | overall: 753 / 4825
# Match IDs processed this run: 754 / 4825 | overall: 754 / 4825
# Match IDs processed this run: 755 / 4825 | overall: 755 / 4825
# Match IDs processed this run: 756 / 4825 | overall: 756 / 4825
# Match IDs processed this run: 757 / 4825 | overall: 757 / 4825
# Match IDs processed this run: 758 / 4825 | overall: 758 / 4825
# Match IDs processed this run: 759 / 4825 | overall: 759 / 4825
# Match IDs processed this run: 760 / 4825 | overall: 760 / 4825
# Match IDs processed this run: 761 / 4825 | overall: 761 / 4825
# ...
# Match IDs processed this run: 4582 / 4825 | overall: 4582 / 4825
# Match IDs processed this run: 4583 / 4825 | overall: 4583 / 4825
# Match IDs processed this run: 4584 / 4825 | overall: 4584 / 4825
# Match IDs processed this run: 4585 / 4825 | overall: 4585 / 4825
# Match IDs processed this run: 4586 / 4825 | overall: 4586 / 4825
# Match IDs processed this run: 4587 / 4825 | overall: 4587 / 4825
# Match IDs processed this run: 4588 / 4825 | overall: 4588 / 4825
# Match IDs processed this run: 4589 / 4825 | overall: 4589 / 4825
# Match IDs processed this run: 4590 / 4825 | overall: 4590 / 4825
# Match IDs processed this run: 4591 / 4825 | overall: 4591 / 4825
# Match IDs processed this run: 4592 / 4825 | overall: 4592 / 4825
# Match IDs processed this run: 4593 / 4825 | overall: 4593 / 4825
# Match IDs processed this run: 4594 / 4825 | overall: 4594 / 4825
# Match IDs processed this run: 4595 / 4825 | overall: 4595 / 4825
# Match IDs processed this run: 4596 / 4825 | overall: 4596 / 4825
# Match IDs processed this run: 4597 / 4825 | overall: 4597 / 4825
# Match IDs processed this run: 4598 / 4825 | overall: 4598 / 4825
# Match IDs processed this run: 4599 / 4825 | overall: 4599 / 4825
# Match IDs processed this run: 4600 / 4825 | overall: 4600 / 4825
# Match IDs processed this run: 4601 / 4825 | overall: 4601 / 4825
# Match IDs processed this run: 4602 / 4825 | overall: 4602 / 4825
# Match IDs processed this run: 4603 / 4825 | overall: 4603 / 4825
# Match IDs processed this run: 4604 / 4825 | overall: 4604 / 4825
# Match IDs processed this run: 4605 / 4825 | overall: 4605 / 4825
# Match IDs processed this run: 4606 / 4825 | overall: 4606 / 4825
# Match IDs processed this run: 4607 / 4825 | overall: 4607 / 4825
# Match IDs processed this run: 4608 / 4825 | overall: 4608 / 4825
# Match IDs processed this run: 4609 / 4825 | overall: 4609 / 4825
# Match IDs processed this run: 4610 / 4825 | overall: 4610 / 4825
# Match IDs processed this run: 4611 / 4825 | overall: 4611 / 4825
# Match IDs processed this run: 4612 / 4825 | overall: 4612 / 4825
# Match IDs processed this run: 4613 / 4825 | overall: 4613 / 4825
# Match IDs processed this run: 4614 / 4825 | overall: 4614 / 4825
# Match IDs processed this run: 4615 / 4825 | overall: 4615 / 4825
# Match IDs processed this run: 4616 / 4825 | overall: 4616 / 4825
# Match IDs processed this run: 4617 / 4825 | overall: 4617 / 4825
# Match IDs processed this run: 4618 / 4825 | overall: 4618 / 4825
# Match IDs processed this run: 4619 / 4825 | overall: 4619 / 4825
# Match IDs processed this run: 4620 / 4825 | overall: 4620 / 4825
# Match IDs processed this run: 4621 / 4825 | overall: 4621 / 4825
# Match IDs processed this run: 4622 / 4825 | overall: 4622 / 4825
# Match IDs processed this run: 4623 / 4825 | overall: 4623 / 4825
# Match IDs processed this run: 4624 / 4825 | overall: 4624 / 4825
# Match IDs processed this run: 4625 / 4825 | overall: 4625 / 4825
# Match IDs processed this run: 4626 / 4825 | overall: 4626 / 4825
# Match IDs processed this run: 4627 / 4825 | overall: 4627 / 4825
# Match IDs processed this run: 4628 / 4825 | overall: 4628 / 4825
# Match IDs processed this run: 4629 / 4825 | overall: 4629 / 4825
# Match IDs processed this run: 4630 / 4825 | overall: 4630 / 4825
# Match IDs processed this run: 4631 / 4825 | overall: 4631 / 4825
# Match IDs processed this run: 4632 / 4825 | overall: 4632 / 4825
# Match IDs processed this run: 4633 / 4825 | overall: 4633 / 4825
# Match IDs processed this run: 4634 / 4825 | overall: 4634 / 4825
# Match IDs processed this run: 4635 / 4825 | overall: 4635 / 4825
# Match IDs processed this run: 4636 / 4825 | overall: 4636 / 4825
# Match IDs processed this run: 4637 / 4825 | overall: 4637 / 4825
# Match IDs processed this run: 4638 / 4825 | overall: 4638 / 4825
# Match IDs processed this run: 4639 / 4825 | overall: 4639 / 4825
# Match IDs processed this run: 4640 / 4825 | overall: 4640 / 4825
# Match IDs processed this run: 4641 / 4825 | overall: 4641 / 4825
# Match IDs processed this run: 4642 / 4825 | overall: 4642 / 4825
# Match IDs processed this run: 4643 / 4825 | overall: 4643 / 4825
# Match IDs processed this run: 4644 / 4825 | overall: 4644 / 4825
# Match IDs processed this run: 4645 / 4825 | overall: 4645 / 4825
# Match IDs processed this run: 4646 / 4825 | overall: 4646 / 4825
# Match IDs processed this run: 4647 / 4825 | overall: 4647 / 4825
# Match IDs processed this run: 4648 / 4825 | overall: 4648 / 4825
# Match IDs processed this run: 4649 / 4825 | overall: 4649 / 4825
# Match IDs processed this run: 4650 / 4825 | overall: 4650 / 4825
# Match IDs processed this run: 4651 / 4825 | overall: 4651 / 4825
# Match IDs processed this run: 4652 / 4825 | overall: 4652 / 4825
# Match IDs processed this run: 4653 / 4825 | overall: 4653 / 4825
# Match IDs processed this run: 4654 / 4825 | overall: 4654 / 4825
# Match IDs processed this run: 4655 / 4825 | overall: 4655 / 4825
# Match IDs processed this run: 4656 / 4825 | overall: 4656 / 4825
# Match IDs processed this run: 4657 / 4825 | overall: 4657 / 4825
# Match IDs processed this run: 4658 / 4825 | overall: 4658 / 4825
# Match IDs processed this run: 4659 / 4825 | overall: 4659 / 4825
# Match IDs processed this run: 4660 / 4825 | overall: 4660 / 4825
# Match IDs processed this run: 4661 / 4825 | overall: 4661 / 4825
# Match IDs processed this run: 4662 / 4825 | overall: 4662 / 4825
# Match IDs processed this run: 4663 / 4825 | overall: 4663 / 4825
# Match IDs processed this run: 4664 / 4825 | overall: 4664 / 4825
# Match IDs processed this run: 4665 / 4825 | overall: 4665 / 4825
# Match IDs processed this run: 4666 / 4825 | overall: 4666 / 4825
# Match IDs processed this run: 4667 / 4825 | overall: 4667 / 4825
# Match IDs processed this run: 4668 / 4825 | overall: 4668 / 4825
# Match IDs processed this run: 4669 / 4825 | overall: 4669 / 4825
# Match IDs processed this run: 4670 / 4825 | overall: 4670 / 4825
# Match IDs processed this run: 4671 / 4825 | overall: 4671 / 4825
# Match IDs processed this run: 4672 / 4825 | overall: 4672 / 4825
# Match IDs processed this run: 4673 / 4825 | overall: 4673 / 4825
# Match IDs processed this run: 4674 / 4825 | overall: 4674 / 4825
# Match IDs processed this run: 4675 / 4825 | overall: 4675 / 4825
# Match IDs processed this run: 4676 / 4825 | overall: 4676 / 4825
# Match IDs processed this run: 4677 / 4825 | overall: 4677 / 4825
# Match IDs processed this run: 4678 / 4825 | overall: 4678 / 4825
# Match IDs processed this run: 4679 / 4825 | overall: 4679 / 4825
# Match IDs processed this run: 4680 / 4825 | overall: 4680 / 4825
# Match IDs processed this run: 4681 / 4825 | overall: 4681 / 4825
# Match IDs processed this run: 4682 / 4825 | overall: 4682 / 4825
# Match IDs processed this run: 4683 / 4825 | overall: 4683 / 4825
# Match IDs processed this run: 4684 / 4825 | overall: 4684 / 4825
# Match IDs processed this run: 4685 / 4825 | overall: 4685 / 4825
# Match IDs processed this run: 4686 / 4825 | overall: 4686 / 4825
# Match IDs processed this run: 4687 / 4825 | overall: 4687 / 4825
# Match IDs processed this run: 4688 / 4825 | overall: 4688 / 4825
# Match IDs processed this run: 4689 / 4825 | overall: 4689 / 4825
# Match IDs processed this run: 4690 / 4825 | overall: 4690 / 4825
# Match IDs processed this run: 4691 / 4825 | overall: 4691 / 4825
# Match IDs processed this run: 4692 / 4825 | overall: 4692 / 4825
# Match IDs processed this run: 4693 / 4825 | overall: 4693 / 4825
# Match IDs processed this run: 4694 / 4825 | overall: 4694 / 4825
# Match IDs processed this run: 4695 / 4825 | overall: 4695 / 4825
# Match IDs processed this run: 4696 / 4825 | overall: 4696 / 4825
# Match IDs processed this run: 4697 / 4825 | overall: 4697 / 4825
# Match IDs processed this run: 4698 / 4825 | overall: 4698 / 4825
# Match IDs processed this run: 4699 / 4825 | overall: 4699 / 4825
# Match IDs processed this run: 4700 / 4825 | overall: 4700 / 4825
# Match IDs processed this run: 4701 / 4825 | overall: 4701 / 4825
# Match IDs processed this run: 4702 / 4825 | overall: 4702 / 4825
# Match IDs processed this run: 4703 / 4825 | overall: 4703 / 4825
# Match IDs processed this run: 4704 / 4825 | overall: 4704 / 4825
# Match IDs processed this run: 4705 / 4825 | overall: 4705 / 4825
# Match IDs processed this run: 4706 / 4825 | overall: 4706 / 4825
# Match IDs processed this run: 4707 / 4825 | overall: 4707 / 4825
# Match IDs processed this run: 4708 / 4825 | overall: 4708 / 4825
# Match IDs processed this run: 4709 / 4825 | overall: 4709 / 4825
# Match IDs processed this run: 4710 / 4825 | overall: 4710 / 4825
# Match IDs processed this run: 4711 / 4825 | overall: 4711 / 4825
# Match IDs processed this run: 4712 / 4825 | overall: 4712 / 4825
# Match IDs processed this run: 4713 / 4825 | overall: 4713 / 4825
# Match IDs processed this run: 4714 / 4825 | overall: 4714 / 4825
# Match IDs processed this run: 4715 / 4825 | overall: 4715 / 4825
# Match IDs processed this run: 4716 / 4825 | overall: 4716 / 4825
# Match IDs processed this run: 4717 / 4825 | overall: 4717 / 4825
# Match IDs processed this run: 4718 / 4825 | overall: 4718 / 4825
# Match IDs processed this run: 4719 / 4825 | overall: 4719 / 4825
# Match IDs processed this run: 4720 / 4825 | overall: 4720 / 4825
# Match IDs processed this run: 4721 / 4825 | overall: 4721 / 4825
# Match IDs processed this run: 4722 / 4825 | overall: 4722 / 4825
# Match IDs processed this run: 4723 / 4825 | overall: 4723 / 4825
# Match IDs processed this run: 4724 / 4825 | overall: 4724 / 4825
# Match IDs processed this run: 4725 / 4825 | overall: 4725 / 4825
# Match IDs processed this run: 4726 / 4825 | overall: 4726 / 4825
# Match IDs processed this run: 4727 / 4825 | overall: 4727 / 4825
# Match IDs processed this run: 4728 / 4825 | overall: 4728 / 4825
# Match IDs processed this run: 4729 / 4825 | overall: 4729 / 4825
# Match IDs processed this run: 4730 / 4825 | overall: 4730 / 4825
# Match IDs processed this run: 4731 / 4825 | overall: 4731 / 4825
# Match IDs processed this run: 4732 / 4825 | overall: 4732 / 4825
# Match IDs processed this run: 4733 / 4825 | overall: 4733 / 4825
# Match IDs processed this run: 4734 / 4825 | overall: 4734 / 4825
# Match IDs processed this run: 4735 / 4825 | overall: 4735 / 4825
# Match IDs processed this run: 4736 / 4825 | overall: 4736 / 4825
# Match IDs processed this run: 4737 / 4825 | overall: 4737 / 4825
# Match IDs processed this run: 4738 / 4825 | overall: 4738 / 4825
# Match IDs processed this run: 4739 / 4825 | overall: 4739 / 4825
# Match IDs processed this run: 4740 / 4825 | overall: 4740 / 4825
# Match IDs processed this run: 4741 / 4825 | overall: 4741 / 4825
# Match IDs processed this run: 4742 / 4825 | overall: 4742 / 4825
# Match IDs processed this run: 4743 / 4825 | overall: 4743 / 4825
# Match IDs processed this run: 4744 / 4825 | overall: 4744 / 4825
# Match IDs processed this run: 4745 / 4825 | overall: 4745 / 4825
# Match IDs processed this run: 4746 / 4825 | overall: 4746 / 4825
# Match IDs processed this run: 4747 / 4825 | overall: 4747 / 4825
# Match IDs processed this run: 4748 / 4825 | overall: 4748 / 4825
# Match IDs processed this run: 4749 / 4825 | overall: 4749 / 4825
# Match IDs processed this run: 4750 / 4825 | overall: 4750 / 4825
# Match IDs processed this run: 4751 / 4825 | overall: 4751 / 4825
# Match IDs processed this run: 4752 / 4825 | overall: 4752 / 4825
# Match IDs processed this run: 4753 / 4825 | overall: 4753 / 4825
# Match IDs processed this run: 4754 / 4825 | overall: 4754 / 4825
# Match IDs processed this run: 4755 / 4825 | overall: 4755 / 4825
# Match IDs processed this run: 4756 / 4825 | overall: 4756 / 4825
# Match IDs processed this run: 4757 / 4825 | overall: 4757 / 4825
# Match IDs processed this run: 4758 / 4825 | overall: 4758 / 4825
# Match IDs processed this run: 4759 / 4825 | overall: 4759 / 4825
# Match IDs processed this run: 4760 / 4825 | overall: 4760 / 4825
# Match IDs processed this run: 4761 / 4825 | overall: 4761 / 4825
# Match IDs processed this run: 4762 / 4825 | overall: 4762 / 4825
# Match IDs processed this run: 4763 / 4825 | overall: 4763 / 4825
# Match IDs processed this run: 4764 / 4825 | overall: 4764 / 4825
# Match IDs processed this run: 4765 / 4825 | overall: 4765 / 4825
# Match IDs processed this run: 4766 / 4825 | overall: 4766 / 4825
# Match IDs processed this run: 4767 / 4825 | overall: 4767 / 4825
# Match IDs processed this run: 4768 / 4825 | overall: 4768 / 4825
# Match IDs processed this run: 4769 / 4825 | overall: 4769 / 4825
# Match IDs processed this run: 4770 / 4825 | overall: 4770 / 4825
# Match IDs processed this run: 4771 / 4825 | overall: 4771 / 4825
# Match IDs processed this run: 4772 / 4825 | overall: 4772 / 4825
# Match IDs processed this run: 4773 / 4825 | overall: 4773 / 4825
# Match IDs processed this run: 4774 / 4825 | overall: 4774 / 4825
# Match IDs processed this run: 4775 / 4825 | overall: 4775 / 4825
# Match IDs processed this run: 4776 / 4825 | overall: 4776 / 4825
# Match IDs processed this run: 4777 / 4825 | overall: 4777 / 4825
# Match IDs processed this run: 4778 / 4825 | overall: 4778 / 4825
# Match IDs processed this run: 4779 / 4825 | overall: 4779 / 4825
# Match IDs processed this run: 4780 / 4825 | overall: 4780 / 4825
# Match IDs processed this run: 4781 / 4825 | overall: 4781 / 4825
# Match IDs processed this run: 4782 / 4825 | overall: 4782 / 4825
# Match IDs processed this run: 4783 / 4825 | overall: 4783 / 4825
# Match IDs processed this run: 4784 / 4825 | overall: 4784 / 4825
# Match IDs processed this run: 4785 / 4825 | overall: 4785 / 4825
# Match IDs processed this run: 4786 / 4825 | overall: 4786 / 4825
# Match IDs processed this run: 4787 / 4825 | overall: 4787 / 4825
# Match IDs processed this run: 4788 / 4825 | overall: 4788 / 4825
# Match IDs processed this run: 4789 / 4825 | overall: 4789 / 4825
# Match IDs processed this run: 4790 / 4825 | overall: 4790 / 4825
# Match IDs processed this run: 4791 / 4825 | overall: 4791 / 4825
# Match IDs processed this run: 4792 / 4825 | overall: 4792 / 4825
# Match IDs processed this run: 4793 / 4825 | overall: 4793 / 4825
# Match IDs processed this run: 4794 / 4825 | overall: 4794 / 4825
# Match IDs processed this run: 4795 / 4825 | overall: 4795 / 4825
# Match IDs processed this run: 4796 / 4825 | overall: 4796 / 4825
# Match IDs processed this run: 4797 / 4825 | overall: 4797 / 4825
# Match IDs processed this run: 4798 / 4825 | overall: 4798 / 4825
# Match IDs processed this run: 4799 / 4825 | overall: 4799 / 4825
# Match IDs processed this run: 4800 / 4825 | overall: 4800 / 4825
# Match IDs processed this run: 4801 / 4825 | overall: 4801 / 4825
# Match IDs processed this run: 4802 / 4825 | overall: 4802 / 4825
# Match IDs processed this run: 4803 / 4825 | overall: 4803 / 4825
# Match IDs processed this run: 4804 / 4825 | overall: 4804 / 4825
# Match IDs processed this run: 4805 / 4825 | overall: 4805 / 4825
# Match IDs processed this run: 4806 / 4825 | overall: 4806 / 4825
# Match IDs processed this run: 4807 / 4825 | overall: 4807 / 4825
# Match IDs processed this run: 4808 / 4825 | overall: 4808 / 4825
# Match IDs processed this run: 4809 / 4825 | overall: 4809 / 4825
# Match IDs processed this run: 4810 / 4825 | overall: 4810 / 4825
# Match IDs processed this run: 4811 / 4825 | overall: 4811 / 4825
# Match IDs processed this run: 4812 / 4825 | overall: 4812 / 4825
# Match IDs processed this run: 4813 / 4825 | overall: 4813 / 4825
# Match IDs processed this run: 4814 / 4825 | overall: 4814 / 4825
# Match IDs processed this run: 4815 / 4825 | overall: 4815 / 4825
# Match IDs processed this run: 4816 / 4825 | overall: 4816 / 4825
# Match IDs processed this run: 4817 / 4825 | overall: 4817 / 4825
# Match IDs processed this run: 4818 / 4825 | overall: 4818 / 4825
# Match IDs processed this run: 4819 / 4825 | overall: 4819 / 4825
# Match IDs processed this run: 4820 / 4825 | overall: 4820 / 4825
# Match IDs processed this run: 4821 / 4825 | overall: 4821 / 4825
# Match IDs processed this run: 4822 / 4825 | overall: 4822 / 4825
# Match IDs processed this run: 4823 / 4825 | overall: 4823 / 4825
# Match IDs processed this run: 4824 / 4825 | overall: 4824 / 4825
# Match IDs processed this run: 4825 / 4825 | overall: 4825 / 4825
# Done. Saved champion picks for 4825 matches to /Users/ruofuli/hcde530/MP1/champion_picks_by_match_id.json

# %% [markdown]
# The code above is actually the second iteration of the script to fetch data from the endpoint due to its massive payload. The first time, I had asked the script to store ALL the fetched data into a JSON file, but that quickly crashed Cursor due to how much information there was. The second iteration of this code still fetches all the API data associated with this Match ID from this endpoint, but now only stores the champion pick data after it's already been sorted for it.

# %% [markdown]
# #### 8a. Converting champion pick JSON to a usable DataFrame
# Next, it'd be really nice if we could see our data laid out. The script below converts `champion_picks_by_match_id` into a usable DataFrame for Pandas Analysis.

# %%
from pathlib import Path
import json

picks_candidates = [
    Path("champion_picks_by_match_id.json"),
    Path("Week 5") / "champion_picks_by_match_id.json",
    Path("..") / "Week 5" / "champion_picks_by_match_id.json",
]
picks_path = next((p for p in picks_candidates if p.is_file()), None)
if picks_path is None:
    raise FileNotFoundError(
        "champion_picks_by_match_id.json not found. Tried: " + ", ".join(str(p) for p in picks_candidates)
    )

with open(picks_path, encoding="utf-8") as f:
    champion_picks_by_match_id = json.load(f)

if not isinstance(champion_picks_by_match_id, dict):
    raise TypeError("champion_picks_by_match_id.json should be a JSON object keyed by match_id.")

rows = []
for match_id, participants in champion_picks_by_match_id.items():
    if not isinstance(participants, list):
        continue
    for pick in participants:
        if not isinstance(pick, dict):
            continue
        row = {"match_id": match_id, **pick}
        rows.append(row)

champion_picks_df = pd.DataFrame(rows)

print("Loaded:", picks_path.resolve())
print("shape (rows, columns):", champion_picks_df.shape)
champion_picks_df.tail(10)
# Out:
# Loaded: /Users/ruofuli/hcde530/MP1/champion_picks_by_match_id.json
# shape (rows, columns): (48210, 8)
#              match_id                                              puuid  \
# 48200  NA1_5539518433  q4gLg8SmSKhE2PmLbp_FvoNtVt4NVYEPrFOglGfNkIPrBb...
# 48201  NA1_5539518433  6GdUKLQ2qbXp7pJJ72OzOwnt5NQINLr7XVyX4sZ4s2JAYU...
# 48202  NA1_5539518433  sSxTEHycncy84QFKnBOsbd8OV3GaXlVmTvtlMtkH2xw_Ej...
# 48203  NA1_5539518433  bYBBl9VTwv0pmZ0Z8FNMj4Z1cOZuv9g7QBaqtaJ0oyx_Bt...
# 48204  NA1_5539518433  YWgOXMk9hKyvCb5yVFNyXEA-FNCZxcP1017gbd9a5rJB-C...
# 48205  NA1_5539518433  pbo3FP7pZPcFruMdq3xqlJVAY-ECLsYI5XQsrHeX7IxupY...
# 48206  NA1_5539518433  Z7m0Wb5WCs4eT1f11lidpFL6WDrI9-lyauW11QQdlSZUI7...
# 48207  NA1_5539518433  7q4nmD7kQExzoj-42jtwsuHSu6Q_W7LXJGEE5H0CfTtIof...
# 48208  NA1_5539518433  HY5aE32vC791a5hn-dBzUZbJbaKC0DZ4rzPzwjUS0pTHx7...
# 48209  NA1_5539518433  idAFkFiSmr1P_-aUp4E7ksoUaocRqkyEBebdcuHEAwoC1j...
#
#        championId championName  teamId teamPosition individualPosition    win
# 48200           2         Olaf     100          TOP                TOP   True
# 48201           5      XinZhao     100       JUNGLE             JUNGLE   True
# 48202          90     Malzahar     100       MIDDLE             MIDDLE   True
# 48203         498        Xayah     100       BOTTOM             BOTTOM   True
# 48204         235        Senna     100      UTILITY            UTILITY   True
# 48205          92        Riven     200          TOP                TOP  False
# 48206          19      Warwick     200       JUNGLE             JUNGLE  False
# 48207         127    Lissandra     200       MIDDLE             MIDDLE  False
# 48208          67        Vayne     200       BOTTOM             BOTTOM  False
# 48209         497        Rakan     200      UTILITY            UTILITY  False

# %% [markdown]
# #### 8ai. Cleaning the DataFrame
# Fetching match data from 4825 Match IDs should have returned 10 champion picks each, resulting in a total of 48,250 total rows. However, in analyzing the DataFrame above, we can only see 48,210. Let's see if there are any null values that we need to clean.

# %%
if "champion_picks_df" not in globals():
    raise RuntimeError("Run section 8a first so champion_picks_df exists.")

rows_before = len(champion_picks_df)
nulls_per_column = champion_picks_df.isna().sum()
total_null_cells = int(nulls_per_column.sum())
rows_with_any_null = int(champion_picks_df.isna().any(axis=1).sum())

print("Rows before dropping nulls:", rows_before)
print("Null cells (total):", total_null_cells)
print("Rows with at least one null:", rows_with_any_null)
if total_null_cells:
    print("\nNulls per column:")
    print(nulls_per_column[nulls_per_column > 0])

champion_picks_df = champion_picks_df.dropna()
rows_after = len(champion_picks_df)
rows_removed = rows_before - rows_after

print("\nRows removed:", rows_removed)
print("Rows after dropping nulls:", rows_after)
print("shape (rows, columns):", champion_picks_df.shape)
champion_picks_df.head()
# Out:
# Rows before dropping nulls: 48210
# Null cells (total): 0
# Rows with at least one null: 0
#
# Rows removed: 0
# Rows after dropping nulls: 48210
# shape (rows, columns): (48210, 8)
#          match_id                                              puuid  \
# 0  NA1_5550304472  dmr_PvsJDqRYwdOsAvRCGlp5676GgstHkcKjev1N03OTVQ...
# 1  NA1_5550304472  73-lrrlMMVWme9MM0yPNZGWRe74f6bjBBK5HAiZu3W9Ddf...
# 2  NA1_5550304472  jK6YPX1S57Juet21uvU4wLeRrINqVQ-7PWF7Qk_zEQgugc...
# 3  NA1_5550304472  iVw8Qyyy0kgySNltkzIj9Cer2Z-vOFtc1pHUwtNjNI9tsV...
# 4  NA1_5550304472  UL3qXsy63hmThQw39LTtPWK2JI316v5jHX8r_yw5g9A873...
#
#    championId championName  teamId teamPosition individualPosition    win
# 0           6        Urgot     100          TOP                TOP  False
# 1          11     MasterYi     100       JUNGLE             JUNGLE  False
# 2          79       Gragas     100       MIDDLE             MIDDLE  False
# 3         875         Sett     100       BOTTOM             BOTTOM  False
# 4         235        Senna     100      UTILITY            UTILITY  False

# %% [markdown]
# Since no rows with null values were discovered, this means that the data in this DataFrame are usable and shouldn't significantly affect the analysis. This is most likely because there were 4 Match IDs that had no champion pick data in the Riot API, but upon detection they were simply skipped and not included in the DataFrame.

# %% [markdown]
# #### 8b. Further Cleaning- Sorting by teamPosition == UTILITY
# Even though we already sorted the fetched data and only stored the information about champion picks, it still includes a lot of other roles that we're not looking for. As a result, let's clean this dataset up a little to only show us the Support champion picks.

# %%
if "champion_picks_df" not in globals():
    raise RuntimeError("Run section 8a first so champion_picks_df exists.")

support_picks_df = champion_picks_df[champion_picks_df["teamPosition"] == "UTILITY"].copy()

print("rows before filter:", len(champion_picks_df))
print("support rows (UTILITY):", len(support_picks_df))
support_picks_df.head(10)
# Out:
# rows before filter: 48210
# support rows (UTILITY): 9631
#           match_id                                              puuid  \
# 4   NA1_5550304472  UL3qXsy63hmThQw39LTtPWK2JI316v5jHX8r_yw5g9A873...
# 9   NA1_5550304472  o9UXKEi4u2kwH6F9UJVxFy8x6Jbi2tXl3Y5sFmPaDBR8Us...
# 14  NA1_5545162641  iAPisvb-m-cDkpVmzVJtNKdNjTwoIgk-PkKIvRQScvPeed...
# 19  NA1_5545162641  z47LTXaQxM72C5dDdLwpdhuZJVDjcmnqkjE11WKKhqtDPx...
# 24  NA1_5530609519  Kj3raKvthe46haxKC6N2LOpUK8_VxgOyRUo48bufObv60i...
# 29  NA1_5530609519  LkD9mUW8W5xEDss269mnh1dmIhdsc-kwm3JB7B_YU8bunW...
# 34  NA1_5530552256  YGIe4YJJm9C8UxGgFnMxB0R28D8eoq7sZd4_7LScRtXGW0...
# 39  NA1_5530552256  vlZi8mpfS47IqAtxbXCjLUWUq9HZqzumvz1fZQ-sYeYxUn...
# 44  NA1_5530519318  05ULVbcqTZ6gRRf_HohaNzkVKlnpa-_X1vScIiIOc2pReR...
# 49  NA1_5530519318  JX2dXFlJi6A2-ZC3Cbzrk6OrAVex80DXcZUIv0oFVxaqlX...
#
#     championId championName  teamId teamPosition individualPosition    win
# 4          235        Senna     100      UTILITY            UTILITY  False
# 9           89        Leona     200      UTILITY            UTILITY   True
# 14          53   Blitzcrank     100      UTILITY            UTILITY   True
# 19          26       Zilean     200      UTILITY            UTILITY  False
# 24          22         Ashe     100      UTILITY            UTILITY   True
# 29          50        Swain     200      UTILITY            UTILITY  False
# 34         223    TahmKench     100      UTILITY            UTILITY  False
# 39          50        Swain     200      UTILITY            UTILITY   True
# 44         161       Velkoz     100      UTILITY            UTILITY   True
# 49          25      Morgana     200      UTILITY            UTILITY  False

# %% [markdown]
# #### 8c. Exporting support picks to CSV for visualization

# %%
from pathlib import Path

if "support_picks_df" not in globals():
    raise RuntimeError("Run section 8b first so support_picks_df exists.")

# Save to MP1/ when run from repo root; otherwise save in the current (MP1) folder
csv_path = (Path("MP1") / "support_picks.csv") if Path("MP1").is_dir() else Path("support_picks.csv")
csv_path.parent.mkdir(parents=True, exist_ok=True)

support_picks_df.to_csv(csv_path, index=False)
print("Saved support picks CSV to:", csv_path.resolve())
print("rows exported:", len(support_picks_df))
# Out:
# Saved support picks CSV to: /Users/ruofuli/hcde530/MP1/support_picks.csv
# rows exported: 9631

# %% [markdown]
# ### To be continued...
# That's the end of this dataset prep! Please refer to `MP1_analysis` to see the analysis and visualizations for this dataset.
