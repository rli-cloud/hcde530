# %% [markdown]
# # HCDE 530 — A5: Pandas Analysis
#
# ### Instructions
# In class you used pandas to answer five questions about a dataset. For A5 you are doing that on your own data — the dataset you chose for Mini Project 1 — and documenting what you found.
#
# This assignment is closely connected to MP1. The analysis you do here is the foundation for the notebook you will build in Week 6.
#
# ### Introduction
# League of Legends is an online multiplayer game where two teams of 5 battle against each other in what I can only describe as a glorified capture the flag game. Each team must destroy the other team's Nexus in their base to win the game. There are 5 unique roles on each team, corresponding to the lane or area they're typically supposed to play in: Top, Middle, Bottom, Support, and Jungle. In competitive play, players are ranked from Iron to Challenger based on their performance.
#
# As a Support main that hovers around the Bronze level, I was curious in using the Riot Developer API to answer the following questions:
#
# 1. Who is the most played Support champion in Bronze IV Solo 5x5 Ranked lobbies? ~~What about across all ranks?~~
# ~~2. What does the distribution of the most popular Support player across every rank look like?~~
# ~~3. What is the most common Bottom Lane/Support pairing in Bronze-level lobbies? What about across all ranks?~~
#
# Adjusted questions from MP1 for A5 correction:
#
# 2. What is the win rate for the top 3 Support champions in this lobby?
# 3. Which Support champion has the highest win rate?
#
# A previous version of these questions included one about the pick rate of cosmetic skins, but because that information isn't available through the Riot Developer API, I've changed that question to one that can actually be answered by the API.

# %% [markdown]
# ---
# ### 0. Setting up Pandas

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

print("pandas version:", pd.__version__)
# Out:
# pandas version: 3.0.2

# %% [markdown]
# ---
# ### 1. Importing up the API
#
# To begin answering my data analysis questions, I need to set up endpoints for 3 different APIs, each dealing with a different type of player information. This includes one to fetch summoner ID data (where I'll query for Player Universally Unique IDs (PUUID)), one to extract game match information based on those PUUIDs, and finally an API to extract champion picks per match.

# %% [markdown]
# ##### Player Universally Unique IDs

# %%
import json
import os
import time
import urllib.error
import urllib.request
from pathlib import Path

#function to load .env file so that this code can read the API key on it 
def _load_env(path: Path) -> None:
    """Load KEY=VALUE pairs from a .env file into os.environ (does not override existing vars).""" 
    if not path.is_file(): #if the .env file doesn't exist, return None
        return
    for line in path.read_text().splitlines():# for each line in the .env file
        line = line.strip()
        if not line or line.startswith("#") or "=" not in line:
            continue
        key, _, val = line.partition("=")
        key, val = key.strip(), val.strip().strip('"').strip("'")
        if key:
            os.environ.setdefault(key, val)


# Resolve Week 5/.env whether the kernel cwd is the repo root or the Week 5 folder
for _env in (Path(".env"), Path("Week 5") / ".env"):
    _load_env(_env)

api_key = os.environ.get("RIOT_API_KEY", "").strip() #the api key I stored in .env, will be regenerated every 24 hours
if not api_key:
    raise ValueError("RIOT_API_KEY missing: add it to Week 5/.env or set it in the environment.")

base = "https://na1.api.riotgames.com/lol/league/v4/entries/RANKED_SOLO_5x5/BRONZE/IV" #endpoint for summoner ID data, need to query for PUUIDs later
# Riot sits behind Cloudflare; default User-Agent "Python-urllib/..." often gets HTTP 403 + "error code: 1010".
headers = {
    "X-Riot-Token": api_key,
    "User-Agent": "HCDE530-A5/1.0 (pandas coursework; contact instructor)",
}

all_entries: list = [] #list to store all the data fetched from the API
for page in range(1, 326):  # pages 1 … 325 #calculated based on API request limit from Riot, but actually only fetched 258 because page 259 had no data (see break function below)
    url = f"{base}?page={page}"
    req = urllib.request.Request(url, headers=headers)
    try:
        with urllib.request.urlopen(req, timeout=30) as resp:
            data = json.load(resp)
    except urllib.error.HTTPError as e:
        body = e.read().decode(errors="replace")
        raise RuntimeError(f"HTTP {e.code} {e.reason}: {body[:500]}") from e

    if not data:
        break
    all_entries.extend(data)
    print(f"page {page}", flush=True) #print the page number to track progress as the loop runs
    time.sleep(2.0) #wait 2 seconds between requests to avoid overwhelming the server

summoner_league_json = all_entries #assign the fetched data to a variable to convert JSON into dataframe later 
print(len(summoner_league_json), "total entries across fetched pages") #total data fetched across each request aka page 
if summoner_league_json:
    print("example keys:", list(summoner_league_json[0].keys())) #fields in the JSON data fetched from the API
# Out:
# page 1
# page 2
# page 3
# page 4
# page 5
# page 6
# page 7
# page 8
# page 9
# page 10
# page 11
# page 12
# page 13
# page 14
# page 15
# page 16
# page 17
# page 18
# page 19
# page 20
# page 21
# page 22
# page 23
# page 24
# page 25
# page 26
# page 27
# page 28
# page 29
# page 30
# page 31
# page 32
# page 33
# page 34
# page 35
# page 36
# page 37
# page 38
# page 39
# page 40
# page 41
# page 42
# page 43
# page 44
# page 45
# page 46
# page 47
# page 48
# page 49
# page 50
# page 51
# page 52
# page 53
# page 54
# page 55
# page 56
# page 57
# page 58
# page 59
# page 60
# page 61
# page 62
# page 63
# page 64
# page 65
# page 66
# page 67
# page 68
# page 69
# page 70
# page 71
# page 72
# page 73
# page 74
# page 75
# page 76
# page 77
# page 78
# page 79
# page 80
# page 81
# page 82
# page 83
# page 84
# page 85
# page 86
# page 87
# page 88
# page 89
# page 90
# page 91
# page 92
# page 93
# page 94
# page 95
# page 96
# page 97
# page 98
# page 99
# page 100
# page 101
# page 102
# page 103
# page 104
# page 105
# page 106
# page 107
# page 108
# page 109
# page 110
# page 111
# page 112
# page 113
# page 114
# page 115
# page 116
# page 117
# page 118
# page 119
# page 120
# page 121
# page 122
# page 123
# page 124
# page 125
# page 126
# page 127
# page 128
# page 129
# page 130
# page 131
# page 132
# page 133
# page 134
# page 135
# page 136
# page 137
# page 138
# page 139
# page 140
# page 141
# page 142
# page 143
# page 144
# page 145
# page 146
# page 147
# page 148
# page 149
# page 150
# page 151
# page 152
# page 153
# page 154
# page 155
# page 156
# page 157
# page 158
# page 159
# page 160
# page 161
# page 162
# page 163
# page 164
# page 165
# page 166
# page 167
# page 168
# page 169
# page 170
# page 171
# page 172
# page 173
# page 174
# page 175
# page 176
# page 177
# page 178
# page 179
# page 180
# page 181
# page 182
# page 183
# page 184
# page 185
# page 186
# page 187
# page 188
# page 189
# page 190
# page 191
# page 192
# page 193
# page 194
# page 195
# page 196
# page 197
# page 198
# page 199
# page 200
# page 201
# page 202
# page 203
# page 204
# page 205
# page 206
# page 207
# page 208
# page 209
# page 210
# page 211
# page 212
# page 213
# page 214
# page 215
# page 216
# page 217
# page 218
# page 219
# page 220
# page 221
# page 222
# page 223
# page 224
# page 225
# page 226
# page 227
# page 228
# page 229
# page 230
# page 231
# page 232
# page 233
# page 234
# page 235
# page 236
# page 237
# page 238
# page 239
# page 240
# page 241
# page 242
# page 243
# page 244
# page 245
# page 246
# page 247
# page 248
# page 249
# page 250
# page 251
# page 252
# page 253
# page 254
# page 255
# page 256
# page 257
# page 258
# 52729 total entries across fetched pages
# example keys: ['leagueId', 'queueType', 'tier', 'rank', 'puuid', 'leaguePoints', 'wins', 'losses', 'veteran', 'inactive', 'freshBlood', 'hotStreak']

# %% [markdown]
# ---
# ### 2. Turning JSON data into a DataFrame

# %%
# List of dicts from section 1a — after the fetch cell runs, `summoner_league_json` and `all_entries` point to the same list.
if "summoner_league_json" in globals():
    rows = summoner_league_json
elif "all_entries" in globals():
    rows = all_entries
else:
    raise RuntimeError("Run the API cell in section 1a first so summoner_league_json / all_entries exist.")

df = pd.DataFrame(rows) #convert the JSON data into a dataframe 
n_src = len(rows) #number of records in the JSON data
n_df = len(df) #number of records in the dataframe
cols = len(df.columns) #number of columns in the dataframe
if n_src == 0:
    print("Conversion finished: empty DataFrame (0 rows) — no API data in rows yet.")
elif n_df == n_src:
    print(
        f"JSON → DataFrame conversion successful: {n_df} rows × {cols} columns "
        f"(matches all {n_src} records from summoner_league_json / all_entries)."
    )
else:
    print(
        f"Unexpected row count after conversion: DataFrame has {n_df} rows but source list has {n_src}."
    )
# Out:
# JSON → DataFrame conversion successful: 52729 rows × 12 columns (matches all 52729 records from summoner_league_json / all_entries).

# %% [markdown]
# ---
# ### 3. Analyzing the DataFrame with Pandas Operations
# #### 3a. What kinds of data did we actually fetch with all these API requests? Finding out with `df.head()`
# This operation will allow me to see all the different kinds of data associated with each row that was fetched from the API. Here, we can see that in addition to the PUUID (which we'll need to fetch match history data), we can also see their associated LP (which determines rank), wins, losses, veteran status, activity, and win streaks.

# %%
# `df` is built in section 2 — run that cell first.
print("shape (rows, columns):", df.shape) #display the number of rows and columns in the dataframe
df.head() #display the first 5 rows of the dataframe
# Out:
# shape (rows, columns): (52729, 12)
#                                leagueId        queueType    tier rank  \
# 0  04116fb7-6868-4521-9910-61fb90b76e5d  RANKED_SOLO_5x5  BRONZE   IV
# 1  1ec3dd38-bf92-4c0e-aa5d-ca540bd70919  RANKED_SOLO_5x5  BRONZE   IV
# 2  3610058c-0fc6-4ee5-a161-dad705389f88  RANKED_SOLO_5x5  BRONZE   IV
# 3  346389f6-9c92-414f-b2a1-19f5524e4895  RANKED_SOLO_5x5  BRONZE   IV
# 4  04ec97a8-c7cc-4d22-aa8d-24ac7b697054  RANKED_SOLO_5x5  BRONZE   IV
#
#                                                puuid  leaguePoints  wins  \
# 0  dmr_PvsJDqRYwdOsAvRCGlp5676GgstHkcKjev1N03OTVQ...            18    33
# 1  Q5tPr4VoHQO40KOqRSjQMkb10Uw1uFX62YNk0ZJNYLR4F3...            23     5
# 2  hseHG45GLA7RwEdsMcqt1t6VjpEMPlV_Jelsv26jLRWCQy...            31    36
# 3  LBIg2k5fCNbUGMESy8Gh5hJH9ZupZGwKdwodsu7rNwdKha...            15   169
# 4  W8zW_QFs2RAV1PcYUYWP31upsQoaVDpOmVAuUDeZyWLsV1...            18    31
#
#    losses  veteran  inactive  freshBlood  hotStreak
# 0      52    False     False       False      False
# 1       8    False     False       False      False
# 2      63    False     False       False      False
# 3     202    False     False       False      False
# 4      40    False     False       False      False

# %% [markdown]
# #### 3b. How many times does each PUUID appear? Using the operations: `df['puuid'].value_counts()` & `df.duplicated(subset=["puuid"]).sum()`
# This operation will allow me to see how many times a PUUID appears in the dataframe. Because I had to fetch data from the API in two different sesions (once before receiving an HTTP 429 error, and once after fixing it), there's a possibility that I accidentally fetched the same pages twice. Since PUUIDs are supposed to be unique to each account, each PUUID should really only appear once in my dataframe. This operation will allow me to catch if I accidentally fetched the same pages twice.

# %%
df['puuid'].value_counts() #display the number of times each PUUID appears in the dataframe in descending order
# Out:
# puuid
# ii89RSci7pZ3Jv6TdPagBbbQVEZzFd2llBH9BLhIipO18RCpJTnt0aFxrXwBOKIN7NouuTy07GtqiQ    2
# B1TB7XUm8qYdS5zFTmtOAXlQTAhahPlb0Uhb-1ZPS741W-foGbeiZpp242p0YpZvOcGniZZhBhz--A    2
# 7IOzK6xmUEZ1-zegE26isH9O5FsFKKigiP9rzhd0eoG6N-y5wMob-vOhFBUG0HuDmnn-8vtOzop8AQ    2
# ableOWCSRBhCLXyxj-ntkSCrsRxCx4XDd8xhEUoCtsV48_4PI2iAAfbWe6bdlHNsjf1D6nXSNUQ2xg    2
# o-b2eX8DQHUqnt1JtChX99atA5kVT6fdA7STnjwqugvtxTl30cRnEEHQlazAAD8FcqXXiKh9MQFfuQ    2
#                                                                                  ..
# vd37E5n0iok6pQmUbdmtDAH9CLr02BGqjZTQQSZOXOd-N8mZflR76ccZZs_tLlOQ2Kk_XpUF4h86RA    1
# DN7Y4yEoj0S3UglHmN1sBe8Is_Ru6aPsjd1KO0Oyej8FLl4tpOCulK8e5F_cF60nr8pyY5lx1w8KkA    1
# 7iOcpIxTZaQu8ZezW3ciIr59C8dpM_pTudfh9Kalx2yyZSgzPZmHzlrtAj1liYcqpFI2ngWXiyf5Mw    1
# WFl6wxhqyNJCGx_6m3QWV9OeaJSqBqVhESi4QJhYb3p-P5ByMlBrz-Y20mtsPjEvpSqs91u-Berfbg    1
# 0DzEUblGPo-tTMNDC17gD3Qn_YcbOgtVJ_mWDSpzmjSzYqdS5h1RJqoBmfcOf1PwLxhfw8_EcFCsWw    1
# Name: count, Length: 51447, dtype: int64

# %% [markdown]
# This next code block will tell us how many times a duplicated PUUID appears in the dataframe.

# %%
df.duplicated(subset=["puuid"]).sum() #display the number of duplicate PUUIDs in the dataframe
# Out:
# np.int64(1282)

# %% [markdown]
# Here, we can see that there are 1282 duplicate entries in the dataframe.
#
# #### 3c. How can we merge or deduplicate the repeated PUUIDs? Cleaning with `df.drop_duplicates` and checking with `df_deduped.duplicated`
# Now, our next step is to merge or deduplicate this repeated data.

# %%
df_deduped = df.drop_duplicates(subset=["puuid"], keep="last") #keeps the last occurence of each PUUID, which should've come from the second API call where all pages were fetched successfully

#check if the deduplication worked
print("rows before:", len(df))
df_deduped = df.drop_duplicates(subset=["puuid"], keep="first")
print("rows after:", len(df_deduped))

df_deduped.duplicated(subset=["puuid"]).sum() #double check that the deduplication worked by checking the number of duplicate PUUIDs in the dataframe
#make sure you're using the deduped dataframe instead of the original one! original one still has the duplicates
# Out:
# rows before: 52729
# rows after: 51447
# np.int64(0)

# %% [markdown]
# Now that our dataset has been cleaned of any duplicates, we can use other Pandas Analysis operations to learn more about the dataframe.
#
# #### 3d. Does this dataframe have any NaN values that could affect our future data analysis? Finding out with `df_deduped.isnull().sum()`

# %% [markdown]
# Because we know that PUUIDs are unique to each account, each column should be filled out with information that comes from Riot's API. By using this operation, we can double check that there won't be any NaN values that could affect our data analysis.

# %%
### 4. Extracting PUUIDs to use in another API for Match IDs
df_deduped.isnull().sum()
# Out:
# leagueId        0
# queueType       0
# tier            0
# rank            0
# puuid           0
# leaguePoints    0
# wins            0
# losses          0
# veteran         0
# inactive        0
# freshBlood      0
# hotStreak       0
# dtype: int64

# %% [markdown]
# Because we really only need the PUUIDs from the dataframe to proceed, we can stop our Pandas Analysis here.
#
# Now that we've cleaned up the duplicate data and gained a good understanding of the dataframe, we can move one to extract PUUIDs from each row and use them to fetch data about Match Id, which will give us the suitable information to fetch data about Champion Picks.

# %% [markdown]
# ---
# ### 5. Extracting PUUIDs to use in another API for Match IDs

# %%
# Extract unique PUUIDs from the deduplicated DataFrame for downstream API scripts.
if "df_deduped" not in globals():
    raise RuntimeError("Run the deduplication cell first so df_deduped exists.")

puuid_list = df_deduped["puuid"].dropna().astype(str).tolist()
print(f"Prepared {len(puuid_list)} PUUIDs for API scripting.")
print("Sample:", puuid_list[:5])

# Optional: save to disk as JSON so another script can load it directly.
with open("puuid_list.json", "w", encoding="utf-8") as f:
    json.dump(puuid_list, f, ensure_ascii=False, indent=2)
print("Saved puuid_list.json")
# Out:
# Prepared 51447 PUUIDs for API scripting.
# Sample: ['dmr_PvsJDqRYwdOsAvRCGlp5676GgstHkcKjev1N03OTVQyvTqLUTZmpYmQnR1QetaEeFBBAFDiI0A', 'Q5tPr4VoHQO40KOqRSjQMkb10Uw1uFX62YNk0ZJNYLR4F3k5hRus6RZxNDNbblocQhEc4or40vRRtA', 'hseHG45GLA7RwEdsMcqt1t6VjpEMPlV_Jelsv26jLRWCQyA8wqK22JG-C9hUTz_A5ilXbKCjvt-dMw', 'LBIg2k5fCNbUGMESy8Gh5hJH9ZupZGwKdwodsu7rNwdKhaOy5_ZjEDJ9MWwKmWcf35kMgsWxGpRqrg', 'W8zW_QFs2RAV1PcYUYWP31upsQoaVDpOmVAuUDeZyWLsV1_sRvTcjUaq-xjZKKhhUrwfkLWgcbmSIQ']
# Saved puuid_list.json

# %% [markdown]
# ---
# ### 6. Using stored PUUIDs to fetch data for Match IDs
# It's important to be precise with this API, because it could return matches that weren't played in Ranked 5x5 Solo (which is how we filtered the PUUIDs above). For analysis purposes, we'll be fetching the 10 most recent matches associated with the PUUIDs that were extracted from the dataframe above. As a reminder, the PUUIDs are supposed to represent players that were Bronze IV in Ranked 5x5 Solo queue as of May 6th, 2026.
#
# Additionally, even though the JSON contains around 51,400 PUUIDs (as fetched from the previous API endpoint), the code below will only fetch Match IDs for the first 500 PUUIDs in the JSON file due to time constraints and request limits from Riot. A sample size of 500 should be statistically significant enough to demonstrate major patterns in player behavior. This will take around 40 minutes.

# %%
import json
import os
import time
import urllib.error
import urllib.parse
import urllib.request
from pathlib import Path

QUEUE_ID = 420  # Ranked Solo/Duo 5v5 — see https://static.developer.riotgames.com/docs/lol/queues.json
MATCH_IDS_START = 0
MATCH_IDS_COUNT = 10
REQUEST_SLEEP_SEC = 2.0  # increase if you get HTTP 429
MAX_PUUIDS = 500  # loop through the first 500 PUUIDs from puuid_list.json

#function to load .env file so that this code can read the API key on it 
def _load_env(path: Path) -> None:
    if not path.is_file():
        return
    for line in path.read_text().splitlines():
        line = line.strip()
        if not line or line.startswith("#") or "=" not in line:
            continue
        key, _, val = line.partition("=")
        key, val = key.strip(), val.strip().strip('"').strip("'")
        if key:
            os.environ.setdefault(key, val)

# Resolve Week 5/.env whether the kernel cwd is the repo root or the Week 5 folder
for _env in (Path(".env"), Path("Week 5") / ".env"):
    _load_env(_env)

api_key = os.environ.get("RIOT_API_KEY", "").strip() #the api key I stored in .env, will be regenerated every 24 hours
if not api_key:
    raise ValueError("RIOT_API_KEY missing: add it to Week 5/.env or set it in the environment.") #debugging flag in case API key is missing

# Load PUUID list using relative fallback paths so this works from different kernel cwd values  bc having trouble that this code is not reading the puuid_list.json file
puuid_candidates = [
    Path("puuid_list.json"),
    Path("Week 5") / "puuid_list.json",
    Path("..") / "Week 5" / "puuid_list.json",
]
puuid_path = next((p for p in puuid_candidates if p.is_file()), None)
if puuid_path is None: #debugging flag in case puuid_list.json is not found
    raise FileNotFoundError(
        "puuid_list.json not found. Tried: " + ", ".join(str(p) for p in puuid_candidates)
    )
#load the puuid_list.json file
with open(puuid_path, encoding="utf-8") as f:
    puuids = json.load(f)

if not isinstance(puuids, list): #debugging flag in case puuid_list.json is not a list
    raise TypeError("puuid_list.json should contain a JSON array of PUUID strings.")

if MAX_PUUIDS is not None: 
    puuids = puuids[: int(MAX_PUUIDS)]

# Save checkpoint/output in a relative path that is valid for current cwd bc having trouble that this code is not reading the puuid_list.json file
out_candidates = [
    Path("match_ids_by_puuid.json"),
    Path("Week 5") / "match_ids_by_puuid.json",
    Path("..") / "Week 5" / "match_ids_by_puuid.json",
]
out_path = next((p for p in out_candidates if p.parent.exists()), out_candidates[0])

# Resume support: load existing checkpoint and skip those PUUIDs on rerun in case session is interrupted.
if out_path.is_file():
    with open(out_path, encoding="utf-8") as f:
        existing = json.load(f)
    if not isinstance(existing, dict):
        raise TypeError("match_ids_by_puuid.json should contain a JSON object keyed by puuid.")
    match_ids_by_puuid: dict[str, list] = existing
else:
    match_ids_by_puuid: dict[str, list] = {}

#create a set of PUUIDs to compare with the existing PUUIDs in the JSON file
puuid_set = set(puuids)
completed = {k for k in match_ids_by_puuid.keys() if k in puuid_set}
remaining_puuids = [p for p in puuids if p not in completed]

#print the number of PUUIDs that have already been completed and the number of PUUIDs that are remaining to be completed
total_puuids = len(puuids)
remaining_total = len(remaining_puuids)
print(f"Already completed: {len(completed)} / {total_puuids}")
print(f"Remaining this run: {remaining_total}")

#set the headers for the API request
headers = {
    "X-Riot-Token": api_key,
    "User-Agent": "HCDE530-A5/1.0 (match-v5 by-puuid; coursework)",
}
base_url = "https://americas.api.riotgames.com/lol/match/v5/matches/by-puuid" #endpoint for fetching match IDs by PUUID

#loop through the remaining PUUIDs and fetch the match IDs
for step_idx, puuid in enumerate(remaining_puuids, start=1):
    safe_puuid = urllib.parse.quote(puuid, safe="")
    query = urllib.parse.urlencode(
        {"start": MATCH_IDS_START, "count": MATCH_IDS_COUNT, "queue": QUEUE_ID} #parameters for the API request
    )
    url = f"{base_url}/{safe_puuid}/ids?{query}" #construct the URL for the API request
    req = urllib.request.Request(url, headers=headers) #send the request to the API

    try:
        with urllib.request.urlopen(req, timeout=30) as resp: 
            match_ids = json.load(resp)
    except urllib.error.HTTPError as e:
        body = e.read().decode(errors="replace")
        if e.code == 429:
            time.sleep(60)
            with urllib.request.urlopen(req, timeout=30) as resp:
                match_ids = json.load(resp)
        else:
            raise RuntimeError(f"HTTP {e.code} {e.reason}: {body[:500]}") from e

    match_ids_by_puuid[puuid] = match_ids #add the match IDs to the dictionary

    # Checkpoint after each success so reruns can resume where this run left off.
    with open(out_path, "w", encoding="utf-8") as f:
        json.dump(match_ids_by_puuid, f, ensure_ascii=False, indent=2)

    processed_now = step_idx
    processed_total = len(completed) + processed_now
    print(
        f"PUUIDs processed this run: {processed_now} / {remaining_total} | "
        f"overall: {processed_total} / {total_puuids}",
        flush=True,
    )
    time.sleep(REQUEST_SLEEP_SEC) #wait 2 seconds between requests to avoid overwhelming the server

print(f"Done. Saved {len(match_ids_by_puuid)} PUUID entries to {out_path.resolve()}") #print the number of PUUIDs that have been processed and the total number of PUUIDs that have been processed
# Out:
# Already completed: 480 / 500
# Remaining this run: 20
# PUUIDs processed this run: 1 / 20 | overall: 481 / 500
# PUUIDs processed this run: 2 / 20 | overall: 482 / 500
# PUUIDs processed this run: 3 / 20 | overall: 483 / 500
# PUUIDs processed this run: 4 / 20 | overall: 484 / 500
# PUUIDs processed this run: 5 / 20 | overall: 485 / 500
# PUUIDs processed this run: 6 / 20 | overall: 486 / 500
# PUUIDs processed this run: 7 / 20 | overall: 487 / 500
# PUUIDs processed this run: 8 / 20 | overall: 488 / 500
# PUUIDs processed this run: 9 / 20 | overall: 489 / 500
# PUUIDs processed this run: 10 / 20 | overall: 490 / 500
# PUUIDs processed this run: 11 / 20 | overall: 491 / 500
# PUUIDs processed this run: 12 / 20 | overall: 492 / 500
# PUUIDs processed this run: 13 / 20 | overall: 493 / 500
# PUUIDs processed this run: 14 / 20 | overall: 494 / 500
# PUUIDs processed this run: 15 / 20 | overall: 495 / 500
# PUUIDs processed this run: 16 / 20 | overall: 496 / 500
# PUUIDs processed this run: 17 / 20 | overall: 497 / 500
# PUUIDs processed this run: 18 / 20 | overall: 498 / 500
# PUUIDs processed this run: 19 / 20 | overall: 499 / 500
# PUUIDs processed this run: 20 / 20 | overall: 500 / 500
# Done. Saved 500 PUUID entries to /Users/ruofuli/hcde530/Week 5/match_ids_by_puuid.json

# %% [markdown]
# #### 6a. Converting Match ID JSON to usable dataframe
# Similar to the initial dataframe that allowed us to extract the PUUIDs, now we need to convert the Match IDs JSON into a usable dataframe for Pandas Analysis.

# %%
from pathlib import Path
import json

# Find the match-id checkpoint file using relative fallbacks.
match_candidates = [
    Path("match_ids_by_puuid.json"),
    Path("Week 5") / "match_ids_by_puuid.json",
    Path("..") / "Week 5" / "match_ids_by_puuid.json",
]
match_path = next((p for p in match_candidates if p.is_file()), None)
if match_path is None:
    raise FileNotFoundError( #debugging flag in case match_ids_by_puuid.json is not found
        "match_ids_by_puuid.json not found. Tried: " + ", ".join(str(p) for p in match_candidates)
    )

#load the match_ids_by_puuid.json file
with open(match_path, encoding="utf-8") as f:
    match_ids_by_puuid = json.load(f)

if not isinstance(match_ids_by_puuid, dict):
    raise TypeError("match_ids_by_puuid.json should contain an object mapping puuid -> list[match_id].")

# Flatten dict-of-lists into row records for pandas.
rows = []
for puuid, match_ids in match_ids_by_puuid.items():
    if not isinstance(match_ids, list):
        continue
    for match_id in match_ids:
        rows.append({"puuid": puuid, "match_id": match_id})

matches_df = pd.DataFrame(rows) #convert the match_ids_by_puuid.json file into a dataframe

print("Loaded:", match_path.resolve())
print("shape (rows, columns):", matches_df.shape)
print("unique PUUIDs:", matches_df["puuid"].nunique() if not matches_df.empty else 0)
print("unique match IDs:", matches_df["match_id"].nunique() if not matches_df.empty else 0)
matches_df.head()
# Out:
# Loaded: /Users/ruofuli/hcde530/Week 5/match_ids_by_puuid.json
# shape (rows, columns): (4831, 2)
# unique PUUIDs: 500
# unique match IDs: 4825
#                                                puuid        match_id
# 0  dmr_PvsJDqRYwdOsAvRCGlp5676GgstHkcKjev1N03OTVQ...  NA1_5550304472
# 1  dmr_PvsJDqRYwdOsAvRCGlp5676GgstHkcKjev1N03OTVQ...  NA1_5545162641
# 2  dmr_PvsJDqRYwdOsAvRCGlp5676GgstHkcKjev1N03OTVQ...  NA1_5530609519
# 3  dmr_PvsJDqRYwdOsAvRCGlp5676GgstHkcKjev1N03OTVQ...  NA1_5530552256
# 4  dmr_PvsJDqRYwdOsAvRCGlp5676GgstHkcKjev1N03OTVQ...  NA1_5530519318

# %% [markdown]
# ---
# ### 7. Analyzing the Match ID dataframe (named `matches_df) using Pandas Analysis
# #### 7a. How many repeated Match IDs are there? With `matches_df.duplicated` and `matches_df["match_id"].value_counts()`
# It makes sense if there are repeated Match IDs, because it's entirely possible that some of these players played against each other in multiple matches. However, because we want to eventually find out which Support role champion has the highest pick rate, it's best to (once again) deduplicate our repeated Match IDs to avoid skewing our data.

# %%
if "matches_df" not in globals():
    raise RuntimeError("Run section 6a first so matches_df exists.")

# Count duplicate rows by match_id (all repeats beyond the first occurrence).
duplicate_match_rows = matches_df.duplicated(subset=["match_id"]).sum()

# Count how many distinct match IDs appear more than once.
match_id_counts = matches_df["match_id"].value_counts()
repeated_match_id_count = (match_id_counts > 1).sum()

print("Total rows:", len(matches_df))
print("Unique match IDs:", matches_df["match_id"].nunique())
print("Duplicate match-ID rows:", duplicate_match_rows)
print("Distinct match IDs that are repeated:", repeated_match_id_count)

# Optional: preview top repeated match IDs.
match_id_counts[match_id_counts > 1].head(10)
# Out:
# Total rows: 4831
# Unique match IDs: 4825
# Duplicate match-ID rows: 6
# Distinct match IDs that are repeated: 6
# match_id
# NA1_5553492411    2
# NA1_5553880975    2
# NA1_5477932306    2
# NA1_5515936514    2
# NA1_5554756967    2
# NA1_5554481168    2
# Name: count, dtype: int64

# %% [markdown]
# Honestly, super surprised that only 6 Match IDs were repeated. This means that across the 10 most recent games (as of the snapshot taken on May 6, 2026) from the 500 player sample size I used, only 12 of these entries appeared in the same match with 1 other entry in this sample.
#
# Now I'm curious...
#
# #### 7b. Which of these PUUIDs shared the same Match ID? With `matches_df.groupby("match_id")["puuid"]`

# %%
if "matches_df" not in globals():
    raise RuntimeError("Run section 6a first so matches_df exists.")

# Show match IDs that were linked to more than one PUUID, plus the PUUIDs in each shared match.
shared_match_puuids = (
    matches_df.groupby("match_id")["puuid"]
    .agg(lambda s: sorted(set(s)))
    .reset_index(name="puuids")
)
shared_match_puuids["puuid_count"] = shared_match_puuids["puuids"].str.len() #count the number of PUUIDs in each match
shared_match_puuids = shared_match_puuids[shared_match_puuids["puuid_count"] > 1] #only keep the matches that have more than 1 PUUID
shared_match_puuids = shared_match_puuids.sort_values("puuid_count", ascending=False) #sort the matches by the number of PUUIDs in descending order

print("match IDs shared by multiple PUUIDs:", len(shared_match_puuids))
shared_match_puuids.head(20)

# One row per (match_id, puuid) pair for easier filtering/export.
shared_match_pairs = shared_match_puuids[["match_id", "puuids"]].explode("puuids")#explode the PUUIDs into separate rows
shared_match_pairs = shared_match_pairs.rename(columns={"puuids": "puuid"}) #rename the PUUID column to "puuid"
shared_match_pairs.head(20) #first 20 entries but there's only 12 rows in total
# Out:
# match IDs shared by multiple PUUIDs: 6
#             match_id                                              puuid
# 1169  NA1_5477932306  kM2Q35kVATyg_-g2p4hucag6ZSM57O8VIIs6rJKO4rH3sw...
# 1169  NA1_5477932306  romsuHz5QKq_XUkx7N4qKPjoc2vD4VHsbgFlGeBlmYyufv...
# 2463  NA1_5515936514  N5ad-8s5iKPYbF14er-6c8TcorXz5JpAkWZ4jZjbcSeR-Y...
# 2463  NA1_5515936514  gbLR3Z4L37vx7U3zu5hYHsFHCjFg9seX5KGXOTTchCkdYJ...
# 4329  NA1_5553492411  FFuw8Efm1P2O9fvvt_xSrn9kOfHI5EaaGnFTBJ3sTN0PnD...
# 4329  NA1_5553492411  eoraV-WPRU9WFjZV_MR7t-6ArYKxPMi3wwRHn7tByfnNiT...
# 4418  NA1_5553880975  HBEhi9sBqE7VqfS1OmK6UcJ-0K6ob-_1LYQ6Q-jVzrH2e9...
# 4418  NA1_5553880975  lAMJFfS183Y5omawvwncjvaJiOBSOMeDaJZD2dv-8IdtQ2...
# 4585  NA1_5554481168  44QNoWysHHA5AjcZ3gmo05AdxqNQGYeV0Bz5vqrUcxqewd...
# 4585  NA1_5554481168  EmW71KcXaKFFJih3Y2F2Hbuq1ls3-4PFU3-F5jixCeIdlO...
# 4685  NA1_5554756967  FPNJo2T8taVm5fnE9VndYM5kFv-zM3fTPkx7CwmT1sdEM2...
# 4685  NA1_5554756967  RM85rpEjVbNejT5Cw7ZUxMZ4FBPLxR0sbmHbmv9kaXInb1...

# %% [markdown]
# #### 7c. Deduplicating repeated Match IDs
# Back to business. As mentioned in 7a, every Match ID has to be unique to avoid skewing the data when we have to analyze it later.

# %%
if "matches_df" not in globals():
    raise RuntimeError("Run section 6a first so matches_df exists.")

rows_before = len(matches_df)

# Deduplicate by match_id so each match contributes only once to later analysis.
matches_df_deduped = matches_df.drop_duplicates(subset=["match_id"], keep="first").copy()

rows_after = len(matches_df_deduped)#number of rows in the deduplicated dataframe
removed = rows_before - rows_after #number of rows removed from the deduplicated dataframe

print("rows before dedupe:", rows_before)
print("rows after dedupe:", rows_after)
print("duplicate rows removed:", removed)
print("remaining duplicate match IDs:", matches_df_deduped.duplicated(subset=["match_id"]).sum())

# Save deduped match IDs for downstream scripts/notebooks.
match_deduped_candidates = [
    Path("matches_df_deduped.json"), #possible file paths to find the deduplicated dataframe for match IDs
    Path("Week 5") / "matches_df_deduped.json",
    Path("..") / "Week 5" / "matches_df_deduped.json",
]
match_deduped_out = next((p for p in match_deduped_candidates if p.parent.exists()), match_deduped_candidates[0]) #find the first file path that exists
matches_df_deduped.to_json(match_deduped_out, orient="records", indent=2) #save the deduplicated dataframe to the file path
print("Saved deduped match DataFrame to:", match_deduped_out.resolve()) #print the file path of the deduplicated dataframe

matches_df_deduped.head()
# Out:
# rows before dedupe: 4831
# rows after dedupe: 4825
# duplicate rows removed: 6
# remaining duplicate match IDs: 0
# Saved deduped match DataFrame to: /Users/ruofuli/hcde530/Week 5/matches_df_deduped.json
#                                                puuid        match_id
# 0  dmr_PvsJDqRYwdOsAvRCGlp5676GgstHkcKjev1N03OTVQ...  NA1_5550304472
# 1  dmr_PvsJDqRYwdOsAvRCGlp5676GgstHkcKjev1N03OTVQ...  NA1_5545162641
# 2  dmr_PvsJDqRYwdOsAvRCGlp5676GgstHkcKjev1N03OTVQ...  NA1_5530609519
# 3  dmr_PvsJDqRYwdOsAvRCGlp5676GgstHkcKjev1N03OTVQ...  NA1_5530552256
# 4  dmr_PvsJDqRYwdOsAvRCGlp5676GgstHkcKjev1N03OTVQ...  NA1_5530519318

# %% [markdown]
# While I was expecting 5000 initial rows, there ended up being less because some players didn't play enough Ranked games to fill up all 10 spots.

# %% [markdown]
# ---
# ### 8. Using stored Match IDs to fetch data for Champion Picks
# In our third and final API that we'll be calling to answer our analytical questions, we'll be using the Match IDs stored in the deduped JSON file in another endpoint that fetches data for which champions were selected per Match ID.
#
# Similar to the transition from PUUIDs to Match IDs, I will be unable to cycle through all of the Match IDs that were fetched previously due to API request limits. As a result, the code below will only cycle through the first 500 Match IDs that appear in the JSON file, which equals to about 50 players.
#
# Each Match ID is going to return a lot of fields, so we'll have to do some further data cleaning after to extract the fields that we actually care about; namely, the 10 champion picks for the game, 5 from each team. The game doesn't allow for repeated champion picks (at least in Ranked), so each champion should be unique.

# %%
import json
import os
import time
import urllib.error
import urllib.parse
import urllib.request
from pathlib import Path

MATCH_ID_OFFSET = 500  # skip first N unique IDs (already fetched)
MAX_MATCH_IDS = 1000  # fetch this many unique IDs after the offset
REQUEST_SLEEP_SEC = 2.0  # increase if you get HTTP 429


def _load_env(path: Path) -> None:
    if not path.is_file():
        return
    for line in path.read_text().splitlines():
        line = line.strip()
        if not line or line.startswith("#") or "=" not in line:
            continue
        key, _, val = line.partition("=")
        key, val = key.strip(), val.strip().strip('"').strip("'")
        if key:
            os.environ.setdefault(key, val)


def _extract_champion_picks(match_data: dict) -> list[dict]:
    """Pull champion/role fields from info.participants for one match."""
    participants = match_data.get("info", {}).get("participants", [])
    picks = []
    for p in participants:
        if not isinstance(p, dict):
            continue
        picks.append(
            {
                "puuid": p.get("puuid"),
                "championId": p.get("championId"),
                "championName": p.get("championName"),
                "teamId": p.get("teamId"),
                "teamPosition": p.get("teamPosition"),
                "individualPosition": p.get("individualPosition"),
                "win": p.get("win"),
            }
        )
    return picks


for _env in (Path(".env"), Path("Week 5") / ".env"):
    _load_env(_env)

api_key = os.environ.get("RIOT_API_KEY", "").strip()
if not api_key:
    raise ValueError("RIOT_API_KEY missing: add it to Week 5/.env or set it in the environment.")

deduped_candidates = [
    Path("matches_df_deduped.json"),
    Path("Week 5") / "matches_df_deduped.json",
    Path("..") / "Week 5" / "matches_df_deduped.json",
]
deduped_path = next((p for p in deduped_candidates if p.is_file()), None)
if deduped_path is None:
    raise FileNotFoundError(
        "matches_df_deduped.json not found. Tried: " + ", ".join(str(p) for p in deduped_candidates)
    )

with open(deduped_path, encoding="utf-8") as f:
    deduped_records = json.load(f)

if not isinstance(deduped_records, list):
    raise TypeError("matches_df_deduped.json should contain a JSON array of records.")

seen: set[str] = set()
all_unique_match_ids: list[str] = []
for row in deduped_records:
    mid = row.get("match_id") if isinstance(row, dict) else None
    if not mid or mid in seen:
        continue
    seen.add(mid)
    all_unique_match_ids.append(str(mid))

match_ids = all_unique_match_ids[MATCH_ID_OFFSET : MATCH_ID_OFFSET + MAX_MATCH_IDS]
if len(all_unique_match_ids) < MATCH_ID_OFFSET:
    raise ValueError(
        f"Only {len(all_unique_match_ids)} unique match IDs in deduped file; "
        f"need at least {MATCH_ID_OFFSET} to start this batch."
    )
if len(match_ids) < MAX_MATCH_IDS:
    print(
        f"Warning: only {len(match_ids)} IDs available after offset "
        f"(wanted {MAX_MATCH_IDS})."
    )

out_candidates = [
    Path("champion_picks_by_match_id.json"),
    Path("Week 5") / "champion_picks_by_match_id.json",
    Path("..") / "Week 5" / "champion_picks_by_match_id.json",
]
out_path = next((p for p in out_candidates if p.parent.exists()), out_candidates[0])

if out_path.is_file():
    with open(out_path, encoding="utf-8") as f:
        existing = json.load(f)
    if not isinstance(existing, dict):
        raise TypeError("champion_picks_by_match_id.json should be a JSON object keyed by match_id.")
    champion_picks_by_match_id: dict[str, list] = existing
else:
    champion_picks_by_match_id = {}

completed = {mid for mid in match_ids if mid in champion_picks_by_match_id}
remaining_match_ids = [mid for mid in match_ids if mid not in completed]

total_match_ids = len(match_ids)
remaining_total = len(remaining_match_ids)
print("Loaded match list from:", deduped_path.resolve())
print(
    f"Batch: unique IDs {MATCH_ID_OFFSET + 1}–{MATCH_ID_OFFSET + total_match_ids} "
    f"(offset {MATCH_ID_OFFSET}, count {total_match_ids})"
)
print("Already completed in this batch:", len(completed), "/", total_match_ids)
print("Remaining this run:", remaining_total)
print("Checkpoint file:", out_path.resolve())

headers = {
    "X-Riot-Token": api_key,
    "User-Agent": "HCDE530-A5/1.0 (match-v5 champion picks; coursework)",
}
base_url = "https://americas.api.riotgames.com/lol/match/v5/matches"

for step_idx, match_id in enumerate(remaining_match_ids, start=1):
    safe_match_id = urllib.parse.quote(match_id, safe="")
    url = f"{base_url}/{safe_match_id}"
    req = urllib.request.Request(url, headers=headers)

    try:
        with urllib.request.urlopen(req, timeout=30) as resp:
            match_data = json.load(resp)
    except urllib.error.HTTPError as e:
        body = e.read().decode(errors="replace")
        if e.code == 429:
            time.sleep(60)
            with urllib.request.urlopen(req, timeout=30) as resp:
                match_data = json.load(resp)
        else:
            raise RuntimeError(f"HTTP {e.code} {e.reason}: {body[:500]}") from e

    champion_picks_by_match_id[match_id] = _extract_champion_picks(match_data)

    with open(out_path, "w", encoding="utf-8") as f:
        json.dump(champion_picks_by_match_id, f, ensure_ascii=False, indent=2)

    processed_now = step_idx
    processed_total = len(completed) + processed_now
    print(
        f"Match IDs processed this run: {processed_now} / {remaining_total} | "
        f"overall: {processed_total} / {total_match_ids}",
        flush=True,
    )
    time.sleep(REQUEST_SLEEP_SEC)

print(f"Done. Saved champion picks for {len(champion_picks_by_match_id)} matches to {out_path.resolve()}")
# Out:
# Loaded match list from: /Users/ruofuli/hcde530/Week 5/matches_df_deduped.json
# Batch: unique IDs 501–1500 (offset 500, count 1000)
# Already completed in this batch: 0 / 1000
# Remaining this run: 1000
# Checkpoint file: /Users/ruofuli/hcde530/Week 5/champion_picks_by_match_id.json
# Match IDs processed this run: 1 / 1000 | overall: 1 / 1000
# Match IDs processed this run: 2 / 1000 | overall: 2 / 1000
# Match IDs processed this run: 3 / 1000 | overall: 3 / 1000
# Match IDs processed this run: 4 / 1000 | overall: 4 / 1000
# Match IDs processed this run: 5 / 1000 | overall: 5 / 1000
# Match IDs processed this run: 6 / 1000 | overall: 6 / 1000
# Match IDs processed this run: 7 / 1000 | overall: 7 / 1000
# Match IDs processed this run: 8 / 1000 | overall: 8 / 1000
# Match IDs processed this run: 9 / 1000 | overall: 9 / 1000
# Match IDs processed this run: 10 / 1000 | overall: 10 / 1000
# Match IDs processed this run: 11 / 1000 | overall: 11 / 1000
# Match IDs processed this run: 12 / 1000 | overall: 12 / 1000
# Match IDs processed this run: 13 / 1000 | overall: 13 / 1000
# Match IDs processed this run: 14 / 1000 | overall: 14 / 1000
# Match IDs processed this run: 15 / 1000 | overall: 15 / 1000
# Match IDs processed this run: 16 / 1000 | overall: 16 / 1000
# Match IDs processed this run: 17 / 1000 | overall: 17 / 1000
# Match IDs processed this run: 18 / 1000 | overall: 18 / 1000
# Match IDs processed this run: 19 / 1000 | overall: 19 / 1000
# Match IDs processed this run: 20 / 1000 | overall: 20 / 1000
# Match IDs processed this run: 21 / 1000 | overall: 21 / 1000
# Match IDs processed this run: 22 / 1000 | overall: 22 / 1000
# Match IDs processed this run: 23 / 1000 | overall: 23 / 1000
# Match IDs processed this run: 24 / 1000 | overall: 24 / 1000
# Match IDs processed this run: 25 / 1000 | overall: 25 / 1000
# Match IDs processed this run: 26 / 1000 | overall: 26 / 1000
# Match IDs processed this run: 27 / 1000 | overall: 27 / 1000
# Match IDs processed this run: 28 / 1000 | overall: 28 / 1000
# Match IDs processed this run: 29 / 1000 | overall: 29 / 1000
# Match IDs processed this run: 30 / 1000 | overall: 30 / 1000
# Match IDs processed this run: 31 / 1000 | overall: 31 / 1000
# Match IDs processed this run: 32 / 1000 | overall: 32 / 1000
# Match IDs processed this run: 33 / 1000 | overall: 33 / 1000
# Match IDs processed this run: 34 / 1000 | overall: 34 / 1000
# Match IDs processed this run: 35 / 1000 | overall: 35 / 1000
# Match IDs processed this run: 36 / 1000 | overall: 36 / 1000
# Match IDs processed this run: 37 / 1000 | overall: 37 / 1000
# Match IDs processed this run: 38 / 1000 | overall: 38 / 1000
# Match IDs processed this run: 39 / 1000 | overall: 39 / 1000
# Match IDs processed this run: 40 / 1000 | overall: 40 / 1000
# Match IDs processed this run: 41 / 1000 | overall: 41 / 1000
# Match IDs processed this run: 42 / 1000 | overall: 42 / 1000
# Match IDs processed this run: 43 / 1000 | overall: 43 / 1000
# Match IDs processed this run: 44 / 1000 | overall: 44 / 1000
# Match IDs processed this run: 45 / 1000 | overall: 45 / 1000
# Match IDs processed this run: 46 / 1000 | overall: 46 / 1000
# Match IDs processed this run: 47 / 1000 | overall: 47 / 1000
# Match IDs processed this run: 48 / 1000 | overall: 48 / 1000
# Match IDs processed this run: 49 / 1000 | overall: 49 / 1000
# Match IDs processed this run: 50 / 1000 | overall: 50 / 1000
# Match IDs processed this run: 51 / 1000 | overall: 51 / 1000
# Match IDs processed this run: 52 / 1000 | overall: 52 / 1000
# Match IDs processed this run: 53 / 1000 | overall: 53 / 1000
# Match IDs processed this run: 54 / 1000 | overall: 54 / 1000
# Match IDs processed this run: 55 / 1000 | overall: 55 / 1000
# Match IDs processed this run: 56 / 1000 | overall: 56 / 1000
# Match IDs processed this run: 57 / 1000 | overall: 57 / 1000
# Match IDs processed this run: 58 / 1000 | overall: 58 / 1000
# Match IDs processed this run: 59 / 1000 | overall: 59 / 1000
# Match IDs processed this run: 60 / 1000 | overall: 60 / 1000
# Match IDs processed this run: 61 / 1000 | overall: 61 / 1000
# Match IDs processed this run: 62 / 1000 | overall: 62 / 1000
# Match IDs processed this run: 63 / 1000 | overall: 63 / 1000
# Match IDs processed this run: 64 / 1000 | overall: 64 / 1000
# Match IDs processed this run: 65 / 1000 | overall: 65 / 1000
# Match IDs processed this run: 66 / 1000 | overall: 66 / 1000
# Match IDs processed this run: 67 / 1000 | overall: 67 / 1000
# Match IDs processed this run: 68 / 1000 | overall: 68 / 1000
# Match IDs processed this run: 69 / 1000 | overall: 69 / 1000
# Match IDs processed this run: 70 / 1000 | overall: 70 / 1000
# Match IDs processed this run: 71 / 1000 | overall: 71 / 1000
# Match IDs processed this run: 72 / 1000 | overall: 72 / 1000
# Match IDs processed this run: 73 / 1000 | overall: 73 / 1000
# Match IDs processed this run: 74 / 1000 | overall: 74 / 1000
# Match IDs processed this run: 75 / 1000 | overall: 75 / 1000
# Match IDs processed this run: 76 / 1000 | overall: 76 / 1000
# Match IDs processed this run: 77 / 1000 | overall: 77 / 1000
# Match IDs processed this run: 78 / 1000 | overall: 78 / 1000
# Match IDs processed this run: 79 / 1000 | overall: 79 / 1000
# Match IDs processed this run: 80 / 1000 | overall: 80 / 1000
# Match IDs processed this run: 81 / 1000 | overall: 81 / 1000
# Match IDs processed this run: 82 / 1000 | overall: 82 / 1000
# Match IDs processed this run: 83 / 1000 | overall: 83 / 1000
# Match IDs processed this run: 84 / 1000 | overall: 84 / 1000
# Match IDs processed this run: 85 / 1000 | overall: 85 / 1000
# Match IDs processed this run: 86 / 1000 | overall: 86 / 1000
# Match IDs processed this run: 87 / 1000 | overall: 87 / 1000
# Match IDs processed this run: 88 / 1000 | overall: 88 / 1000
# Match IDs processed this run: 89 / 1000 | overall: 89 / 1000
# Match IDs processed this run: 90 / 1000 | overall: 90 / 1000
# Match IDs processed this run: 91 / 1000 | overall: 91 / 1000
# Match IDs processed this run: 92 / 1000 | overall: 92 / 1000
# Match IDs processed this run: 93 / 1000 | overall: 93 / 1000
# Match IDs processed this run: 94 / 1000 | overall: 94 / 1000
# Match IDs processed this run: 95 / 1000 | overall: 95 / 1000
# Match IDs processed this run: 96 / 1000 | overall: 96 / 1000
# Match IDs processed this run: 97 / 1000 | overall: 97 / 1000
# Match IDs processed this run: 98 / 1000 | overall: 98 / 1000
# Match IDs processed this run: 99 / 1000 | overall: 99 / 1000
# Match IDs processed this run: 100 / 1000 | overall: 100 / 1000
# Match IDs processed this run: 101 / 1000 | overall: 101 / 1000
# Match IDs processed this run: 102 / 1000 | overall: 102 / 1000
# Match IDs processed this run: 103 / 1000 | overall: 103 / 1000
# Match IDs processed this run: 104 / 1000 | overall: 104 / 1000
# Match IDs processed this run: 105 / 1000 | overall: 105 / 1000
# Match IDs processed this run: 106 / 1000 | overall: 106 / 1000
# Match IDs processed this run: 107 / 1000 | overall: 107 / 1000
# Match IDs processed this run: 108 / 1000 | overall: 108 / 1000
# Match IDs processed this run: 109 / 1000 | overall: 109 / 1000
# Match IDs processed this run: 110 / 1000 | overall: 110 / 1000
# Match IDs processed this run: 111 / 1000 | overall: 111 / 1000
# Match IDs processed this run: 112 / 1000 | overall: 112 / 1000
# Match IDs processed this run: 113 / 1000 | overall: 113 / 1000
# Match IDs processed this run: 114 / 1000 | overall: 114 / 1000
# Match IDs processed this run: 115 / 1000 | overall: 115 / 1000
# Match IDs processed this run: 116 / 1000 | overall: 116 / 1000
# Match IDs processed this run: 117 / 1000 | overall: 117 / 1000
# Match IDs processed this run: 118 / 1000 | overall: 118 / 1000
# Match IDs processed this run: 119 / 1000 | overall: 119 / 1000
# Match IDs processed this run: 120 / 1000 | overall: 120 / 1000
# Match IDs processed this run: 121 / 1000 | overall: 121 / 1000
# Match IDs processed this run: 122 / 1000 | overall: 122 / 1000
# Match IDs processed this run: 123 / 1000 | overall: 123 / 1000
# Match IDs processed this run: 124 / 1000 | overall: 124 / 1000
# Match IDs processed this run: 125 / 1000 | overall: 125 / 1000
# Match IDs processed this run: 126 / 1000 | overall: 126 / 1000
# Match IDs processed this run: 127 / 1000 | overall: 127 / 1000
# Match IDs processed this run: 128 / 1000 | overall: 128 / 1000
# Match IDs processed this run: 129 / 1000 | overall: 129 / 1000
# Match IDs processed this run: 130 / 1000 | overall: 130 / 1000
# Match IDs processed this run: 131 / 1000 | overall: 131 / 1000
# Match IDs processed this run: 132 / 1000 | overall: 132 / 1000
# Match IDs processed this run: 133 / 1000 | overall: 133 / 1000
# Match IDs processed this run: 134 / 1000 | overall: 134 / 1000
# Match IDs processed this run: 135 / 1000 | overall: 135 / 1000
# Match IDs processed this run: 136 / 1000 | overall: 136 / 1000
# Match IDs processed this run: 137 / 1000 | overall: 137 / 1000
# Match IDs processed this run: 138 / 1000 | overall: 138 / 1000
# Match IDs processed this run: 139 / 1000 | overall: 139 / 1000
# Match IDs processed this run: 140 / 1000 | overall: 140 / 1000
# Match IDs processed this run: 141 / 1000 | overall: 141 / 1000
# Match IDs processed this run: 142 / 1000 | overall: 142 / 1000
# Match IDs processed this run: 143 / 1000 | overall: 143 / 1000
# Match IDs processed this run: 144 / 1000 | overall: 144 / 1000
# Match IDs processed this run: 145 / 1000 | overall: 145 / 1000
# Match IDs processed this run: 146 / 1000 | overall: 146 / 1000
# Match IDs processed this run: 147 / 1000 | overall: 147 / 1000
# Match IDs processed this run: 148 / 1000 | overall: 148 / 1000
# Match IDs processed this run: 149 / 1000 | overall: 149 / 1000
# Match IDs processed this run: 150 / 1000 | overall: 150 / 1000
# Match IDs processed this run: 151 / 1000 | overall: 151 / 1000
# Match IDs processed this run: 152 / 1000 | overall: 152 / 1000
# Match IDs processed this run: 153 / 1000 | overall: 153 / 1000
# Match IDs processed this run: 154 / 1000 | overall: 154 / 1000
# Match IDs processed this run: 155 / 1000 | overall: 155 / 1000
# Match IDs processed this run: 156 / 1000 | overall: 156 / 1000
# Match IDs processed this run: 157 / 1000 | overall: 157 / 1000
# Match IDs processed this run: 158 / 1000 | overall: 158 / 1000
# Match IDs processed this run: 159 / 1000 | overall: 159 / 1000
# Match IDs processed this run: 160 / 1000 | overall: 160 / 1000
# Match IDs processed this run: 161 / 1000 | overall: 161 / 1000
# Match IDs processed this run: 162 / 1000 | overall: 162 / 1000
# Match IDs processed this run: 163 / 1000 | overall: 163 / 1000
# Match IDs processed this run: 164 / 1000 | overall: 164 / 1000
# Match IDs processed this run: 165 / 1000 | overall: 165 / 1000
# Match IDs processed this run: 166 / 1000 | overall: 166 / 1000
# Match IDs processed this run: 167 / 1000 | overall: 167 / 1000
# Match IDs processed this run: 168 / 1000 | overall: 168 / 1000
# Match IDs processed this run: 169 / 1000 | overall: 169 / 1000
# Match IDs processed this run: 170 / 1000 | overall: 170 / 1000
# Match IDs processed this run: 171 / 1000 | overall: 171 / 1000
# Match IDs processed this run: 172 / 1000 | overall: 172 / 1000
# Match IDs processed this run: 173 / 1000 | overall: 173 / 1000
# Match IDs processed this run: 174 / 1000 | overall: 174 / 1000
# Match IDs processed this run: 175 / 1000 | overall: 175 / 1000
# Match IDs processed this run: 176 / 1000 | overall: 176 / 1000
# Match IDs processed this run: 177 / 1000 | overall: 177 / 1000
# Match IDs processed this run: 178 / 1000 | overall: 178 / 1000
# Match IDs processed this run: 179 / 1000 | overall: 179 / 1000
# Match IDs processed this run: 180 / 1000 | overall: 180 / 1000
# Match IDs processed this run: 181 / 1000 | overall: 181 / 1000
# Match IDs processed this run: 182 / 1000 | overall: 182 / 1000
# Match IDs processed this run: 183 / 1000 | overall: 183 / 1000
# Match IDs processed this run: 184 / 1000 | overall: 184 / 1000
# Match IDs processed this run: 185 / 1000 | overall: 185 / 1000
# Match IDs processed this run: 186 / 1000 | overall: 186 / 1000
# Match IDs processed this run: 187 / 1000 | overall: 187 / 1000
# Match IDs processed this run: 188 / 1000 | overall: 188 / 1000
# Match IDs processed this run: 189 / 1000 | overall: 189 / 1000
# Match IDs processed this run: 190 / 1000 | overall: 190 / 1000
# Match IDs processed this run: 191 / 1000 | overall: 191 / 1000
# Match IDs processed this run: 192 / 1000 | overall: 192 / 1000
# Match IDs processed this run: 193 / 1000 | overall: 193 / 1000
# Match IDs processed this run: 194 / 1000 | overall: 194 / 1000
# Match IDs processed this run: 195 / 1000 | overall: 195 / 1000
# Match IDs processed this run: 196 / 1000 | overall: 196 / 1000
# Match IDs processed this run: 197 / 1000 | overall: 197 / 1000
# Match IDs processed this run: 198 / 1000 | overall: 198 / 1000
# Match IDs processed this run: 199 / 1000 | overall: 199 / 1000
# Match IDs processed this run: 200 / 1000 | overall: 200 / 1000
# Match IDs processed this run: 201 / 1000 | overall: 201 / 1000
# Match IDs processed this run: 202 / 1000 | overall: 202 / 1000
# Match IDs processed this run: 203 / 1000 | overall: 203 / 1000
# Match IDs processed this run: 204 / 1000 | overall: 204 / 1000
# Match IDs processed this run: 205 / 1000 | overall: 205 / 1000
# Match IDs processed this run: 206 / 1000 | overall: 206 / 1000
# Match IDs processed this run: 207 / 1000 | overall: 207 / 1000
# Match IDs processed this run: 208 / 1000 | overall: 208 / 1000
# Match IDs processed this run: 209 / 1000 | overall: 209 / 1000
# Match IDs processed this run: 210 / 1000 | overall: 210 / 1000
# Match IDs processed this run: 211 / 1000 | overall: 211 / 1000
# Match IDs processed this run: 212 / 1000 | overall: 212 / 1000
# Match IDs processed this run: 213 / 1000 | overall: 213 / 1000
# Match IDs processed this run: 214 / 1000 | overall: 214 / 1000
# Match IDs processed this run: 215 / 1000 | overall: 215 / 1000
# Match IDs processed this run: 216 / 1000 | overall: 216 / 1000
# Match IDs processed this run: 217 / 1000 | overall: 217 / 1000
# Match IDs processed this run: 218 / 1000 | overall: 218 / 1000
# Match IDs processed this run: 219 / 1000 | overall: 219 / 1000
# Match IDs processed this run: 220 / 1000 | overall: 220 / 1000
# Match IDs processed this run: 221 / 1000 | overall: 221 / 1000
# Match IDs processed this run: 222 / 1000 | overall: 222 / 1000
# Match IDs processed this run: 223 / 1000 | overall: 223 / 1000
# Match IDs processed this run: 224 / 1000 | overall: 224 / 1000
# Match IDs processed this run: 225 / 1000 | overall: 225 / 1000
# Match IDs processed this run: 226 / 1000 | overall: 226 / 1000
# Match IDs processed this run: 227 / 1000 | overall: 227 / 1000
# Match IDs processed this run: 228 / 1000 | overall: 228 / 1000
# Match IDs processed this run: 229 / 1000 | overall: 229 / 1000
# Match IDs processed this run: 230 / 1000 | overall: 230 / 1000
# Match IDs processed this run: 231 / 1000 | overall: 231 / 1000
# Match IDs processed this run: 232 / 1000 | overall: 232 / 1000
# Match IDs processed this run: 233 / 1000 | overall: 233 / 1000
# Match IDs processed this run: 234 / 1000 | overall: 234 / 1000
# Match IDs processed this run: 235 / 1000 | overall: 235 / 1000
# Match IDs processed this run: 236 / 1000 | overall: 236 / 1000
# Match IDs processed this run: 237 / 1000 | overall: 237 / 1000
# Match IDs processed this run: 238 / 1000 | overall: 238 / 1000
# Match IDs processed this run: 239 / 1000 | overall: 239 / 1000
# Match IDs processed this run: 240 / 1000 | overall: 240 / 1000
# Match IDs processed this run: 241 / 1000 | overall: 241 / 1000
# Match IDs processed this run: 242 / 1000 | overall: 242 / 1000
# Match IDs processed this run: 243 / 1000 | overall: 243 / 1000
# Match IDs processed this run: 244 / 1000 | overall: 244 / 1000
# Match IDs processed this run: 245 / 1000 | overall: 245 / 1000
# Match IDs processed this run: 246 / 1000 | overall: 246 / 1000
# Match IDs processed this run: 247 / 1000 | overall: 247 / 1000
# Match IDs processed this run: 248 / 1000 | overall: 248 / 1000
# Match IDs processed this run: 249 / 1000 | overall: 249 / 1000
# Match IDs processed this run: 250 / 1000 | overall: 250 / 1000
# Match IDs processed this run: 251 / 1000 | overall: 251 / 1000
# Match IDs processed this run: 252 / 1000 | overall: 252 / 1000
# Match IDs processed this run: 253 / 1000 | overall: 253 / 1000
# Match IDs processed this run: 254 / 1000 | overall: 254 / 1000
# Match IDs processed this run: 255 / 1000 | overall: 255 / 1000
# Match IDs processed this run: 256 / 1000 | overall: 256 / 1000
# Match IDs processed this run: 257 / 1000 | overall: 257 / 1000
# Match IDs processed this run: 258 / 1000 | overall: 258 / 1000
# Match IDs processed this run: 259 / 1000 | overall: 259 / 1000
# Match IDs processed this run: 260 / 1000 | overall: 260 / 1000
# Match IDs processed this run: 261 / 1000 | overall: 261 / 1000
# Match IDs processed this run: 262 / 1000 | overall: 262 / 1000
# Match IDs processed this run: 263 / 1000 | overall: 263 / 1000
# Match IDs processed this run: 264 / 1000 | overall: 264 / 1000
# Match IDs processed this run: 265 / 1000 | overall: 265 / 1000
# Match IDs processed this run: 266 / 1000 | overall: 266 / 1000
# Match IDs processed this run: 267 / 1000 | overall: 267 / 1000
# Match IDs processed this run: 268 / 1000 | overall: 268 / 1000
# Match IDs processed this run: 269 / 1000 | overall: 269 / 1000
# Match IDs processed this run: 270 / 1000 | overall: 270 / 1000
# Match IDs processed this run: 271 / 1000 | overall: 271 / 1000
# Match IDs processed this run: 272 / 1000 | overall: 272 / 1000
# Match IDs processed this run: 273 / 1000 | overall: 273 / 1000
# Match IDs processed this run: 274 / 1000 | overall: 274 / 1000
# Match IDs processed this run: 275 / 1000 | overall: 275 / 1000
# Match IDs processed this run: 276 / 1000 | overall: 276 / 1000
# Match IDs processed this run: 277 / 1000 | overall: 277 / 1000
# Match IDs processed this run: 278 / 1000 | overall: 278 / 1000
# Match IDs processed this run: 279 / 1000 | overall: 279 / 1000
# Match IDs processed this run: 280 / 1000 | overall: 280 / 1000
# Match IDs processed this run: 281 / 1000 | overall: 281 / 1000
# Match IDs processed this run: 282 / 1000 | overall: 282 / 1000
# Match IDs processed this run: 283 / 1000 | overall: 283 / 1000
# Match IDs processed this run: 284 / 1000 | overall: 284 / 1000
# Match IDs processed this run: 285 / 1000 | overall: 285 / 1000
# Match IDs processed this run: 286 / 1000 | overall: 286 / 1000
# Match IDs processed this run: 287 / 1000 | overall: 287 / 1000
# Match IDs processed this run: 288 / 1000 | overall: 288 / 1000
# Match IDs processed this run: 289 / 1000 | overall: 289 / 1000
# Match IDs processed this run: 290 / 1000 | overall: 290 / 1000
# Match IDs processed this run: 291 / 1000 | overall: 291 / 1000
# Match IDs processed this run: 292 / 1000 | overall: 292 / 1000
# Match IDs processed this run: 293 / 1000 | overall: 293 / 1000
# Match IDs processed this run: 294 / 1000 | overall: 294 / 1000
# Match IDs processed this run: 295 / 1000 | overall: 295 / 1000
# Match IDs processed this run: 296 / 1000 | overall: 296 / 1000
# Match IDs processed this run: 297 / 1000 | overall: 297 / 1000
# Match IDs processed this run: 298 / 1000 | overall: 298 / 1000
# Match IDs processed this run: 299 / 1000 | overall: 299 / 1000
# Match IDs processed this run: 300 / 1000 | overall: 300 / 1000
# Match IDs processed this run: 301 / 1000 | overall: 301 / 1000
# Match IDs processed this run: 302 / 1000 | overall: 302 / 1000
# Match IDs processed this run: 303 / 1000 | overall: 303 / 1000
# Match IDs processed this run: 304 / 1000 | overall: 304 / 1000
# Match IDs processed this run: 305 / 1000 | overall: 305 / 1000
# Match IDs processed this run: 306 / 1000 | overall: 306 / 1000
# Match IDs processed this run: 307 / 1000 | overall: 307 / 1000
# Match IDs processed this run: 308 / 1000 | overall: 308 / 1000
# Match IDs processed this run: 309 / 1000 | overall: 309 / 1000
# Match IDs processed this run: 310 / 1000 | overall: 310 / 1000
# Match IDs processed this run: 311 / 1000 | overall: 311 / 1000
# Match IDs processed this run: 312 / 1000 | overall: 312 / 1000
# Match IDs processed this run: 313 / 1000 | overall: 313 / 1000
# Match IDs processed this run: 314 / 1000 | overall: 314 / 1000
# Match IDs processed this run: 315 / 1000 | overall: 315 / 1000
# Match IDs processed this run: 316 / 1000 | overall: 316 / 1000
# Match IDs processed this run: 317 / 1000 | overall: 317 / 1000
# Match IDs processed this run: 318 / 1000 | overall: 318 / 1000
# Match IDs processed this run: 319 / 1000 | overall: 319 / 1000
# Match IDs processed this run: 320 / 1000 | overall: 320 / 1000
# Match IDs processed this run: 321 / 1000 | overall: 321 / 1000
# Match IDs processed this run: 322 / 1000 | overall: 322 / 1000
# Match IDs processed this run: 323 / 1000 | overall: 323 / 1000
# Match IDs processed this run: 324 / 1000 | overall: 324 / 1000
# Match IDs processed this run: 325 / 1000 | overall: 325 / 1000
# Match IDs processed this run: 326 / 1000 | overall: 326 / 1000
# Match IDs processed this run: 327 / 1000 | overall: 327 / 1000
# Match IDs processed this run: 328 / 1000 | overall: 328 / 1000
# Match IDs processed this run: 329 / 1000 | overall: 329 / 1000
# Match IDs processed this run: 330 / 1000 | overall: 330 / 1000
# Match IDs processed this run: 331 / 1000 | overall: 331 / 1000
# Match IDs processed this run: 332 / 1000 | overall: 332 / 1000
# Match IDs processed this run: 333 / 1000 | overall: 333 / 1000
# Match IDs processed this run: 334 / 1000 | overall: 334 / 1000
# Match IDs processed this run: 335 / 1000 | overall: 335 / 1000
# Match IDs processed this run: 336 / 1000 | overall: 336 / 1000
# Match IDs processed this run: 337 / 1000 | overall: 337 / 1000
# Match IDs processed this run: 338 / 1000 | overall: 338 / 1000
# Match IDs processed this run: 339 / 1000 | overall: 339 / 1000
# Match IDs processed this run: 340 / 1000 | overall: 340 / 1000
# Match IDs processed this run: 341 / 1000 | overall: 341 / 1000
# Match IDs processed this run: 342 / 1000 | overall: 342 / 1000
# Match IDs processed this run: 343 / 1000 | overall: 343 / 1000
# Match IDs processed this run: 344 / 1000 | overall: 344 / 1000
# Match IDs processed this run: 345 / 1000 | overall: 345 / 1000
# Match IDs processed this run: 346 / 1000 | overall: 346 / 1000
# Match IDs processed this run: 347 / 1000 | overall: 347 / 1000
# Match IDs processed this run: 348 / 1000 | overall: 348 / 1000
# Match IDs processed this run: 349 / 1000 | overall: 349 / 1000
# Match IDs processed this run: 350 / 1000 | overall: 350 / 1000
# Match IDs processed this run: 351 / 1000 | overall: 351 / 1000
# Match IDs processed this run: 352 / 1000 | overall: 352 / 1000
# Match IDs processed this run: 353 / 1000 | overall: 353 / 1000
# Match IDs processed this run: 354 / 1000 | overall: 354 / 1000
# Match IDs processed this run: 355 / 1000 | overall: 355 / 1000
# Match IDs processed this run: 356 / 1000 | overall: 356 / 1000
# Match IDs processed this run: 357 / 1000 | overall: 357 / 1000
# Match IDs processed this run: 358 / 1000 | overall: 358 / 1000
# Match IDs processed this run: 359 / 1000 | overall: 359 / 1000
# Match IDs processed this run: 360 / 1000 | overall: 360 / 1000
# Match IDs processed this run: 361 / 1000 | overall: 361 / 1000
# Match IDs processed this run: 362 / 1000 | overall: 362 / 1000
# Match IDs processed this run: 363 / 1000 | overall: 363 / 1000
# Match IDs processed this run: 364 / 1000 | overall: 364 / 1000
# Match IDs processed this run: 365 / 1000 | overall: 365 / 1000
# Match IDs processed this run: 366 / 1000 | overall: 366 / 1000
# Match IDs processed this run: 367 / 1000 | overall: 367 / 1000
# Match IDs processed this run: 368 / 1000 | overall: 368 / 1000
# Match IDs processed this run: 369 / 1000 | overall: 369 / 1000
# Match IDs processed this run: 370 / 1000 | overall: 370 / 1000
# Match IDs processed this run: 371 / 1000 | overall: 371 / 1000
# Match IDs processed this run: 372 / 1000 | overall: 372 / 1000
# Match IDs processed this run: 373 / 1000 | overall: 373 / 1000
# Match IDs processed this run: 374 / 1000 | overall: 374 / 1000
# Match IDs processed this run: 375 / 1000 | overall: 375 / 1000
# Match IDs processed this run: 376 / 1000 | overall: 376 / 1000
# Match IDs processed this run: 377 / 1000 | overall: 377 / 1000
# Match IDs processed this run: 378 / 1000 | overall: 378 / 1000
# Match IDs processed this run: 379 / 1000 | overall: 379 / 1000
# Match IDs processed this run: 380 / 1000 | overall: 380 / 1000
# Match IDs processed this run: 381 / 1000 | overall: 381 / 1000
# Match IDs processed this run: 382 / 1000 | overall: 382 / 1000
# Match IDs processed this run: 383 / 1000 | overall: 383 / 1000
# Match IDs processed this run: 384 / 1000 | overall: 384 / 1000
# Match IDs processed this run: 385 / 1000 | overall: 385 / 1000
# Match IDs processed this run: 386 / 1000 | overall: 386 / 1000
# Match IDs processed this run: 387 / 1000 | overall: 387 / 1000
# Match IDs processed this run: 388 / 1000 | overall: 388 / 1000
# Match IDs processed this run: 389 / 1000 | overall: 389 / 1000
# Match IDs processed this run: 390 / 1000 | overall: 390 / 1000
# Match IDs processed this run: 391 / 1000 | overall: 391 / 1000
# Match IDs processed this run: 392 / 1000 | overall: 392 / 1000
# Match IDs processed this run: 393 / 1000 | overall: 393 / 1000
# Match IDs processed this run: 394 / 1000 | overall: 394 / 1000
# Match IDs processed this run: 395 / 1000 | overall: 395 / 1000
# Match IDs processed this run: 396 / 1000 | overall: 396 / 1000
# Match IDs processed this run: 397 / 1000 | overall: 397 / 1000
# Match IDs processed this run: 398 / 1000 | overall: 398 / 1000
# Match IDs processed this run: 399 / 1000 | overall: 399 / 1000
# Match IDs processed this run: 400 / 1000 | overall: 400 / 1000
# Match IDs processed this run: 401 / 1000 | overall: 401 / 1000
# Match IDs processed this run: 402 / 1000 | overall: 402 / 1000
# Match IDs processed this run: 403 / 1000 | overall: 403 / 1000
# Match IDs processed this run: 404 / 1000 | overall: 404 / 1000
# Match IDs processed this run: 405 / 1000 | overall: 405 / 1000
# Match IDs processed this run: 406 / 1000 | overall: 406 / 1000
# Match IDs processed this run: 407 / 1000 | overall: 407 / 1000
# Match IDs processed this run: 408 / 1000 | overall: 408 / 1000
# Match IDs processed this run: 409 / 1000 | overall: 409 / 1000
# Match IDs processed this run: 410 / 1000 | overall: 410 / 1000
# Match IDs processed this run: 411 / 1000 | overall: 411 / 1000
# Match IDs processed this run: 412 / 1000 | overall: 412 / 1000
# Match IDs processed this run: 413 / 1000 | overall: 413 / 1000
# Match IDs processed this run: 414 / 1000 | overall: 414 / 1000
# Match IDs processed this run: 415 / 1000 | overall: 415 / 1000
# Match IDs processed this run: 416 / 1000 | overall: 416 / 1000
# Match IDs processed this run: 417 / 1000 | overall: 417 / 1000
# Match IDs processed this run: 418 / 1000 | overall: 418 / 1000
# Match IDs processed this run: 419 / 1000 | overall: 419 / 1000
# Match IDs processed this run: 420 / 1000 | overall: 420 / 1000
# Match IDs processed this run: 421 / 1000 | overall: 421 / 1000
# Match IDs processed this run: 422 / 1000 | overall: 422 / 1000
# Match IDs processed this run: 423 / 1000 | overall: 423 / 1000
# Match IDs processed this run: 424 / 1000 | overall: 424 / 1000
# Match IDs processed this run: 425 / 1000 | overall: 425 / 1000
# Match IDs processed this run: 426 / 1000 | overall: 426 / 1000
# Match IDs processed this run: 427 / 1000 | overall: 427 / 1000
# Match IDs processed this run: 428 / 1000 | overall: 428 / 1000
# Match IDs processed this run: 429 / 1000 | overall: 429 / 1000
# Match IDs processed this run: 430 / 1000 | overall: 430 / 1000
# Match IDs processed this run: 431 / 1000 | overall: 431 / 1000
# Match IDs processed this run: 432 / 1000 | overall: 432 / 1000
# Match IDs processed this run: 433 / 1000 | overall: 433 / 1000
# Match IDs processed this run: 434 / 1000 | overall: 434 / 1000
# Match IDs processed this run: 435 / 1000 | overall: 435 / 1000
# Match IDs processed this run: 436 / 1000 | overall: 436 / 1000
# Match IDs processed this run: 437 / 1000 | overall: 437 / 1000
# Match IDs processed this run: 438 / 1000 | overall: 438 / 1000
# Match IDs processed this run: 439 / 1000 | overall: 439 / 1000
# Match IDs processed this run: 440 / 1000 | overall: 440 / 1000
# Match IDs processed this run: 441 / 1000 | overall: 441 / 1000
# Match IDs processed this run: 442 / 1000 | overall: 442 / 1000
# Match IDs processed this run: 443 / 1000 | overall: 443 / 1000
# Match IDs processed this run: 444 / 1000 | overall: 444 / 1000
# Match IDs processed this run: 445 / 1000 | overall: 445 / 1000
# Match IDs processed this run: 446 / 1000 | overall: 446 / 1000
# Match IDs processed this run: 447 / 1000 | overall: 447 / 1000
# Match IDs processed this run: 448 / 1000 | overall: 448 / 1000
# Match IDs processed this run: 449 / 1000 | overall: 449 / 1000
# Match IDs processed this run: 450 / 1000 | overall: 450 / 1000
# Match IDs processed this run: 451 / 1000 | overall: 451 / 1000
# Match IDs processed this run: 452 / 1000 | overall: 452 / 1000
# Match IDs processed this run: 453 / 1000 | overall: 453 / 1000
# Match IDs processed this run: 454 / 1000 | overall: 454 / 1000
# Match IDs processed this run: 455 / 1000 | overall: 455 / 1000
# Match IDs processed this run: 456 / 1000 | overall: 456 / 1000
# Match IDs processed this run: 457 / 1000 | overall: 457 / 1000
# Match IDs processed this run: 458 / 1000 | overall: 458 / 1000
# Match IDs processed this run: 459 / 1000 | overall: 459 / 1000
# Match IDs processed this run: 460 / 1000 | overall: 460 / 1000
# Match IDs processed this run: 461 / 1000 | overall: 461 / 1000
# Match IDs processed this run: 462 / 1000 | overall: 462 / 1000
# Match IDs processed this run: 463 / 1000 | overall: 463 / 1000
# Match IDs processed this run: 464 / 1000 | overall: 464 / 1000
# Match IDs processed this run: 465 / 1000 | overall: 465 / 1000
# Match IDs processed this run: 466 / 1000 | overall: 466 / 1000
# Match IDs processed this run: 467 / 1000 | overall: 467 / 1000
# Match IDs processed this run: 468 / 1000 | overall: 468 / 1000
# Match IDs processed this run: 469 / 1000 | overall: 469 / 1000
# Match IDs processed this run: 470 / 1000 | overall: 470 / 1000
# Match IDs processed this run: 471 / 1000 | overall: 471 / 1000
# Match IDs processed this run: 472 / 1000 | overall: 472 / 1000
# Match IDs processed this run: 473 / 1000 | overall: 473 / 1000
# Match IDs processed this run: 474 / 1000 | overall: 474 / 1000
# Match IDs processed this run: 475 / 1000 | overall: 475 / 1000
# Match IDs processed this run: 476 / 1000 | overall: 476 / 1000
# Match IDs processed this run: 477 / 1000 | overall: 477 / 1000
# Match IDs processed this run: 478 / 1000 | overall: 478 / 1000
# Match IDs processed this run: 479 / 1000 | overall: 479 / 1000
# Match IDs processed this run: 480 / 1000 | overall: 480 / 1000
# Match IDs processed this run: 481 / 1000 | overall: 481 / 1000
# Match IDs processed this run: 482 / 1000 | overall: 482 / 1000
# Match IDs processed this run: 483 / 1000 | overall: 483 / 1000
# Match IDs processed this run: 484 / 1000 | overall: 484 / 1000
# Match IDs processed this run: 485 / 1000 | overall: 485 / 1000
# Match IDs processed this run: 486 / 1000 | overall: 486 / 1000
# Match IDs processed this run: 487 / 1000 | overall: 487 / 1000
# Match IDs processed this run: 488 / 1000 | overall: 488 / 1000
# Match IDs processed this run: 489 / 1000 | overall: 489 / 1000
# Match IDs processed this run: 490 / 1000 | overall: 490 / 1000
# Match IDs processed this run: 491 / 1000 | overall: 491 / 1000
# Match IDs processed this run: 492 / 1000 | overall: 492 / 1000
# Match IDs processed this run: 493 / 1000 | overall: 493 / 1000
# Match IDs processed this run: 494 / 1000 | overall: 494 / 1000
# Match IDs processed this run: 495 / 1000 | overall: 495 / 1000
# Match IDs processed this run: 496 / 1000 | overall: 496 / 1000
# Match IDs processed this run: 497 / 1000 | overall: 497 / 1000
# Match IDs processed this run: 498 / 1000 | overall: 498 / 1000
# Match IDs processed this run: 499 / 1000 | overall: 499 / 1000
# Match IDs processed this run: 500 / 1000 | overall: 500 / 1000
# Match IDs processed this run: 501 / 1000 | overall: 501 / 1000
# Match IDs processed this run: 502 / 1000 | overall: 502 / 1000
# Match IDs processed this run: 503 / 1000 | overall: 503 / 1000
# Match IDs processed this run: 504 / 1000 | overall: 504 / 1000
# Match IDs processed this run: 505 / 1000 | overall: 505 / 1000
# Match IDs processed this run: 506 / 1000 | overall: 506 / 1000
# Match IDs processed this run: 507 / 1000 | overall: 507 / 1000
# Match IDs processed this run: 508 / 1000 | overall: 508 / 1000
# Match IDs processed this run: 509 / 1000 | overall: 509 / 1000
# Match IDs processed this run: 510 / 1000 | overall: 510 / 1000
# Match IDs processed this run: 511 / 1000 | overall: 511 / 1000
# Match IDs processed this run: 512 / 1000 | overall: 512 / 1000
# Match IDs processed this run: 513 / 1000 | overall: 513 / 1000
# Match IDs processed this run: 514 / 1000 | overall: 514 / 1000
# Match IDs processed this run: 515 / 1000 | overall: 515 / 1000
# Match IDs processed this run: 516 / 1000 | overall: 516 / 1000
# Match IDs processed this run: 517 / 1000 | overall: 517 / 1000
# Match IDs processed this run: 518 / 1000 | overall: 518 / 1000
# Match IDs processed this run: 519 / 1000 | overall: 519 / 1000
# Match IDs processed this run: 520 / 1000 | overall: 520 / 1000
# Match IDs processed this run: 521 / 1000 | overall: 521 / 1000
# Match IDs processed this run: 522 / 1000 | overall: 522 / 1000
# Match IDs processed this run: 523 / 1000 | overall: 523 / 1000
# Match IDs processed this run: 524 / 1000 | overall: 524 / 1000
# Match IDs processed this run: 525 / 1000 | overall: 525 / 1000
# Match IDs processed this run: 526 / 1000 | overall: 526 / 1000
# Match IDs processed this run: 527 / 1000 | overall: 527 / 1000
# Match IDs processed this run: 528 / 1000 | overall: 528 / 1000
# Match IDs processed this run: 529 / 1000 | overall: 529 / 1000
# Match IDs processed this run: 530 / 1000 | overall: 530 / 1000
# Match IDs processed this run: 531 / 1000 | overall: 531 / 1000
# Match IDs processed this run: 532 / 1000 | overall: 532 / 1000
# Match IDs processed this run: 533 / 1000 | overall: 533 / 1000
# Match IDs processed this run: 534 / 1000 | overall: 534 / 1000
# Match IDs processed this run: 535 / 1000 | overall: 535 / 1000
# Match IDs processed this run: 536 / 1000 | overall: 536 / 1000
# Match IDs processed this run: 537 / 1000 | overall: 537 / 1000
# Match IDs processed this run: 538 / 1000 | overall: 538 / 1000
# Match IDs processed this run: 539 / 1000 | overall: 539 / 1000
# Match IDs processed this run: 540 / 1000 | overall: 540 / 1000
# Match IDs processed this run: 541 / 1000 | overall: 541 / 1000
# Match IDs processed this run: 542 / 1000 | overall: 542 / 1000
# Match IDs processed this run: 543 / 1000 | overall: 543 / 1000
# Match IDs processed this run: 544 / 1000 | overall: 544 / 1000
# Match IDs processed this run: 545 / 1000 | overall: 545 / 1000
# Match IDs processed this run: 546 / 1000 | overall: 546 / 1000
# Match IDs processed this run: 547 / 1000 | overall: 547 / 1000
# Match IDs processed this run: 548 / 1000 | overall: 548 / 1000
# Match IDs processed this run: 549 / 1000 | overall: 549 / 1000
# Match IDs processed this run: 550 / 1000 | overall: 550 / 1000
# Match IDs processed this run: 551 / 1000 | overall: 551 / 1000
# Match IDs processed this run: 552 / 1000 | overall: 552 / 1000
# Match IDs processed this run: 553 / 1000 | overall: 553 / 1000
# Match IDs processed this run: 554 / 1000 | overall: 554 / 1000
# Match IDs processed this run: 555 / 1000 | overall: 555 / 1000
# Match IDs processed this run: 556 / 1000 | overall: 556 / 1000
# Match IDs processed this run: 557 / 1000 | overall: 557 / 1000
# Match IDs processed this run: 558 / 1000 | overall: 558 / 1000
# Match IDs processed this run: 559 / 1000 | overall: 559 / 1000
# Match IDs processed this run: 560 / 1000 | overall: 560 / 1000
# Match IDs processed this run: 561 / 1000 | overall: 561 / 1000
# Match IDs processed this run: 562 / 1000 | overall: 562 / 1000
# Match IDs processed this run: 563 / 1000 | overall: 563 / 1000
# Match IDs processed this run: 564 / 1000 | overall: 564 / 1000
# Match IDs processed this run: 565 / 1000 | overall: 565 / 1000
# Match IDs processed this run: 566 / 1000 | overall: 566 / 1000
# Match IDs processed this run: 567 / 1000 | overall: 567 / 1000
# Match IDs processed this run: 568 / 1000 | overall: 568 / 1000
# Match IDs processed this run: 569 / 1000 | overall: 569 / 1000
# Match IDs processed this run: 570 / 1000 | overall: 570 / 1000
# Match IDs processed this run: 571 / 1000 | overall: 571 / 1000
# Match IDs processed this run: 572 / 1000 | overall: 572 / 1000
# Match IDs processed this run: 573 / 1000 | overall: 573 / 1000
# Match IDs processed this run: 574 / 1000 | overall: 574 / 1000
# Match IDs processed this run: 575 / 1000 | overall: 575 / 1000
# Match IDs processed this run: 576 / 1000 | overall: 576 / 1000
# Match IDs processed this run: 577 / 1000 | overall: 577 / 1000
# Match IDs processed this run: 578 / 1000 | overall: 578 / 1000
# Match IDs processed this run: 579 / 1000 | overall: 579 / 1000
# Match IDs processed this run: 580 / 1000 | overall: 580 / 1000
# Match IDs processed this run: 581 / 1000 | overall: 581 / 1000
# Match IDs processed this run: 582 / 1000 | overall: 582 / 1000
# Match IDs processed this run: 583 / 1000 | overall: 583 / 1000
# Match IDs processed this run: 584 / 1000 | overall: 584 / 1000
# Match IDs processed this run: 585 / 1000 | overall: 585 / 1000
# Match IDs processed this run: 586 / 1000 | overall: 586 / 1000
# Match IDs processed this run: 587 / 1000 | overall: 587 / 1000
# Match IDs processed this run: 588 / 1000 | overall: 588 / 1000
# Match IDs processed this run: 589 / 1000 | overall: 589 / 1000
# Match IDs processed this run: 590 / 1000 | overall: 590 / 1000
# Match IDs processed this run: 591 / 1000 | overall: 591 / 1000
# Match IDs processed this run: 592 / 1000 | overall: 592 / 1000
# Match IDs processed this run: 593 / 1000 | overall: 593 / 1000
# Match IDs processed this run: 594 / 1000 | overall: 594 / 1000
# Match IDs processed this run: 595 / 1000 | overall: 595 / 1000
# Match IDs processed this run: 596 / 1000 | overall: 596 / 1000
# Match IDs processed this run: 597 / 1000 | overall: 597 / 1000
# Match IDs processed this run: 598 / 1000 | overall: 598 / 1000
# Match IDs processed this run: 599 / 1000 | overall: 599 / 1000
# Match IDs processed this run: 600 / 1000 | overall: 600 / 1000
# Match IDs processed this run: 601 / 1000 | overall: 601 / 1000
# Match IDs processed this run: 602 / 1000 | overall: 602 / 1000
# Match IDs processed this run: 603 / 1000 | overall: 603 / 1000
# Match IDs processed this run: 604 / 1000 | overall: 604 / 1000
# Match IDs processed this run: 605 / 1000 | overall: 605 / 1000
# Match IDs processed this run: 606 / 1000 | overall: 606 / 1000
# Match IDs processed this run: 607 / 1000 | overall: 607 / 1000
# Match IDs processed this run: 608 / 1000 | overall: 608 / 1000
# Match IDs processed this run: 609 / 1000 | overall: 609 / 1000
# Match IDs processed this run: 610 / 1000 | overall: 610 / 1000
# Match IDs processed this run: 611 / 1000 | overall: 611 / 1000
# Match IDs processed this run: 612 / 1000 | overall: 612 / 1000
# Match IDs processed this run: 613 / 1000 | overall: 613 / 1000
# Match IDs processed this run: 614 / 1000 | overall: 614 / 1000
# Match IDs processed this run: 615 / 1000 | overall: 615 / 1000
# Match IDs processed this run: 616 / 1000 | overall: 616 / 1000
# Match IDs processed this run: 617 / 1000 | overall: 617 / 1000
# Match IDs processed this run: 618 / 1000 | overall: 618 / 1000
# Match IDs processed this run: 619 / 1000 | overall: 619 / 1000
# Match IDs processed this run: 620 / 1000 | overall: 620 / 1000
# Match IDs processed this run: 621 / 1000 | overall: 621 / 1000
# Match IDs processed this run: 622 / 1000 | overall: 622 / 1000
# Match IDs processed this run: 623 / 1000 | overall: 623 / 1000
# Match IDs processed this run: 624 / 1000 | overall: 624 / 1000
# Match IDs processed this run: 625 / 1000 | overall: 625 / 1000
# Match IDs processed this run: 626 / 1000 | overall: 626 / 1000
# Match IDs processed this run: 627 / 1000 | overall: 627 / 1000
# Match IDs processed this run: 628 / 1000 | overall: 628 / 1000
# Match IDs processed this run: 629 / 1000 | overall: 629 / 1000
# Match IDs processed this run: 630 / 1000 | overall: 630 / 1000
# Match IDs processed this run: 631 / 1000 | overall: 631 / 1000
# Match IDs processed this run: 632 / 1000 | overall: 632 / 1000
# Match IDs processed this run: 633 / 1000 | overall: 633 / 1000
# Match IDs processed this run: 634 / 1000 | overall: 634 / 1000
# Match IDs processed this run: 635 / 1000 | overall: 635 / 1000
# Match IDs processed this run: 636 / 1000 | overall: 636 / 1000
# Match IDs processed this run: 637 / 1000 | overall: 637 / 1000
# Match IDs processed this run: 638 / 1000 | overall: 638 / 1000
# Match IDs processed this run: 639 / 1000 | overall: 639 / 1000
# Match IDs processed this run: 640 / 1000 | overall: 640 / 1000
# Match IDs processed this run: 641 / 1000 | overall: 641 / 1000
# Match IDs processed this run: 642 / 1000 | overall: 642 / 1000
# Match IDs processed this run: 643 / 1000 | overall: 643 / 1000
# Match IDs processed this run: 644 / 1000 | overall: 644 / 1000
# Match IDs processed this run: 645 / 1000 | overall: 645 / 1000
# Match IDs processed this run: 646 / 1000 | overall: 646 / 1000
# Match IDs processed this run: 647 / 1000 | overall: 647 / 1000
# Match IDs processed this run: 648 / 1000 | overall: 648 / 1000
# Match IDs processed this run: 649 / 1000 | overall: 649 / 1000
# Match IDs processed this run: 650 / 1000 | overall: 650 / 1000
# Match IDs processed this run: 651 / 1000 | overall: 651 / 1000
# Match IDs processed this run: 652 / 1000 | overall: 652 / 1000
# Match IDs processed this run: 653 / 1000 | overall: 653 / 1000
# Match IDs processed this run: 654 / 1000 | overall: 654 / 1000
# Match IDs processed this run: 655 / 1000 | overall: 655 / 1000
# Match IDs processed this run: 656 / 1000 | overall: 656 / 1000
# Match IDs processed this run: 657 / 1000 | overall: 657 / 1000
# Match IDs processed this run: 658 / 1000 | overall: 658 / 1000
# Match IDs processed this run: 659 / 1000 | overall: 659 / 1000
# Match IDs processed this run: 660 / 1000 | overall: 660 / 1000
# Match IDs processed this run: 661 / 1000 | overall: 661 / 1000
# Match IDs processed this run: 662 / 1000 | overall: 662 / 1000
# Match IDs processed this run: 663 / 1000 | overall: 663 / 1000
# Match IDs processed this run: 664 / 1000 | overall: 664 / 1000
# Match IDs processed this run: 665 / 1000 | overall: 665 / 1000
# Match IDs processed this run: 666 / 1000 | overall: 666 / 1000
# Match IDs processed this run: 667 / 1000 | overall: 667 / 1000
# Match IDs processed this run: 668 / 1000 | overall: 668 / 1000
# Match IDs processed this run: 669 / 1000 | overall: 669 / 1000
# Match IDs processed this run: 670 / 1000 | overall: 670 / 1000
# Match IDs processed this run: 671 / 1000 | overall: 671 / 1000
# Match IDs processed this run: 672 / 1000 | overall: 672 / 1000
# Match IDs processed this run: 673 / 1000 | overall: 673 / 1000
# Match IDs processed this run: 674 / 1000 | overall: 674 / 1000
# Match IDs processed this run: 675 / 1000 | overall: 675 / 1000
# Match IDs processed this run: 676 / 1000 | overall: 676 / 1000
# Match IDs processed this run: 677 / 1000 | overall: 677 / 1000
# Match IDs processed this run: 678 / 1000 | overall: 678 / 1000
# Match IDs processed this run: 679 / 1000 | overall: 679 / 1000
# Match IDs processed this run: 680 / 1000 | overall: 680 / 1000
# Match IDs processed this run: 681 / 1000 | overall: 681 / 1000
# Match IDs processed this run: 682 / 1000 | overall: 682 / 1000
# Match IDs processed this run: 683 / 1000 | overall: 683 / 1000
# Match IDs processed this run: 684 / 1000 | overall: 684 / 1000
# Match IDs processed this run: 685 / 1000 | overall: 685 / 1000
# Match IDs processed this run: 686 / 1000 | overall: 686 / 1000
# Match IDs processed this run: 687 / 1000 | overall: 687 / 1000
# Match IDs processed this run: 688 / 1000 | overall: 688 / 1000
# Match IDs processed this run: 689 / 1000 | overall: 689 / 1000
# Match IDs processed this run: 690 / 1000 | overall: 690 / 1000
# Match IDs processed this run: 691 / 1000 | overall: 691 / 1000
# Match IDs processed this run: 692 / 1000 | overall: 692 / 1000
# Match IDs processed this run: 693 / 1000 | overall: 693 / 1000
# Match IDs processed this run: 694 / 1000 | overall: 694 / 1000
# Match IDs processed this run: 695 / 1000 | overall: 695 / 1000
# Match IDs processed this run: 696 / 1000 | overall: 696 / 1000
# Match IDs processed this run: 697 / 1000 | overall: 697 / 1000
# Match IDs processed this run: 698 / 1000 | overall: 698 / 1000
# Match IDs processed this run: 699 / 1000 | overall: 699 / 1000
# Match IDs processed this run: 700 / 1000 | overall: 700 / 1000
# Match IDs processed this run: 701 / 1000 | overall: 701 / 1000
# Match IDs processed this run: 702 / 1000 | overall: 702 / 1000
# Match IDs processed this run: 703 / 1000 | overall: 703 / 1000
# Match IDs processed this run: 704 / 1000 | overall: 704 / 1000
# Match IDs processed this run: 705 / 1000 | overall: 705 / 1000
# Match IDs processed this run: 706 / 1000 | overall: 706 / 1000
# Match IDs processed this run: 707 / 1000 | overall: 707 / 1000
# Match IDs processed this run: 708 / 1000 | overall: 708 / 1000
# Match IDs processed this run: 709 / 1000 | overall: 709 / 1000
# Match IDs processed this run: 710 / 1000 | overall: 710 / 1000
# Match IDs processed this run: 711 / 1000 | overall: 711 / 1000
# Match IDs processed this run: 712 / 1000 | overall: 712 / 1000
# Match IDs processed this run: 713 / 1000 | overall: 713 / 1000
# Match IDs processed this run: 714 / 1000 | overall: 714 / 1000
# Match IDs processed this run: 715 / 1000 | overall: 715 / 1000
# Match IDs processed this run: 716 / 1000 | overall: 716 / 1000
# Match IDs processed this run: 717 / 1000 | overall: 717 / 1000
# Match IDs processed this run: 718 / 1000 | overall: 718 / 1000
# Match IDs processed this run: 719 / 1000 | overall: 719 / 1000
# Match IDs processed this run: 720 / 1000 | overall: 720 / 1000
# Match IDs processed this run: 721 / 1000 | overall: 721 / 1000
# Match IDs processed this run: 722 / 1000 | overall: 722 / 1000
# Match IDs processed this run: 723 / 1000 | overall: 723 / 1000
# Match IDs processed this run: 724 / 1000 | overall: 724 / 1000
# Match IDs processed this run: 725 / 1000 | overall: 725 / 1000
# Match IDs processed this run: 726 / 1000 | overall: 726 / 1000
# Match IDs processed this run: 727 / 1000 | overall: 727 / 1000
# Match IDs processed this run: 728 / 1000 | overall: 728 / 1000
# Match IDs processed this run: 729 / 1000 | overall: 729 / 1000
# Match IDs processed this run: 730 / 1000 | overall: 730 / 1000
# Match IDs processed this run: 731 / 1000 | overall: 731 / 1000
# Match IDs processed this run: 732 / 1000 | overall: 732 / 1000
# Match IDs processed this run: 733 / 1000 | overall: 733 / 1000
# Match IDs processed this run: 734 / 1000 | overall: 734 / 1000
# Match IDs processed this run: 735 / 1000 | overall: 735 / 1000
# Match IDs processed this run: 736 / 1000 | overall: 736 / 1000
# Match IDs processed this run: 737 / 1000 | overall: 737 / 1000
# Match IDs processed this run: 738 / 1000 | overall: 738 / 1000
# Match IDs processed this run: 739 / 1000 | overall: 739 / 1000
# Match IDs processed this run: 740 / 1000 | overall: 740 / 1000
# Match IDs processed this run: 741 / 1000 | overall: 741 / 1000
# Match IDs processed this run: 742 / 1000 | overall: 742 / 1000
# Match IDs processed this run: 743 / 1000 | overall: 743 / 1000
# Match IDs processed this run: 744 / 1000 | overall: 744 / 1000
# Match IDs processed this run: 745 / 1000 | overall: 745 / 1000
# Match IDs processed this run: 746 / 1000 | overall: 746 / 1000
# Match IDs processed this run: 747 / 1000 | overall: 747 / 1000
# Match IDs processed this run: 748 / 1000 | overall: 748 / 1000
# Match IDs processed this run: 749 / 1000 | overall: 749 / 1000
# Match IDs processed this run: 750 / 1000 | overall: 750 / 1000
# Match IDs processed this run: 751 / 1000 | overall: 751 / 1000
# Match IDs processed this run: 752 / 1000 | overall: 752 / 1000
# Match IDs processed this run: 753 / 1000 | overall: 753 / 1000
# Match IDs processed this run: 754 / 1000 | overall: 754 / 1000
# Match IDs processed this run: 755 / 1000 | overall: 755 / 1000
# Match IDs processed this run: 756 / 1000 | overall: 756 / 1000
# Match IDs processed this run: 757 / 1000 | overall: 757 / 1000
# Match IDs processed this run: 758 / 1000 | overall: 758 / 1000
# Match IDs processed this run: 759 / 1000 | overall: 759 / 1000
# Match IDs processed this run: 760 / 1000 | overall: 760 / 1000
# Match IDs processed this run: 761 / 1000 | overall: 761 / 1000
# Match IDs processed this run: 762 / 1000 | overall: 762 / 1000
# Match IDs processed this run: 763 / 1000 | overall: 763 / 1000
# Match IDs processed this run: 764 / 1000 | overall: 764 / 1000
# Match IDs processed this run: 765 / 1000 | overall: 765 / 1000
# Match IDs processed this run: 766 / 1000 | overall: 766 / 1000
# Match IDs processed this run: 767 / 1000 | overall: 767 / 1000
# Match IDs processed this run: 768 / 1000 | overall: 768 / 1000
# Match IDs processed this run: 769 / 1000 | overall: 769 / 1000
# Match IDs processed this run: 770 / 1000 | overall: 770 / 1000
# Match IDs processed this run: 771 / 1000 | overall: 771 / 1000
# Match IDs processed this run: 772 / 1000 | overall: 772 / 1000
# Match IDs processed this run: 773 / 1000 | overall: 773 / 1000
# Match IDs processed this run: 774 / 1000 | overall: 774 / 1000
# Match IDs processed this run: 775 / 1000 | overall: 775 / 1000
# Match IDs processed this run: 776 / 1000 | overall: 776 / 1000
# Match IDs processed this run: 777 / 1000 | overall: 777 / 1000
# Match IDs processed this run: 778 / 1000 | overall: 778 / 1000
# Match IDs processed this run: 779 / 1000 | overall: 779 / 1000
# Match IDs processed this run: 780 / 1000 | overall: 780 / 1000
# Match IDs processed this run: 781 / 1000 | overall: 781 / 1000
# Match IDs processed this run: 782 / 1000 | overall: 782 / 1000
# Match IDs processed this run: 783 / 1000 | overall: 783 / 1000
# Match IDs processed this run: 784 / 1000 | overall: 784 / 1000
# Match IDs processed this run: 785 / 1000 | overall: 785 / 1000
# Match IDs processed this run: 786 / 1000 | overall: 786 / 1000
# Match IDs processed this run: 787 / 1000 | overall: 787 / 1000
# Match IDs processed this run: 788 / 1000 | overall: 788 / 1000
# Match IDs processed this run: 789 / 1000 | overall: 789 / 1000
# Match IDs processed this run: 790 / 1000 | overall: 790 / 1000
# Match IDs processed this run: 791 / 1000 | overall: 791 / 1000
# Match IDs processed this run: 792 / 1000 | overall: 792 / 1000
# Match IDs processed this run: 793 / 1000 | overall: 793 / 1000
# Match IDs processed this run: 794 / 1000 | overall: 794 / 1000
# Match IDs processed this run: 795 / 1000 | overall: 795 / 1000
# Match IDs processed this run: 796 / 1000 | overall: 796 / 1000
# Match IDs processed this run: 797 / 1000 | overall: 797 / 1000
# Match IDs processed this run: 798 / 1000 | overall: 798 / 1000
# Match IDs processed this run: 799 / 1000 | overall: 799 / 1000
# Match IDs processed this run: 800 / 1000 | overall: 800 / 1000
# Match IDs processed this run: 801 / 1000 | overall: 801 / 1000
# Match IDs processed this run: 802 / 1000 | overall: 802 / 1000
# Match IDs processed this run: 803 / 1000 | overall: 803 / 1000
# Match IDs processed this run: 804 / 1000 | overall: 804 / 1000
# Match IDs processed this run: 805 / 1000 | overall: 805 / 1000
# Match IDs processed this run: 806 / 1000 | overall: 806 / 1000
# Match IDs processed this run: 807 / 1000 | overall: 807 / 1000
# Match IDs processed this run: 808 / 1000 | overall: 808 / 1000
# Match IDs processed this run: 809 / 1000 | overall: 809 / 1000
# Match IDs processed this run: 810 / 1000 | overall: 810 / 1000
# Match IDs processed this run: 811 / 1000 | overall: 811 / 1000
# Match IDs processed this run: 812 / 1000 | overall: 812 / 1000
# Match IDs processed this run: 813 / 1000 | overall: 813 / 1000
# Match IDs processed this run: 814 / 1000 | overall: 814 / 1000
# Match IDs processed this run: 815 / 1000 | overall: 815 / 1000
# Match IDs processed this run: 816 / 1000 | overall: 816 / 1000
# Match IDs processed this run: 817 / 1000 | overall: 817 / 1000
# Match IDs processed this run: 818 / 1000 | overall: 818 / 1000
# Match IDs processed this run: 819 / 1000 | overall: 819 / 1000
# Match IDs processed this run: 820 / 1000 | overall: 820 / 1000
# Match IDs processed this run: 821 / 1000 | overall: 821 / 1000
# Match IDs processed this run: 822 / 1000 | overall: 822 / 1000
# Match IDs processed this run: 823 / 1000 | overall: 823 / 1000
# Match IDs processed this run: 824 / 1000 | overall: 824 / 1000
# Match IDs processed this run: 825 / 1000 | overall: 825 / 1000
# Match IDs processed this run: 826 / 1000 | overall: 826 / 1000
# Match IDs processed this run: 827 / 1000 | overall: 827 / 1000
# Match IDs processed this run: 828 / 1000 | overall: 828 / 1000
# Match IDs processed this run: 829 / 1000 | overall: 829 / 1000
# Match IDs processed this run: 830 / 1000 | overall: 830 / 1000
# Match IDs processed this run: 831 / 1000 | overall: 831 / 1000
# Match IDs processed this run: 832 / 1000 | overall: 832 / 1000
# Match IDs processed this run: 833 / 1000 | overall: 833 / 1000
# Match IDs processed this run: 834 / 1000 | overall: 834 / 1000
# Match IDs processed this run: 835 / 1000 | overall: 835 / 1000
# Match IDs processed this run: 836 / 1000 | overall: 836 / 1000
# Match IDs processed this run: 837 / 1000 | overall: 837 / 1000
# Match IDs processed this run: 838 / 1000 | overall: 838 / 1000
# Match IDs processed this run: 839 / 1000 | overall: 839 / 1000
# Match IDs processed this run: 840 / 1000 | overall: 840 / 1000
# Match IDs processed this run: 841 / 1000 | overall: 841 / 1000
# Match IDs processed this run: 842 / 1000 | overall: 842 / 1000
# Match IDs processed this run: 843 / 1000 | overall: 843 / 1000
# Match IDs processed this run: 844 / 1000 | overall: 844 / 1000
# Match IDs processed this run: 845 / 1000 | overall: 845 / 1000
# Match IDs processed this run: 846 / 1000 | overall: 846 / 1000
# Match IDs processed this run: 847 / 1000 | overall: 847 / 1000
# Match IDs processed this run: 848 / 1000 | overall: 848 / 1000
# Match IDs processed this run: 849 / 1000 | overall: 849 / 1000
# Match IDs processed this run: 850 / 1000 | overall: 850 / 1000
# Match IDs processed this run: 851 / 1000 | overall: 851 / 1000
# Match IDs processed this run: 852 / 1000 | overall: 852 / 1000
# Match IDs processed this run: 853 / 1000 | overall: 853 / 1000
# Match IDs processed this run: 854 / 1000 | overall: 854 / 1000
# Match IDs processed this run: 855 / 1000 | overall: 855 / 1000
# Match IDs processed this run: 856 / 1000 | overall: 856 / 1000
# Match IDs processed this run: 857 / 1000 | overall: 857 / 1000
# Match IDs processed this run: 858 / 1000 | overall: 858 / 1000
# Match IDs processed this run: 859 / 1000 | overall: 859 / 1000
# Match IDs processed this run: 860 / 1000 | overall: 860 / 1000
# Match IDs processed this run: 861 / 1000 | overall: 861 / 1000
# Match IDs processed this run: 862 / 1000 | overall: 862 / 1000
# Match IDs processed this run: 863 / 1000 | overall: 863 / 1000
# Match IDs processed this run: 864 / 1000 | overall: 864 / 1000
# Match IDs processed this run: 865 / 1000 | overall: 865 / 1000
# Match IDs processed this run: 866 / 1000 | overall: 866 / 1000
# Match IDs processed this run: 867 / 1000 | overall: 867 / 1000
# Match IDs processed this run: 868 / 1000 | overall: 868 / 1000
# Match IDs processed this run: 869 / 1000 | overall: 869 / 1000
# Match IDs processed this run: 870 / 1000 | overall: 870 / 1000
# Match IDs processed this run: 871 / 1000 | overall: 871 / 1000
# Match IDs processed this run: 872 / 1000 | overall: 872 / 1000
# Match IDs processed this run: 873 / 1000 | overall: 873 / 1000
# Match IDs processed this run: 874 / 1000 | overall: 874 / 1000
# Match IDs processed this run: 875 / 1000 | overall: 875 / 1000
# Match IDs processed this run: 876 / 1000 | overall: 876 / 1000
# Match IDs processed this run: 877 / 1000 | overall: 877 / 1000
# Match IDs processed this run: 878 / 1000 | overall: 878 / 1000
# Match IDs processed this run: 879 / 1000 | overall: 879 / 1000
# Match IDs processed this run: 880 / 1000 | overall: 880 / 1000
# Match IDs processed this run: 881 / 1000 | overall: 881 / 1000
# Match IDs processed this run: 882 / 1000 | overall: 882 / 1000
# Match IDs processed this run: 883 / 1000 | overall: 883 / 1000
# Match IDs processed this run: 884 / 1000 | overall: 884 / 1000
# Match IDs processed this run: 885 / 1000 | overall: 885 / 1000
# Match IDs processed this run: 886 / 1000 | overall: 886 / 1000
# Match IDs processed this run: 887 / 1000 | overall: 887 / 1000
# Match IDs processed this run: 888 / 1000 | overall: 888 / 1000
# Match IDs processed this run: 889 / 1000 | overall: 889 / 1000
# Match IDs processed this run: 890 / 1000 | overall: 890 / 1000
# Match IDs processed this run: 891 / 1000 | overall: 891 / 1000
# Match IDs processed this run: 892 / 1000 | overall: 892 / 1000
# Match IDs processed this run: 893 / 1000 | overall: 893 / 1000
# Match IDs processed this run: 894 / 1000 | overall: 894 / 1000
# Match IDs processed this run: 895 / 1000 | overall: 895 / 1000
# Match IDs processed this run: 896 / 1000 | overall: 896 / 1000
# Match IDs processed this run: 897 / 1000 | overall: 897 / 1000
# Match IDs processed this run: 898 / 1000 | overall: 898 / 1000
# Match IDs processed this run: 899 / 1000 | overall: 899 / 1000
# Match IDs processed this run: 900 / 1000 | overall: 900 / 1000
# Match IDs processed this run: 901 / 1000 | overall: 901 / 1000
# Match IDs processed this run: 902 / 1000 | overall: 902 / 1000
# Match IDs processed this run: 903 / 1000 | overall: 903 / 1000
# Match IDs processed this run: 904 / 1000 | overall: 904 / 1000
# Match IDs processed this run: 905 / 1000 | overall: 905 / 1000
# Match IDs processed this run: 906 / 1000 | overall: 906 / 1000
# Match IDs processed this run: 907 / 1000 | overall: 907 / 1000
# Match IDs processed this run: 908 / 1000 | overall: 908 / 1000
# Match IDs processed this run: 909 / 1000 | overall: 909 / 1000
# Match IDs processed this run: 910 / 1000 | overall: 910 / 1000
# Match IDs processed this run: 911 / 1000 | overall: 911 / 1000
# Match IDs processed this run: 912 / 1000 | overall: 912 / 1000
# Match IDs processed this run: 913 / 1000 | overall: 913 / 1000
# Match IDs processed this run: 914 / 1000 | overall: 914 / 1000
# Match IDs processed this run: 915 / 1000 | overall: 915 / 1000
# Match IDs processed this run: 916 / 1000 | overall: 916 / 1000
# Match IDs processed this run: 917 / 1000 | overall: 917 / 1000
# Match IDs processed this run: 918 / 1000 | overall: 918 / 1000
# Match IDs processed this run: 919 / 1000 | overall: 919 / 1000
# Match IDs processed this run: 920 / 1000 | overall: 920 / 1000
# Match IDs processed this run: 921 / 1000 | overall: 921 / 1000
# Match IDs processed this run: 922 / 1000 | overall: 922 / 1000
# Match IDs processed this run: 923 / 1000 | overall: 923 / 1000
# Match IDs processed this run: 924 / 1000 | overall: 924 / 1000
# Match IDs processed this run: 925 / 1000 | overall: 925 / 1000
# Match IDs processed this run: 926 / 1000 | overall: 926 / 1000
# Match IDs processed this run: 927 / 1000 | overall: 927 / 1000
# Match IDs processed this run: 928 / 1000 | overall: 928 / 1000
# Match IDs processed this run: 929 / 1000 | overall: 929 / 1000
# Match IDs processed this run: 930 / 1000 | overall: 930 / 1000
# Match IDs processed this run: 931 / 1000 | overall: 931 / 1000
# Match IDs processed this run: 932 / 1000 | overall: 932 / 1000
# Match IDs processed this run: 933 / 1000 | overall: 933 / 1000
# Match IDs processed this run: 934 / 1000 | overall: 934 / 1000
# Match IDs processed this run: 935 / 1000 | overall: 935 / 1000
# Match IDs processed this run: 936 / 1000 | overall: 936 / 1000
# Match IDs processed this run: 937 / 1000 | overall: 937 / 1000
# Match IDs processed this run: 938 / 1000 | overall: 938 / 1000
# Match IDs processed this run: 939 / 1000 | overall: 939 / 1000
# Match IDs processed this run: 940 / 1000 | overall: 940 / 1000
# Match IDs processed this run: 941 / 1000 | overall: 941 / 1000
# Match IDs processed this run: 942 / 1000 | overall: 942 / 1000
# Match IDs processed this run: 943 / 1000 | overall: 943 / 1000
# Match IDs processed this run: 944 / 1000 | overall: 944 / 1000
# Match IDs processed this run: 945 / 1000 | overall: 945 / 1000
# Match IDs processed this run: 946 / 1000 | overall: 946 / 1000
# Match IDs processed this run: 947 / 1000 | overall: 947 / 1000
# Match IDs processed this run: 948 / 1000 | overall: 948 / 1000
# Match IDs processed this run: 949 / 1000 | overall: 949 / 1000
# Match IDs processed this run: 950 / 1000 | overall: 950 / 1000
# Match IDs processed this run: 951 / 1000 | overall: 951 / 1000
# Match IDs processed this run: 952 / 1000 | overall: 952 / 1000
# Match IDs processed this run: 953 / 1000 | overall: 953 / 1000
# Match IDs processed this run: 954 / 1000 | overall: 954 / 1000
# Match IDs processed this run: 955 / 1000 | overall: 955 / 1000
# Match IDs processed this run: 956 / 1000 | overall: 956 / 1000
# Match IDs processed this run: 957 / 1000 | overall: 957 / 1000
# Match IDs processed this run: 958 / 1000 | overall: 958 / 1000
# Match IDs processed this run: 959 / 1000 | overall: 959 / 1000
# Match IDs processed this run: 960 / 1000 | overall: 960 / 1000
# Match IDs processed this run: 961 / 1000 | overall: 961 / 1000
# Match IDs processed this run: 962 / 1000 | overall: 962 / 1000
# Match IDs processed this run: 963 / 1000 | overall: 963 / 1000
# Match IDs processed this run: 964 / 1000 | overall: 964 / 1000
# Match IDs processed this run: 965 / 1000 | overall: 965 / 1000
# Match IDs processed this run: 966 / 1000 | overall: 966 / 1000
# Match IDs processed this run: 967 / 1000 | overall: 967 / 1000
# Match IDs processed this run: 968 / 1000 | overall: 968 / 1000
# Match IDs processed this run: 969 / 1000 | overall: 969 / 1000
# Match IDs processed this run: 970 / 1000 | overall: 970 / 1000
# Match IDs processed this run: 971 / 1000 | overall: 971 / 1000
# Match IDs processed this run: 972 / 1000 | overall: 972 / 1000
# Match IDs processed this run: 973 / 1000 | overall: 973 / 1000
# Match IDs processed this run: 974 / 1000 | overall: 974 / 1000
# Match IDs processed this run: 975 / 1000 | overall: 975 / 1000
# Match IDs processed this run: 976 / 1000 | overall: 976 / 1000
# Match IDs processed this run: 977 / 1000 | overall: 977 / 1000
# Match IDs processed this run: 978 / 1000 | overall: 978 / 1000
# Match IDs processed this run: 979 / 1000 | overall: 979 / 1000
# Match IDs processed this run: 980 / 1000 | overall: 980 / 1000
# Match IDs processed this run: 981 / 1000 | overall: 981 / 1000
# Match IDs processed this run: 982 / 1000 | overall: 982 / 1000
# Match IDs processed this run: 983 / 1000 | overall: 983 / 1000
# Match IDs processed this run: 984 / 1000 | overall: 984 / 1000
# Match IDs processed this run: 985 / 1000 | overall: 985 / 1000
# Match IDs processed this run: 986 / 1000 | overall: 986 / 1000
# Match IDs processed this run: 987 / 1000 | overall: 987 / 1000
# Match IDs processed this run: 988 / 1000 | overall: 988 / 1000
# Match IDs processed this run: 989 / 1000 | overall: 989 / 1000
# Match IDs processed this run: 990 / 1000 | overall: 990 / 1000
# Match IDs processed this run: 991 / 1000 | overall: 991 / 1000
# Match IDs processed this run: 992 / 1000 | overall: 992 / 1000
# Match IDs processed this run: 993 / 1000 | overall: 993 / 1000
# Match IDs processed this run: 994 / 1000 | overall: 994 / 1000
# Match IDs processed this run: 995 / 1000 | overall: 995 / 1000
# Match IDs processed this run: 996 / 1000 | overall: 996 / 1000
# Match IDs processed this run: 997 / 1000 | overall: 997 / 1000
# Match IDs processed this run: 998 / 1000 | overall: 998 / 1000
# Match IDs processed this run: 999 / 1000 | overall: 999 / 1000
# Match IDs processed this run: 1000 / 1000 | overall: 1000 / 1000
# Done. Saved champion picks for 1500 matches to /Users/ruofuli/hcde530/Week 5/champion_picks_by_match_id.json

# %% [markdown]
# The code above is actually the second iteration of the script to fetch data from the endpoint due to its massive payload. The first time, I had asked the script to store ALL the fetched data into a JSON file, but that quickly crashed Cursor due to how much information there was. The second iteration of this code still fetches all the API data associated with this Match ID from this endpoint, but now only stores the champion pick data after it's already been sorted for it.

# %% [markdown]
# #### 8a. Converting champion pick JSON to a usable DataFrame
# Next, it'd be really nice if we could see our data laid out. The script below converts `champion_picks_by_match_id` into a usable DataFrame for Pandas Analysis.

# %%
from pathlib import Path
import json

picks_candidates = [
    Path("champion_picks_by_match_id.json"),
    Path("Week 5") / "champion_picks_by_match_id.json",
    Path("..") / "Week 5" / "champion_picks_by_match_id.json",
]
picks_path = next((p for p in picks_candidates if p.is_file()), None)
if picks_path is None:
    raise FileNotFoundError(
        "champion_picks_by_match_id.json not found. Tried: " + ", ".join(str(p) for p in picks_candidates)
    )

with open(picks_path, encoding="utf-8") as f:
    champion_picks_by_match_id = json.load(f)

if not isinstance(champion_picks_by_match_id, dict):
    raise TypeError("champion_picks_by_match_id.json should be a JSON object keyed by match_id.")

rows = []
for match_id, participants in champion_picks_by_match_id.items():
    if not isinstance(participants, list):
        continue
    for pick in participants:
        if not isinstance(pick, dict):
            continue
        row = {"match_id": match_id, **pick}
        rows.append(row)

champion_picks_df = pd.DataFrame(rows)

print("Loaded:", picks_path.resolve())
print("shape (rows, columns):", champion_picks_df.shape)
champion_picks_df.head(10)
# Out:
# Loaded: /Users/ruofuli/hcde530/Week 5/champion_picks_by_match_id.json
# shape (rows, columns): (4990, 8)
#          match_id                                              puuid  \
# 0  NA1_5550304472  dmr_PvsJDqRYwdOsAvRCGlp5676GgstHkcKjev1N03OTVQ...
# 1  NA1_5550304472  73-lrrlMMVWme9MM0yPNZGWRe74f6bjBBK5HAiZu3W9Ddf...
# 2  NA1_5550304472  jK6YPX1S57Juet21uvU4wLeRrINqVQ-7PWF7Qk_zEQgugc...
# 3  NA1_5550304472  iVw8Qyyy0kgySNltkzIj9Cer2Z-vOFtc1pHUwtNjNI9tsV...
# 4  NA1_5550304472  UL3qXsy63hmThQw39LTtPWK2JI316v5jHX8r_yw5g9A873...
# 5  NA1_5550304472  Au4sDCmV_atawjHQC2vcrWMPjWuc8PJOESsfdSsjd8ccZp...
# 6  NA1_5550304472  0rYwoUgz9vPFfOBod9IatryWC116iveVrTyuNmpSbhBaY8...
# 7  NA1_5550304472  8s1zQmQWiAEgiwPnj1SOukd-e31Em6ZJrXFMcaqKcp1sAu...
# 8  NA1_5550304472  pHmzT3fviEQn8RsZTB4P3V2p2K-5SjbMZEFFt7S5i1LwXD...
# 9  NA1_5550304472  o9UXKEi4u2kwH6F9UJVxFy8x6Jbi2tXl3Y5sFmPaDBR8Us...
#
#    championId championName  teamId teamPosition individualPosition    win
# 0           6        Urgot     100          TOP                TOP  False
# 1          11     MasterYi     100       JUNGLE             JUNGLE  False
# 2          79       Gragas     100       MIDDLE             MIDDLE  False
# 3         875         Sett     100       BOTTOM             BOTTOM  False
# 4         235        Senna     100      UTILITY            UTILITY  False
# 5          23   Tryndamere     200          TOP                TOP   True
# 6         141         Kayn     200       JUNGLE             JUNGLE   True
# 7         134       Syndra     200       MIDDLE             MIDDLE   True
# 8         145        Kaisa     200       BOTTOM             BOTTOM   True
# 9          89        Leona     200      UTILITY            UTILITY   True

# %% [markdown]
# #### 8b. Further Cleaning- Sorting by teamPosition == UTILITY
# Even though we already sorted the fetched data and only stored the information about champion picks, it still includes a lot of other roles that we're not looking for. As a result, let's clean this dataset up a little to only show us the Support champion picks.

# %%
if "champion_picks_df" not in globals():
    raise RuntimeError("Run section 8a first so champion_picks_df exists.")

support_picks_df = champion_picks_df[champion_picks_df["teamPosition"] == "UTILITY"].copy()

print("rows before filter:", len(champion_picks_df))
print("support rows (UTILITY):", len(support_picks_df))
support_picks_df.head(10)
# Out:
# rows before filter: 4990
# support rows (UTILITY): 996
#           match_id                                              puuid  \
# 4   NA1_5550304472  UL3qXsy63hmThQw39LTtPWK2JI316v5jHX8r_yw5g9A873...
# 9   NA1_5550304472  o9UXKEi4u2kwH6F9UJVxFy8x6Jbi2tXl3Y5sFmPaDBR8Us...
# 14  NA1_5545162641  iAPisvb-m-cDkpVmzVJtNKdNjTwoIgk-PkKIvRQScvPeed...
# 19  NA1_5545162641  z47LTXaQxM72C5dDdLwpdhuZJVDjcmnqkjE11WKKhqtDPx...
# 24  NA1_5530609519  Kj3raKvthe46haxKC6N2LOpUK8_VxgOyRUo48bufObv60i...
# 29  NA1_5530609519  LkD9mUW8W5xEDss269mnh1dmIhdsc-kwm3JB7B_YU8bunW...
# 34  NA1_5530552256  YGIe4YJJm9C8UxGgFnMxB0R28D8eoq7sZd4_7LScRtXGW0...
# 39  NA1_5530552256  vlZi8mpfS47IqAtxbXCjLUWUq9HZqzumvz1fZQ-sYeYxUn...
# 44  NA1_5530519318  05ULVbcqTZ6gRRf_HohaNzkVKlnpa-_X1vScIiIOc2pReR...
# 49  NA1_5530519318  JX2dXFlJi6A2-ZC3Cbzrk6OrAVex80DXcZUIv0oFVxaqlX...
#
#     championId championName  teamId teamPosition individualPosition    win
# 4          235        Senna     100      UTILITY            UTILITY  False
# 9           89        Leona     200      UTILITY            UTILITY   True
# 14          53   Blitzcrank     100      UTILITY            UTILITY   True
# 19          26       Zilean     200      UTILITY            UTILITY  False
# 24          22         Ashe     100      UTILITY            UTILITY   True
# 29          50        Swain     200      UTILITY            UTILITY  False
# 34         223    TahmKench     100      UTILITY            UTILITY  False
# 39          50        Swain     200      UTILITY            UTILITY   True
# 44         161       Velkoz     100      UTILITY            UTILITY   True
# 49          25      Morgana     200      UTILITY            UTILITY  False

# %% [markdown]
# #### 8c. Exporting support picks to CSV for visualization

# %%
from pathlib import Path

if "support_picks_df" not in globals():
    raise RuntimeError("Run section 8b first so support_picks_df exists.")

csv_candidates = [
    Path("support_picks.csv"),
    Path("Week 5") / "support_picks.csv",
    Path("..") / "Week 5" / "support_picks.csv",
]
csv_path = next((p for p in csv_candidates if p.parent.exists()), csv_candidates[0])

support_picks_df.to_csv(csv_path, index=False)
print("Saved support picks CSV to:", csv_path.resolve())
print("rows exported:", len(support_picks_df))
# Out:
# Saved support picks CSV to: /Users/ruofuli/hcde530/Week 5/support_picks.csv
# rows exported: 996

# %% [markdown]
# ---
#
# ## A5 Correction
#
# In this section, we'll finally be analyzing `support_picks.csv` to answer our core analytical questions. While the pandas operations above helped us clean the dataset for analysis, the operations below help us answer our analytical questions (as adjusted in MP1).

# %% [markdown]
# #### Question 1: Who is the most played Support champion in Bronze IV Solo 5x5 Ranked lobbies?
# The script below groups all champions in `support_picks.csv` and aggregates their pick count to see which Support champion is the most selected, represented in descending order.

# %%
# Count how often each support champion appears, then sort most → least to see who the most played Support champion is
champion_pick_counts = (
    df.groupby("championName", as_index=False) #pandas groupby function to group the raw data by champion name
    .agg(pick_count=("championName", "size")) #aggregate the sorted data above by pick count for each champion
    .sort_values("pick_count", ascending=False) #sort the champions by pick count in descending order
)

champion_pick_counts.head(10) #so i can see the top 10 champions that were sorted
# Out:
#     championName  pick_count
# 67           Lux         805
# 77       Morgana         683
# 108    Seraphine         668
# 79          Nami         376
# 62         Leona         364
# 81      Nautilus         343
# 15         Brand         329
# 117         Sona         311
# 126       Thresh         302
# 92          Pyke         285

# %% [markdown]
# #### Question 2: What is the win rate for the top 3 Support champions in this lobby?
# The script below calculates the win rate for the top 3 most selected Support champions and sorts them in descending order.

# %%
#sorts dataset by champion name, pick count, and win rate in that order to see what the win rate is for the top 3 most selected champions
champion_pick_counts = (
    df.groupby("championName", as_index=False) #pandas groupby function to group the data by champion name
    .agg(pick_count=("championName", "size"), win_rate=("win", "mean")) #aggregate the pick count and win rate for each champion
    .sort_values("pick_count", ascending=False) #sort the champions by pick count in descending order
)

champion_pick_counts.head(3)
# Out:
#     championName  pick_count  win_rate
# 67           Lux         805  0.505590
# 77       Morgana         683  0.496340
# 108    Seraphine         668  0.483533

# %% [markdown]
# #### Question 3: Which of the top 10 Support champions with the most picks overall has the highest win rate?
#
# The script below filters the dataset to include the top 10 champions with the most picks and sorts them in descending order based on win rate.

# %%
#Sorts dataset by champion name, pick count, and win rate in that order to see what the win rate is for the top 10 most picked champions
champion_pick_counts = (
    df.groupby("championName", as_index=False) #pandas groupby function to group the data by champion name
    .agg(pick_count=("championName", "size"), win_rate=("win", "mean")) #aggregate the pick count and win rate for each champion
    .query("pick_count > 20") #filter the data to only include champions with more than 20 picks
    .sort_values("win_rate", ascending=False) #sort the champions by win rate in descending order
)

champion_pick_counts
# Out:
#     championName  pick_count  win_rate
# 62         Leona         364  0.543956
# 117         Sona         311  0.517685
# 15         Brand         329  0.513678
# 81      Nautilus         343  0.513120
# 126       Thresh         302  0.509934
# 67           Lux         805  0.505590
# 77       Morgana         683  0.496340
# 92          Pyke         285  0.487719
# 108    Seraphine         668  0.483533
# 79          Nami         376  0.476064

# %% [markdown]
# #### Question 3 Pt 2: Which Support champion with more than 20 picks has the highest win rate (not just restricted to the top 10 champions)?
#
# The script below filters the dataset to the champions with a pick count of more than 20 and sorts them in descending order based on win rate.

# %%
#sorts dataset by champion name, pick count, and win rate in that order to see what the win rate is for the top 10 most picked champions (that have more than 20 picks because a lot of them only had 1-2 picks)
champion_pick_counts = (
    df.groupby("championName", as_index=False) #pandas groupby function to group the data by champion name
    .agg(pick_count=("championName", "size"), win_rate=("win", "mean")) #aggregate the pick count and win rate for each champion
    .query("pick_count > 20") #filter the data to only include champions with more than 20 picks
    .sort_values("win_rate", ascending=False) #sort the champions by win rate in descending order
)

champion_pick_counts.head(10)
# Out:
#      championName  pick_count  win_rate
# 135        Veigar          46  0.630435
# 5          Anivia          36  0.611111
# 119         Swain         271  0.605166
# 111          Shen          42  0.595238
# 154           Zoe          22  0.590909
# 39   Heimerdinger          22  0.590909
# 124         Taric          86  0.581395
# 70         Maokai         104  0.576923
# 110         Shaco          50  0.560000
# 44          Janna          58  0.551724
